# %%
import tensorflow as tf
import numpy as np
import os
import get_data
from Word2Vec import Word2Vec_Model
from IPython.display import clear_output, Image, display, HTML

tf.logging.set_verbosity(tf.logging.INFO)

########## Hyperparameter ##########
BATCH_SIZE = 20
VALIDATION_SIZE = 500
EPOCH_BOUND = 1000
EARLY_STOP_CHECK_EPOCH = 20
TAKE_CROSS_VALIDATION = False
CROSS_VALIDATION = 5
TEXT_EMBEDDING_SIZE = 300
MARGIN = 0.1
STORED_PATH = "./devise_model/devise.ckpt"
########## Hyperparameter ##########

########## load Word2Vec model ##########
# TextEmbeddings = TextEmbeddings(word2vec_model_path="./Data/glove.6B/glove.6B.50d.txt")
# all_text_embedding = TextEmbeddings.load_light_word2vec()
# W2V_texts = np.array(list(all_text_embedding.keys()), dtype=np.str)
# print('W2V_texts', W2V_texts.shape)

TextEmbeddings = Word2Vec_Model(word2vec_model_path="./Data/wiki.en.vec")
# Out:
# /Users/jean/tensorflow/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# ##### loading word2vec model #####
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-2e1105a057c6> in <module>()
#      26 # print('W2V_texts', W2V_texts.shape)
#      27
# ---> 28 TextEmbeddings = Word2Vec_Model(word2vec_model_path="./Data/wiki.en.vec")
#      29
#
# ~/Projects/DeViSE/Word2Vec.py in __init__(self, training_data, word2vec_model_path, model, nearest_neighbor)
#      21         if(word2vec_model_path!=''): ## if model path is given then load the existing model
#      22             print("##### loading word2vec model #####")
# ---> 23             self.model = KeyedVectors.load_word2vec_format(self.word2vec_model_path, binary=False)
#      24
#      25
#
# ~/tensorflow/lib/python3.6/site-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#     193
#     194         logger.info("loading projection weights from %s", fname)
# --> 195         with utils.smart_open(fname) as fin:
#     196             header = utils.to_unicode(fin.readline(), encoding=encoding)
#     197             vocab_size, vector_size = (int(x) for x in header.split())  # throws for invalid file format
#
# ~/tensorflow/lib/python3.6/site-packages/smart_open/smart_open_lib.py in smart_open(uri, mode, **kw)
#     174             encoding = kw.pop('encoding', None)
#     175             errors = kw.pop('errors', DEFAULT_ERRORS)
# --> 176             return file_smart_open(parsed_uri.uri_path, mode, encoding=encoding, errors=errors)
#     177         elif parsed_uri.scheme in ("s3", "s3n", 's3u'):
#     178             return s3_open_uri(parsed_uri, mode, **kw)
#
# ~/tensorflow/lib/python3.6/site-packages/smart_open/smart_open_lib.py in file_smart_open(fname, mode, encoding, errors)
#     669     except KeyError:
#     670         raw_mode = mode
# --> 671     raw_fobj = open(fname, raw_mode)
#     672     decompressed_fobj = compression_wrapper(raw_fobj, fname, raw_mode)
#     673     decoded_fobj = encoding_wrapper(decompressed_fobj, mode, encoding=encoding, errors=errors)
#
# FileNotFoundError: [Errno 2] No such file or directory: './Data/wiki.en.vec'

# %%
########## load Word2Vec model ##########
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = graph_def
    #strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

def weight_variable(shape, w=0.1):
    initial = tf.truncated_normal(shape, stddev=w) #Outputs random values from a truncated normal distribution.
    return tf.Variable(initial)

def bias_variable(shape, w=0.1):
    initial = tf.constant(w, shape=shape)
    return tf.Variable(initial)

def devise_model(features, labels, mode):
    # Input Layer
    # input layer shape should be [batch_size, image_width, image_height, channels] for conv2d
    # set batch_size = -1 means batch_size = the number of input
    print('input data shape: ', features)
    input_layer = tf.reshape(features, [-1, 32, 32, 3])
    print('input layer shape: ', input_layer.shape)
    
    ########## Core Visual Model ##########
    # conv1
    with tf.variable_scope('conv1') as scope:
        kernel = weight_variable(shape=[5, 5, 3, 64]) #shape=[filter_height * filter_width * in_channels, output_channels]
        conv = tf.nn.conv2d(input_layer, kernel, [1, 1, 1, 1], padding='SAME')
        biases = bias_variable(shape=[64], w=0.0)
        pre_activation = tf.nn.bias_add(conv, biases)
        conv1 = tf.nn.relu(pre_activation, name=scope.name)
       
    # pool1
    pool1 = tf.nn.max_pool(conv1, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='SAME')
    # norm1
    norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name='norm1')
    # conv2
    with tf.variable_scope('conv2') as scope:
        kernel = weight_variable(shape=[5, 5, 64, 64])
        conv = tf.nn.conv2d(norm1, kernel, [1, 1, 1, 1], padding='SAME')
        biases = bias_variable(shape=[64], w=0.1)
        pre_activation = tf.nn.bias_add(conv, biases)
        conv2 = tf.nn.relu(pre_activation, name=scope.name)
    # pool2    
    pool2 = tf.nn.max_pool(conv2, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='SAME', name='pool2')
    # norm2
    norm2 = tf.nn.lrn(pool2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name='norm2')
    
    pool2_flat = tf.reshape(norm2, [-1, 8*8*64])
    dense1 = tf.layers.dense(
        inputs=pool2_flat,
        units=1024, # number of neurons in the dense layer
        activation=tf.nn.relu,
        name='dense1')
    dropout1 = tf.layers.dropout(
        inputs=dense1,
        rate=0.1,
        training= mode=='TRAIN',
        name='dropout1')
    dense2 = tf.layers.dense(
        inputs=dropout1,
        units=512, # number of neurons in the dense layer
        activation=tf.nn.relu,
        name='dense2')
    dropout2 = tf.layers.dropout(
        inputs=dense2,
        rate=0.1,
        training= mode=='TRAIN',
        name='dropout2')
    ########## Core Visual Model ##########
    
    ########## Transformation ##########
    visual_embeddings = tf.layers.dense(inputs=dropout2, units=TEXT_EMBEDDING_SIZE, name='transform')
    tf.summary.histogram('visual_embeddings', visual_embeddings)
    ########## Transformation ##########
    
    return visual_embeddings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-83cf717e81bc> in <module>()
# ----> 1 import tensorflow as tf
#       2 import numpy as np
#       3 import os
#       4 import get_data
#       5 from Word2Vec import Word2Vec_Model
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
def train(X_train, y_fine_train, y_coarse_train, X_validate, y_fine_validate, y_coarse_validate
                        , train_op, EPOCH_BOUND, EARLY_STOP_CHECK_EPOCH, BATCH_SIZE, testing=True):

    global saver, loss
    global writer, merged
    
    early_stop = 0
    best_loss = np.infty
    
    for epoch in range(epoch_bound):

        # randomize training set
        indices_training = np.random.permutation(X_train.shape[0])
        X_train, y_train = X_train[indices_training,:], y_train[indices_training,:]

        # split training set into multiple mini-batches and start training        
        total_batches = int(X_train.shape[0] / batch_size)
        for batch in range(total_batches):
            if batch == total_batches - 1:
                sess.run(train_op, feed_dict={x: X_train[batch*batch_size:], 
                                               y1: y_coarse_train[batch*batch_size:],
                                               y2: y_fine_train[batch*batch_size:], 
                                               mode:'TRAIN'})
                summary = sess.run(merged, feed_dict={x: X_train[batch*batch_size:],
                                                      y1: y_coarse_train[batch*batch_size:],
                                                      y2: y_fine_train[batch*batch_size:],
                                                      mode:'TRAIN'})
                writer.add_summary(summary, epoch + (batch/total_batches))


            else:
                sess.run(train_op, feed_dict={x: X_train[batch*batch_size : (batch+1)*batch_size], 
                                               y1: y_coarse_train[batch*batch_size : (batch+1)*batch_size],
                                               y2: y_fine_train[batch*batch_size : (batch+1)*batch_size],
                                               mode:'TRAIN'})
                summary = sess.run(merged, feed_dict={x: X_train[batch*batch_size : (batch+1)*batch_size],
                                                      y1: y_coarse_train[batch*batch_size : (batch+1)*batch_size],
                                                      y2: y_fine_train[batch*batch_size : (batch+1)*batch_size],
                                                      mode:'TRAIN'})
                writer.add_summary(summary, epoch + (batch/total_batches))

        # split validation set into multiple mini-batches and start validating
        cur_loss = 0.0
        total_batches = int(X_validate.shape[0] / batch_size)
        for batch in range(total_batches):
            
            if batch == total_batches - 1:
                cur_loss += sess.run(loss, feed_dict={x:X_validate[batch*batch_size:],
                                                      y1:y_coarse_validate[batch*batch_size:],
                                                      y2:y_fine_validate[batch*batch_size:],
                                                     mode:'EVAL'})
            else:
                cur_loss += sess.run(loss, feed_dict={x:X_validate[batch*batch_size : (batch+1)*batch_size],
                                                      y1:y_coarse_validate[batch*batch_size : (batch+1)*batch_size],
                                                      y2:y_fine_validate[batch*batch_size : (batch+1)*batch_size],
                                                     mode:'EVAL'})
        cur_loss /= total_batches
        
        # #test for prediction
        # prediction = sess.run(predictions, feed_dict={x:X_validate, y:y_validate, mode:'EVAL'})
        # print('Predic nearest neighbor: ', prediction['nearest_neighbors'])
        
        # If the loss does not decrease for many times, it will early stop epochs-loop 
        if best_loss > cur_loss:
            early_stop = 0
            best_loss = cur_loss
            # save best model in testing phase
            if testing == True:
                save_path = saver.save(sess, STORED_PATH)
        else:
            early_stop += 1
        print('\tEpoch: ', epoch, '\tBest loss: ', best_loss, '\tCurrent loss: ', cur_loss)
        if early_stop == stop_threshold:
            break

    return best_loss

def unpickle(file):
        import pickle
        with open(file, 'rb') as fo:
            dict = pickle.load(fo, encoding='bytes')
            return dict # return dic keys: [b'filenames', b'batch_label', b'fine_labels', b'coarse_labels', b'data']
        
def labels_2_embeddings(labels_idx, ref):
    """ Get text embeddings of labels from Text embedding lookup table
        label(i) = ref[labels_idx[i]]
    Argument: 
        labels_idx : a list of indices that should refers to ref
        ref: a list of labels
    Return:
        labels_embeddings: a list of text embeddings
    """
    global TextEmbeddings, TEXT_EMBEDDING_SIZE
    
    labels_embeddings = []
    for i in labels:
        labels_embeddings.append(TextEmbeddings.text_embedding_lookup(TEXT_EMBEDDING_SIZE, ref[i]))
    labels_embeddings = np.array(labels_embeddings, dtype=np.float32)
    
    return labels_embeddings

# %%
########## Data ##########
# Data format:
# data -- a 10000x3072 numpy array of uint8s. 
#         Each row of the array stores a 32x32 colour image. 
#         The first 1024 entries contain the red channel values, 
#         the next 1024 the green, and the final 1024 the blue. 
#         The image is stored in row-major order, so that the first 32 entries of the array are the red channel values of the first row of the image.
# labels -- a list of 10000 numbers in the range 0-99. The number at index i indicates the label of the ith image in the array data.

# Load training and testing data
(train_data, y_train_fine_labels, y_train_coarse_labels), (eval_data, y_eval_fine_labels, y_eval_coarse_labels) = get_data.load_data(label_mode='both',path='./Data/cifar-100/')
train_data = train_data.reshape(train_data.shape[0], 32*32*3)
eval_data = eval_data.reshape(eval_data.shape[0], 32*32*3)

# normalize inputs from 0-255 to 0.0-1.0
train_data = train_data / 255.0
eval_data = eval_data / 255.0

# 100 labels of cifar-100
# cifar-100 class list
# fine_labels: 100 labels of classes
# coarse_labels: 20 labels of super classes
classes = unpickle('./Data/cifar-100/meta')
FINE_CLASSES = np.asarray(classes[b'fine_label_names'], dtype=np.dtype(np.str))
COARSE_CLASSES = np.asarray(classes[b'coarse_label_names'], dtype=np.dtype(np.str))

train_fine_labels_embeddings = labels_2_embeddings(y_train_fine_labels, FINE_CLASSES)
train_coarse_labels_embeddings = labels_2_embeddings(y_train_coarse_labels, COARSE_CLASSES)

eval_fine_labels_embeddings = labels_2_embeddings(y_eval_fine_labels, FINE_CLASSES)
eval_coarse_labels_embeddings = labels_2_embeddings(y_eval_coarse_labels, COARSE_CLASSES)

fine_classes_text_embedding = TextEmbeddings.get_classes_text_embedding(TEXT_EMBEDDING_SIZE, FINE_CLASSES)
coarse_classes_text_embedding = TextEmbeddings.get_classes_text_embedding(TEXT_EMBEDDING_SIZE, COARSE_CLASSES)

print('Train Data shape: ',train_data.shape)
print('Train Fine Label shape: ', y_train_fine_labels.shape)
print('Train Coarse Label shape:', y_train_coarse_labels.shape)
########## Data ##########
# Out:
# Train Data shape:  (50000, 3072)
# Train Label shape:  (50000,)

# %%
########## devise classifier ##########
# x = tf.placeholder(tf.float32, [None, train_data.shape[1]], name='x')

# mode = tf.placeholder(tf.string, name='mode')

# visual_embeddings = devise_model(x, y, mode)

reset_graph()
# Transfer layers
pretrained_model_path = "./saved_model/cifar-100"
# Get graph from pretrained visual model
pretrained_saver = tf.train.import_meta_graph(pretrained_model_path + ".ckpt.meta")
# Get variables of cifar-100 cnn model
x = tf.get_default_graph().get_tensor_by_name("x:0")
mode = tf.get_default_graph().get_tensor_by_name("mode:0")
cnn_output = tf.get_default_graph().get_tensor_by_name("dropout2/Identity:0")

# Define new input label placeholder: y1 for super class labels, y2 for fine class labels
y1 = tf.placeholder(tf.float32, [None, train_coarse_labels_embeddings.shape[1]], name='y1')
y2 = tf.placeholder(tf.float32, [None, train_fine_labels_embeddings.shape[1]], name='y2')

tf.summary.histogram('cnn_output', cnn_output)

# attach transform layer
with tf.name_scope('transform'):
    visual_embeddings = tf.layers.dense(inputs=cnn_output, units=TEXT_EMBEDDING_SIZE, name='transform')
    tf.summary.histogram('visual_embeddings', visual_embeddings)

# get training parameter in transform layer for training operation
training_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="transform")

# Calculate Loss (for both TRAIN and EVAL modes)
## Origine DeViSE defined hinge rank loss
# with tf.name_scope('devise_loss'):
#     loss = tf.constant(0.0)
#     predic_true_distance = tf.reduce_sum(tf.multiply(y, visual_embeddings), axis=1, keep_dims=True)
#     for j in range(len(classes_text_embedding)):
#         loss = tf.add(loss, tf.maximum(0.0, (MARGIN - predic_true_distance 
#                                     + tf.reduce_sum(tf.multiply(classes_text_embedding[j], visual_embeddings),axis=1, keep_dims=True))))
#     loss = tf.subtract(loss, MARGIN)
#     loss = tf.reduce_sum(loss)
#     loss = tf.div(loss, BATCH_SIZE)
#     tf.summary.scalar('loss', loss)

## New loss: Hierachicical hinge rank loss
with tf.name_scope('devise_loss'):
    loss = tf.constant(0.0)
    
    ### (H1) Coarse labels hinge rank loss
    predic_true_distance = tf.reduce_sum(tf.multiply(y1, visual_embeddings), axis=1, keep_dims=True)
    for j in range(len(coarse_classes_text_embedding)):
        loss = tf.add(loss, tf.maximum(0.0, (MARGIN - predic_true_distance 
                                    + tf.reduce_sum(tf.multiply(coarse_classes_text_embedding[j], visual_embeddings),axis=1, keep_dims=True))))
    h1_loss = tf.subtract(loss, MARGIN)
    h1_loss = tf.reduce_sum(loss)
    h1_loss = tf.div(loss, BATCH_SIZE)
    
    ### (H2) Fine labels hinge rank loss
    predic_true_distance = tf.reduce_sum(tf.multiply(y2, visual_embeddings), axis=1, keep_dims=True)
    for j in range(len(fine_classes_text_embedding)):
        loss = tf.add(loss, tf.maximum(0.0, (MARGIN - predic_true_distance 
                                    + tf.reduce_sum(tf.multiply(fine_classes_text_embedding[j], visual_embeddings),axis=1, keep_dims=True))))
    h2_loss = tf.subtract(loss, MARGIN)
    h2_loss = tf.reduce_sum(loss)
    h2_loss = tf.div(loss, BATCH_SIZE)
    
    ### loss = alpha*H1 + beta*H2
    loss = 0.5*alpha + 0.5*beta
    
    tf.summary.scalar('loss', loss)
    
print("loss defined")

# Define optimizer and Training iteration (for TRAIN)
## Decaying learning rate exponentially based on the total training step
decay_steps = int(BATCH_SIZE * EPOCH_PER_DECAY) # Define decay steps
global_step = tf.train.get_or_create_global_step()

learning_rate = tf.train.exponential_decay(
        learning_rate=0.01, #initial learning rate
        global_step=global_step,
        decay_steps=decay_steps,
        decay_rate=0.96,
        staircase=True,
        name='ExponentialDecayLearningRate'
    )
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate, name='GD_Optimizer')
train_op = optimizer.minimize(loss, name='train_op')
## exponential moving average
ema = tf.train.ExponentialMovingAverage(decay=0.9999)

with tf.control_dependencies([train_op]):
      train_op = ema.apply(tf.trainable_variables()) # apply exponential moving average to training operation

########## devise classifier ##########
# Out:
# loss defined

# %%
########## Train ##########
print("########## Start training ##########")
sess = tf.Session()
init = tf.global_variables_initializer()
# init saver to save model
saver = tf.train.Saver()
# visualize data
merged = tf.summary.merge_all()
writer = tf.summary.FileWriter("logs/", sess.graph)

# init weights
sess.run(init)
# restore value from pretrained model
pretrained_saver.restore = (sess, pretrained_model_path + ".ckpt")
for var in training_vars:
    sess.run(var.initializer)
    
# randomize dataset
indices = np.random.permutation(train_data.shape[0])
Inputs = np.array(train_data[indices,:])
Fine_Labels = np.array(train_fine_labels_embeddings[indices,:])
Coarse_Labels = np.array(train_coarse_labels_embeddings[indices,:])

# get validation set with the size of a batch for early-stop
X_train, y_fine_train, y_coarse_train = Inputs[VALIDATION_SIZE:], Fine_Labels[VALIDATION_SIZE:], Coarse_Labels[VALIDATION_SIZE:]
X_validate, y_fine_validate, y_coarse_validate = Inputs[:VALIDATION_SIZE], Fine_Labels[:VALIDATION_SIZE], Coarse_Labels[:VALIDATION_SIZE]

print('X_train[0]: ', X_train[0])

# start training with all the inputs
best_loss = train(X_train, y_fine_train, y_coarse_train, X_validate, y_fine_validate, y_coarse_validate
                        , train_op, EPOCH_BOUND, EARLY_STOP_CHECK_EPOCH, BATCH_SIZE, testing=True)
print("training with all the inputs, loss:", best_loss)

sess.close()
########## Train ##########

# %%
########## Evaluate ##########
# Evaluate the model and print results
print("########## Start evaluating ##########")
sess = tf.Session()
# restore the precious best model
saver = tf.train.Saver()
saver.restore(sess, STORED_PATH)

hit = 0
for i in range(10):
    predict_embeddings = sess.run(visual_embeddings, feed_dict={x:eval_data[i*1000:(i+1)*1000], y1:eval_coarse_labels_embeddings[i*1000:(i+1)*1000], y2:eval_fine_labels_embeddings[i*1000:(i+1)*1000], mode:'EVAL'})
    predict_batch_labels = TextEmbeddings.get_nearest_neighbor_labels(predict_embeddings)
    print('Predic nearest neighbor: ')
    for idx, predict_labels in enumerate(predict_batch_labels):
        long_true_label = FINE_CLASSES[eval_labels[idx]] # refer to class labels
        print('Predict top 5 labels:', predict_labels, 'True lable:', long_true_label)
        
        # consider a class name is concated by multiple labels (ex., maple_tree)
        true_labels = long_true_label.split('_')
        for true in true_labels:
            if(true in predict_labels):
                hit+=1
                print("HIT!")

print("Test result: Top 5 hit rate", hit/100, "%")

#print('Test accuracy: ', testing_accuracy/5)
sess.close()
######### Evaluate ##########
# Out:
# ########## Start evaluating ##########
# INFO:tensorflow:Restoring parameters from ./devise_model/devise.ckpt
# Predic nearest neighbor:
# Predict top 5 labels: ['belayer' 'frrom' 'abtan' 'bilge' 'fileh'] True lable: mountain
# Predict top 5 labels: ['dhog' 'mongoose' 'mongooses' 'gopher' 'sandhogs'] True lable: forest
# Predict top 5 labels: ['suweid' 'reeds' 'suweidi' 'ammun' 'chebbites'] True lable: seal
# Predict top 5 labels: ['frrom' 'กา' 'snorkels' 'iouf' 'scbas'] True lable: mushroom
# Predict top 5 labels: ['livan' 'ilyon' 'chian' 'candarid' 'trilyon'] True lable: sea
# Predict top 5 labels: ['poult' 'mongooses' 'mongoose' 'erminois' 'lion'] True lable: tulip
# Predict top 5 labels: ['allocators' 'urops' 'mongoose' 'ϣ' 'pagie'] True lable: camel
# Predict top 5 labels: ['fossors' 'shrews' 'lagus' 'delegs' 'sandhogs'] True lable: butterfly
# Predict top 5 labels: ['visim' 'shores,' 'telmap' 'filefoo' 'rmap'] True lable: cloud
# Predict top 5 labels: ['negib' 'cretors' 'zunuzi' 'pèp' 'پے'] True lable: apple
# Predict top 5 labels: ['kundun' 'kanun' 'tubah' 'fidil' 'inik'] True lable: sea
# Predict top 5 labels: ['wipey' 'permittee' 'pocketed' 'sphr' 'advice,'] True lable: skunk
# Predict top 5 labels: ['sandlas' 'lumbered' 'hauling' 'ammun' 'wagons,'] True lable: streetcar
# Predict top 5 labels: ['fladday' 'palmahim' 'davidof' 'coastline' 'cliffs'] True lable: rocket
# Predict top 5 labels: ['cups' 'chairman,' 'napkin' 'napkins' 'tongs'] True lable: lamp
# Predict top 5 labels: ['thumble' 'table/file' 'srid' 'unpins' 'erminois'] True lable: lion
# Predict top 5 labels: ['çârgâh' 'yegâh' 'mees' 'ostim' 'embonate'] True lable: tulip
# Predict top 5 labels: ['gophone' 'chairman/managing' 'chairman,' 'indin' 'chairman/manager'] True lable: wolf
# Predict top 5 labels: ['livan' 'tonnie' 'ryst' 'tonnis' 'annouk'] True lable: rose
# Predict top 5 labels: ['millet' 'azurine' 'pansy' '們' 'osmet'] True lable: orange
# Predict top 5 labels: ['tyan' 'rosy' 'pcga' '完' 'drose'] True lable: rose
# Predict top 5 labels: ['hikin' 'ãn' 'kanun' 'padday' 'emrin'] True lable: mountain
# Predict top 5 labels: ['mafew' '逃' 'band…' 'aphone' 'abendan'] True lable: skunk
# Predict top 5 labels: ['dunes' 'traversing' 'seawalls' 'reeds' 'seashore'] True lable: dinosaur
# Predict top 5 labels: ['corruptible' '⑆' 'mediaries' 'nyamsus' 'mediary'] True lable: chimpanzee
# Predict top 5 labels: ['dictation' '罗' 'subserviency' 'dictations' 'subservient'] True lable: can
# Predict top 5 labels: ['concessionaire' 'helpan' 'lpr' 'recli' 'metrobús'] True lable: keyboard
# Predict top 5 labels: ['εχ' 'frrom' 'compax' 'delegs' 'toepads'] True lable: bicycle
# Predict top 5 labels: ['benevolently' 'senā' 'plural' 'foorth' 'pyek'] True lable: bicycle
# Predict top 5 labels: ['¬ψ' '价' 'psgb' 'eygpt' 'napkins'] True lable: rose
# Predict top 5 labels: ['panlop' 'chairman,' 'chairmans' 'delegs' 'acarid'] True lable: chair
# Predict top 5 labels: ['>not' 'atiek' 'zoy' 'mayeb' 'tiek'] True lable: plate
# Predict top 5 labels: ['stook' 'mower' 'fifes' 'delegs' 'armers'] True lable: lawn_mower
# HIT!
# Predict top 5 labels: ['sagih' 'ãn' 'tubis' 'oilfish' 'xpec'] True lable: turtle
# Predict top 5 labels: ['masticating' 'raspin' 'gopher' 'huddling' 'gopherus'] True lable: palm_tree
# Predict top 5 labels: ['reeds' 'burrow' 'mud' 'ɖo' 'sidth'] True lable: shark
# Predict top 5 labels: ['spryman' 'panlop' 'loumi' 'phtk' 'ezoe'] True lable: pickup_truck
# Predict top 5 labels: ['法家' 'theethose' 'poosy' 'thouk' 'bosom'] True lable: boy
# Predict top 5 labels: ['foung' 'hting' 'scye' 'chinstraps' '蒸'] True lable: couch
# Predict top 5 labels: ['ammun' 'raftsmen' 'lumbered' '}ø' 'wagons,'] True lable: house
# Predict top 5 labels: ['urops' 'pigdog' 'mongooses' 'mongoose' 'badger'] True lable: porcupine
# Predict top 5 labels: ['eididh' 'diaspar' 'bearers' 'delegs' 'descedent'] True lable: cockroach
# Predict top 5 labels: ['o̱' 'hikin' 'hajlah' 'istak' 'ksur'] True lable: mountain
# Predict top 5 labels: ['ikil' 'istak' 'davidof' 'coastline' 'hamikdosh'] True lable: shark
# Predict top 5 labels: ['cuppers' 'indin' 'chairmanships' 'handcart' 'dipicting'] True lable: palm_tree
# Predict top 5 labels: ['>not' 'mitap' '恩州' 'miic' 'nо'] True lable: clock
# Predict top 5 labels: ['apbpa' 'reclarify' 'parfew' 'enotif' 'gous'] True lable: lawn_mower
# Predict top 5 labels: ['‘servant' 'sosy' 'chits' 'plural' 'toep'] True lable: pickup_truck
# Predict top 5 labels: ['lymen' 'desposit' 'janky' 'biram' 'opiah'] True lable: skunk
# Predict top 5 labels: ['alifs' 'isön' 'ammun' 'lanun' 'danun'] True lable: castle
# Predict top 5 labels: ['沓' 'kratek' 'nysid' 'okoy' 'mermen'] True lable: beaver
# Predict top 5 labels: ['farava' 'lmlk' 'toothpick' 'seal' 'delegs'] True lable: bee
# Predict top 5 labels: ['dpep' 'nutriments' 'žabkar' 'delegs' 'nonfood'] True lable: bottle
# Predict top 5 labels: ['selfishly' 'kpers' 'ipin' 'boafish' 'reptin'] True lable: pear
# Predict top 5 labels: ['refeer' '‘consent' 'cud' 'pyet' 'advice,'] True lable: baby
# Predict top 5 labels: ['>not' 'ibin' 'kanun' '菅原' 'debter'] True lable: flatfish
# Predict top 5 labels: ['coastlines' '糾' 'shorelines' 'coastline' 'shores'] True lable: sea
# Predict top 5 labels: ['muttonwood' 'ammun' 'lumbered' 'tree' 'vedars'] True lable: oak_tree
# HIT!
# Predict top 5 labels: ['々' '>not' 'xyrem' 'amercan' 'zian'] True lable: leopard
# Predict top 5 labels: ['chemrey' 'ikil' 'reshare' 'frrom' 'emret'] True lable: rocket
# Predict top 5 labels: ['offspin' 'frrom' 'kopt' 'ungaziq' 'emrin'] True lable: snail
# Predict top 5 labels: ['pouch' 'zoy' 'srid' 'emerald' 'goosy'] True lable: crocodile
# Predict top 5 labels: ['lucking' 'phalangers' 'toothpick' 'fifer' 'armers'] True lable: camel
# Predict top 5 labels: ['thumble' 'urops' 'thumbless' 'poosy' 'mongoose'] True lable: rabbit
# Predict top 5 labels: ['sosy' '唐人' 'kloeu' 'laband' '明天'] True lable: beetle
# Predict top 5 labels: ['servier' 'sosy' '麻衣子' 'eerd' 'toep'] True lable: girl
# Predict top 5 labels: ['bisushield' 'pouch' 'ϣ' 'ayeb' 'pyet'] True lable: lion
# Predict top 5 labels: ['¬ψ' 'discomfiture' 'usurping' 'chewers' 'delegs'] True lable: sunflower
# Predict top 5 labels: ['#player' 'mongoose' 'gopher' 'pouch' 'keur'] True lable: porcupine
# Predict top 5 labels: ['millet' 'poorters' 'pansy' 'osmet' 'foorth'] True lable: tulip
# Predict top 5 labels: ['kanun' 'frrom' 'aidil' 'saraph' 'tjan'] True lable: raccoon
# Predict top 5 labels: ['thag' 'poosy' 'ammun' 'hayin' 'dammun'] True lable: train
# Predict top 5 labels: ['kanun' 'emrin' 'mayeb' 'ayeb' 'એ'] True lable: ray
# Predict top 5 labels: ['#fishwater' 'fish' 'aquafish' 'manfish' 'bongfish'] True lable: trout
# Predict top 5 labels: ['nevit' '#yet' 'ayeb' 'emret' 'erel'] True lable: flatfish
# Predict top 5 labels: ['proppen' 'ammun' 'propped' 'ড়' '蒸'] True lable: flatfish
# Predict top 5 labels: ['millet' 'natfruit' 'pansy' 'artichoke' 'millets'] True lable: sunflower
# Predict top 5 labels: ['luncheons' 'curriers' 'hting' 'cpgs' '蒸'] True lable: bowl
# Predict top 5 labels: ['zoy' 'keptin' 'osmet' 'sosy' 'gastrol'] True lable: snail
# Predict top 5 labels: ['alide' 'pouch' 'lustre' 'scleraxis' 'reish'] True lable: clock
# Predict top 5 labels: ['coastland' 'shorelines' 'coastline' 'coastlines' 'seafloors'] True lable: sea
# Predict top 5 labels: ['munid' 'pouch' 'raspin' 'parid' 'teat'] True lable: snake
# Predict top 5 labels: ['safian' 'restak' 'maystor' 'ayeb' 'fileh'] True lable: orchid
# Predict top 5 labels: ['chits' 'badger' 'shrews' 'mongoose' 'mongooses'] True lable: bee
# Predict top 5 labels: ['peyek' 'oilfish' 'wotif' 'xeye' 'zunafish'] True lable: dinosaur
# Predict top 5 labels: ['granaries' 'ᐄ' 'ammun' 'solankis' 'taluqdars'] True lable: tractor
# Predict top 5 labels: ['restak' 'frrom' 'darm' 'chair/' 'oiip'] True lable: snake
# Predict top 5 labels: ['lumbered' 'ammun' 'keval' '__i' 'lumberer'] True lable: forest
# Predict top 5 labels: ['dmed' 'chairman,' 'chewers' 'chairmans' 'toep'] True lable: boy
# Predict top 5 labels: ['offshore' 'oceanflow' 'davidof' 'coastline' 'shores'] True lable: ray
# Predict top 5 labels: ['rd/e' 'kadeshi' '西村' 'nd/cd' 'efiks'] True lable: clock
# Predict top 5 labels: ['refeer' 'bisushield' '々' 'amercan' 'એ'] True lable: caterpillar
# Predict top 5 labels: ['noning' 'lumberers' 'burrows' 'reeds' 'seal'] True lable: crocodile
# Predict top 5 labels: ['senary' 'biograafiline' 'ostim' 'xyrem' 'mediary'] True lable: chimpanzee
# Predict top 5 labels: ['benow' 'my/md' 'karpal' 'sanim' 'demit'] True lable: bus
# Predict top 5 labels: ['urops' 'shrews' 'gophersnake' 'mongooses' 'burrowing'] True lable: chimpanzee
# Predict top 5 labels: ['¬ψ' 'tseshaht' 'dedar' 'eididh' 'raeb'] True lable: mouse
# Predict top 5 labels: ['napkins' 'kneepads' 'offspin' 'napkin' 'delegs'] True lable: skunk
# Predict top 5 labels: ['pahoran' 'himank' 'alakël' 'ammun' 'bedars'] True lable: house
# Predict top 5 labels: ['tzds' 'senā' '‘servant' 'hting' '蒸'] True lable: girl
# Predict top 5 labels: ['narcan' 'brotherband' 'aidil' 'mycogen' 'cpaj'] True lable: crab
# Predict top 5 labels: ['cultivian' 'pansy' 'osmet' 'unsweetened' 'iodize'] True lable: sweet_pepper
# Predict top 5 labels: ['nhow' 'granaries' '蒸' '詞' 'feodal'] True lable: maple_tree
# Predict top 5 labels: ['chairmanship' 'chairmanships' 'chairmans' 'hands' 'prpbably'] True lable: whale
# Predict top 5 labels: ['mpon' 'osmet' '‘servant' '師父' 'ranats'] True lable: lion
# Predict top 5 labels: ['ikil' 'ksur' 'huvafen' 'inik' 'eratosphere'] True lable: rocket
# Predict top 5 labels: ['dilşad' 'symbid' 'ayeb' 'safian' 'girgin'] True lable: skyscraper
# Predict top 5 labels: ['granaries' '亅' 'bedars' 'ammun' 'kammun'] True lable: castle
# Predict top 5 labels: ['pomegranate' 'millets' 'شر' 'almond' 'artichoke'] True lable: pear
# Predict top 5 labels: ['ardvi' 'alifs' 'nehaj' 'adna' 'hvats'] True lable: pine_tree
# Predict top 5 labels: ['irnc' 'frrom' 'scye' 'ऑफ' 'dbngp'] True lable: couch
# Predict top 5 labels: ['chair' 'hands' 'raspin' 'napkin' 'napkins'] True lable: chair
# HIT!
# Predict top 5 labels: ['sagih' 'saraph' 'tubis' 'tubah' 'erel'] True lable: crocodile
# Predict top 5 labels: ['‘left' '們' 'laband' '罗' 'amyint'] True lable: apple
# Predict top 5 labels: ['teat' 'ϣ' 'pyet' 'napkins' 'w–z'] True lable: bottle
# Predict top 5 labels: ['seawalls' 'seaward' 'saltpans' 'landward' 'setnence'] True lable: sea
# Predict top 5 labels: ['chairs' 'chairmanship' 'frrom' 'mouthpiece' 'delegs'] True lable: bicycle
# Predict top 5 labels: ['owm' 'hting' 'zoy' '師父' 'pyet'] True lable: lion
# Predict top 5 labels: ['dmed' '們' 'sosy' 'pints' 'chye'] True lable: pear
# Predict top 5 labels: ['thidar' 'manidar' 'toothpick' 'armers' '陳立夫'] True lable: palm_tree
# Predict top 5 labels: ['ammun' 'farmsteads' 'lumbered' 'raftsmen' 'sketraw'] True lable: tank
# Predict top 5 labels: ['mindin' 'chairman,' 'indin' 'sosis' 'ayeb'] True lable: bowl
# Predict top 5 labels: ['kepas' 'กา' 'akbash' 'wotif' 'cebid'] True lable: cattle
# Predict top 5 labels: ['livan' 'medicure' 'sosy' '何晏' 'cultivian'] True lable: tulip
# Predict top 5 labels: ['forest' 'tea' 'paan' 'degrow' 'fructify'] True lable: forest
# HIT!
# Predict top 5 labels: ['ὅς' 'mindin' '唐人' 'indin' 'langoustine'] True lable: chair
# Predict top 5 labels: ['toothpick' 'nysid' 'mūþ' 'delegs' 'toothpicks'] True lable: chimpanzee
# Predict top 5 labels: ['kaadan' 'kvb' 'dhog' '菅原' 'sandhogs'] True lable: mouse
# Predict top 5 labels: ['法家' '何晏' 'oyster' 'maem' 'mah'] True lable: rose
# Predict top 5 labels: ['eygpt' 'memin' 'brotherband' 'wotif' 'aidil'] True lable: man
# Predict top 5 labels: ['沓' 'cuppers' '价' 'psgb' 'dipicting'] True lable: boy
# Predict top 5 labels: ['napkin' 'chewers' 'chewer' 'napkins' 'delegs'] True lable: can
# Predict top 5 labels: ['laman' 'toothpick' 'porm' 'archbar' 'vyre'] True lable: aquarium_fish
# Predict top 5 labels: ['a—for' 'soundhog' 'gophone' '菅原' 'nd/cd'] True lable: shrew
# Predict top 5 labels: ['nondomestic' 'man/men' 'razal' 'ranats' 'uggug'] True lable: forest
# Predict top 5 labels: ['___i' 'curried' '>occasion' '#eating' 'rp^'] True lable: trout
# Predict top 5 labels: ['marshy' 'ammun' 'landward' 'ivats' 'setnence'] True lable: plain
# Predict top 5 labels: ['aidil' 'กา' 'gophone' 'wotif' 'nо'] True lable: possum
# Predict top 5 labels: ['arving' 'lumber' 'lumbered' 'dhavle' 'tree'] True lable: oak_tree
# HIT!
# Predict top 5 labels: ['sedim' 'voon' 'oceanflow' 'hiuch' 'danun'] True lable: cloud
# Predict top 5 labels: ['kloeu' 'urops' 'dozy' 'table/file' 'gébé'] True lable: beaver
# Predict top 5 labels: ['hand/foot' 'kratek' 'recli' 'delegs' 'vondran'] True lable: boy
# Predict top 5 labels: ['parsetree' 'lumbered' 'tree' 'vedars' 'unrooted'] True lable: oak_tree
# HIT!
# Predict top 5 labels: ['reeds' 'srid' 'ammun' 'delegs' 'setnence'] True lable: house
# Predict top 5 labels: ['berix' 'maspin' 'raspin' 'seal' 'delegs'] True lable: cockroach
# Predict top 5 labels: ['offshores' 'offshore' 'davidof' 'offshorer' 'ship'] True lable: whale
# Predict top 5 labels: ['pgals' '___i' 'interations' 'n\\rfloor' 'rp^'] True lable: couch
# Predict top 5 labels: ['zon' '‘snake' 'seur' 'phalangers' 'boon'] True lable: keyboard
# Predict top 5 labels: ['pouch' 'memin' 'poosy' 'pitapat' 'cepas'] True lable: mushroom
# Predict top 5 labels: ['relates,' 'natrual' 'rd/m' 'nehat' 'padday'] True lable: pickup_truck
# Predict top 5 labels: ['chairmanship' 'chairman,' 'chairmanships' 'delegs' 'chairmans'] True lable: pickup_truck
# Predict top 5 labels: ['fietsers' 'beter' 'frrom' 'remittant' 'abendan'] True lable: snail
# Predict top 5 labels: ['sagih' 'remittant' 'isol' 'fareshare' 'attan'] True lable: caterpillar
# Predict top 5 labels: ['granaries' 'ammuna' 'ammun' 'vedars' 'kammun'] True lable: pine_tree
# Predict top 5 labels: ['lobsters' 'toothpick' 'delegs' 'lobster' 'toothpicks'] True lable: lobster
# HIT!
# Predict top 5 labels: ['poc' 'gophers' 'gopher' 'ψχ' 'sphr'] True lable: raccoon
# Predict top 5 labels: ['匕' 'gangwan' 'nookah' 'dhog' 'sbkri'] True lable: pickup_truck
# Predict top 5 labels: ['chairman,' 'toepads' 'chairmans' 'toep' 'mah'] True lable: chair
# Predict top 5 labels: ['argat' 'ostir' 'edrin' 'delegs' 'dipodids'] True lable: cockroach
# Predict top 5 labels: ['pouch' 'dhog' 'setesh' 'chattergoon' 'thumbling'] True lable: beaver
# Predict top 5 labels: ['frrom' 'ostim' 'kanun' 'emret' 'emrin'] True lable: hamster
# Predict top 5 labels: ['belayer' 'bedars' 'setesh' 'bedar' 'issur'] True lable: bicycle
# Predict top 5 labels: ['yap' 'berix' 'poc' 'vocifer' 'raspin'] True lable: television
# Predict top 5 labels: ['beter' 'ghen' 'tyan' 'zian' 'yegâh'] True lable: bowl
# Predict top 5 labels: ['mmunication' 'dhog' 'gopher' 'communication/interaction' 'ungaziq'] True lable: dolphin
# Predict top 5 labels: ['#preserving' 'agema' 'hereditary' 'officered' '螭魅'] True lable: maple_tree
# Predict top 5 labels: ['glowy' 'hie' 'zian' 'safian' '…wi'] True lable: orchid
# Predict top 5 labels: ['法家' 'sosy' '弘仁' 'paan' 'bidil'] True lable: worm
# Predict top 5 labels: ['poos' 'parfew' 'zoy' 'sosy' 'boon'] True lable: mushroom
# Predict top 5 labels: ['‘hereditary' '罗' 'shefta' 'loumi' 'hereditary'] True lable: sweet_pepper
# Predict top 5 labels: ['indentify' 'berix' 'seal' 'seals' 'sealer'] True lable: bottle
# Predict top 5 labels: ['me‼' '패밀리의' 'sosy' 'dozy' '何晏'] True lable: house
# Predict top 5 labels: ['dhog' 'mongoose' 'urops' 'gopher' 'mongooses'] True lable: beaver
# Predict top 5 labels: ['fuddling' 'prosigns' 'man/men' 'yŏ' 'biram'] True lable: sweet_pepper
# Predict top 5 labels: ['spearfishing' 'snorkels' 'spearfishermen' 'snorkers' 'scuba'] True lable: whale
# Predict top 5 labels: ['‘consent' 'sosy' '‘control' 'plural' 'foorth'] True lable: sweet_pepper
# Predict top 5 labels: ['padday' 'natrual' 'bidil' 'scyl' 'issur'] True lable: flatfish
# Predict top 5 labels: ['offshores' 'offshore' 'submers' 'submersing' 'tsunami'] True lable: shark
# Predict top 5 labels: ['leafflower' 'pansy' 'allomengea' 'herb' 'quackgrass'] True lable: caterpillar
# Predict top 5 labels: ['yegâh' 'reclarify' 'şahap' 'pyet' 'filise'] True lable: lamp
# Predict top 5 labels: ['soundhog' 'dhog' 'gopher' 'seal' 'sandhogs'] True lable: keyboard
# Predict top 5 labels: ['εχ' 'dalaphone' 'fifer' 'delegs' 'aidil'] True lable: possum
# Predict top 5 labels: ['‘hereditary' 'dmed' 'panlop' 'indin' 'chairmanships'] True lable: clock
# Predict top 5 labels: ['seror' 'kepas' 'กา' 'akbash' 'cebid'] True lable: squirrel
# Predict top 5 labels: ['teats' 'huddling' 'thumbling' 'unpins' 'unpin'] True lable: cup
# Predict top 5 labels: ['pouch' 'ϣ' '`did' 'רמי' 'teat'] True lable: cup
# Predict top 5 labels: ['何晏' 'plural' 'zoy' 'sosy' 'dozy'] True lable: lamp
# Predict top 5 labels: ['eididh' 'nehaj' 'seal' 'seals' 'nehat'] True lable: whale
# Predict top 5 labels: ['kloeu' '패밀리의' 'sosy' 'pint' 'dozy'] True lable: woman
# Predict top 5 labels: ['cadian' 'tonnies' 'laband' 'pcga' 'tonnie'] True lable: sweet_pepper
# Predict top 5 labels: ['rtses' 'frrom' 'sbkri' 'wpad' 'dbngp'] True lable: bridge
# Predict top 5 labels: ['dalaphone' 'defecator' 'defecatory' 'delegs' 'paralyzes'] True lable: cockroach
# Predict top 5 labels: ['mafew' 'man/men' 'postmen' 'consocer' '‘smith'] True lable: lobster
# Predict top 5 labels: ['staffs' 'rld' '成龍' 'ghee' 'millets'] True lable: bus
# Predict top 5 labels: ['‘serving' 'legqog' '‘servant' 'officered' 'subalterns'] True lable: wardrobe
# Predict top 5 labels: ['cockroach' 'maspin' 'cockroachs' 'raspin' 'delegs'] True lable: cockroach
# HIT!
# Predict top 5 labels: ['法家' 'vruyr' 'alian' 'suweidan' 'ridvan'] True lable: pickup_truck
# Predict top 5 labels: ['indin' 'urops' 'gopher' 'erald' 'goph'] True lable: porcupine
# Predict top 5 labels: ['dpep' 'agid' 'osmet' 'protargol' 'natricine'] True lable: beetle
# Predict top 5 labels: ['relates,' 'padday' 'offspin' 'raspin' 'nehat'] True lable: television
# Predict top 5 labels: ['pansy' 'osmet' 'chewers' 'poosy' 'queenless'] True lable: bee
# Predict top 5 labels: ['sinked' 'poc' '菅原' 'vocifer' 'padday'] True lable: snake
# Predict top 5 labels: ['nehaj' 'karshes' 'shoresh' 'caves' 'saltpans'] True lable: road
# Predict top 5 labels: ['亅' 'bubiyan' 'barid' 'talut' 'siyag'] True lable: plain
# Predict top 5 labels: ['solitaire' 'pouch' 'laot' 'ayeb' 'paravane'] True lable: bee
# Predict top 5 labels: ['sinked' 'pouch' 'oceanflow' 'emret' 'ocean,'] True lable: cloud
# Predict top 5 labels: ['cpoy' 'bisushield' 'restak' 'raspin' 'frrom'] True lable: lizard
# Predict top 5 labels: ['dhavle' 'lumbered' 'byre' 'vedars' 'keval'] True lable: elephant
# Predict top 5 labels: ['¬ψ' 'holding' '价' 'j♥' 'delegs'] True lable: squirrel
# Predict top 5 labels: ['arving' 'lumbered' 'lumberers' 'lumber' 'dipicting'] True lable: turtle
# Predict top 5 labels: ['istak' 'offshorer' 'offshore' 'davidof' 'spearfishermen'] True lable: shark
# Predict top 5 labels: ['甲骨文' '朋友' 'napkins' 'bosom' 'ay,'] True lable: woman
# Predict top 5 labels: ['alifs' 'cezhug' 'bubiyan' 'lanun' 'danun'] True lable: mountain
# Predict top 5 labels: ['selfishly' 'babas' 'dhog' 'razal' 'mpaj'] True lable: train
# Predict top 5 labels: ['n^n' 'washball' 'pancy' 'thavie' 'table/file'] True lable: wolf
# Predict top 5 labels: ['dhog' 'simpon' 'caterpillar' 'mongooses' 'table/file'] True lable: pine_tree
# Predict top 5 labels: ['plural' 'omtay' 'mg̃á' 'panlop' 'thouk'] True lable: baby
# Predict top 5 labels: ['offshorer' 'offshore' 'reef' 'offshores' '#offshore'] True lable: ray
# Predict top 5 labels: ['adsu' 'stook' 'graphs,' 'boxes' 'toothpicks'] True lable: can
# Predict top 5 labels: ['sandhog' 'dhog' 'legging' 'iañ' 'sandhogs'] True lable: streetcar
# Predict top 5 labels: ['rmd' 'dmsus' 'recli' 'continence' '‘smith'] True lable: wardrobe
# Predict top 5 labels: ['traversing' 'uninhabited' 'islets' 'nehat' 'velidhoo'] True lable: crocodile
# Predict top 5 labels: ['>not' 'bisushield' 'pouch' 'emret' 'pyet'] True lable: skyscraper
# Predict top 5 labels: ['lmen' 'setesh' 'burrows' 'shallus' 'reeds'] True lable: snail
# Predict top 5 labels: ['pcjf' 'kanun' 'ammun' 'frrom' 'routeboxes'] True lable: bridge
# Predict top 5 labels: ['istak' 'enhydros' 'ikil' 'ψχ' 'nehat'] True lable: caterpillar
# Predict top 5 labels: ['onesies' 'msuh' 'qmey' 'shxw' '蒸'] True lable: apple
# Predict top 5 labels: ['burh' 'joisted' 'keval' 'vedars' 'tavle'] True lable: skyscraper
# Predict top 5 labels: ['dhog' 'frrom' 'sbkri' 'sagil' 'edar'] True lable: spider
# Predict top 5 labels: ['sedim' 'ispend' 'apgn' '赵文蓓' 'gemet'] True lable: sea
# Predict top 5 labels: ['seawalls' 'ardvi' 'shore' 'laasqoray' 'shores'] True lable: tractor
# Predict top 5 labels: ['founts' 'osmet' 'chewers' 'pdbid' 'napkins'] True lable: pear
# Predict top 5 labels: ['sawed' 'bedars' 'lumbered' 'ammun' 'planks'] True lable: maple_tree
# Predict top 5 labels: ['cockroach' 'frrom' 'cockroachs' 'hands' 'delegs'] True lable: cockroach
# HIT!
# Predict top 5 labels: ['optocht' 'mayeb' 'wotif' 'ayeb' 'nо'] True lable: rabbit
# Predict top 5 labels: ['﷼' 'tabes' 'bidil' '獠' 'rasiah'] True lable: apple
# Predict top 5 labels: ['cuppers' 'balaphone' 'gopher' 'fifer' 'pndt'] True lable: flatfish
# Predict top 5 labels: ['nagap' 'dmed' 'milk' '們' 'chairmans'] True lable: hamster
# Predict top 5 labels: ['pomegranate' 'millets' 'phytofruit' 'artichoke' 'almond'] True lable: sunflower
# Predict top 5 labels: ['matad' 'dinay' 'table/file' 'setesh' 'seal'] True lable: elephant
# Predict top 5 labels: ['sharm' 'מחזור' 'huvafen' 'davidof' 'emret'] True lable: cloud
# Predict top 5 labels: ['cockroach' 'cockroachs' 'ceran' 'cockroaches' 'delegs'] True lable: cockroach
# HIT!
# Predict top 5 labels: ['nо' 'kpers' '#cure' '張昌儀' 'memin'] True lable: fox
# Predict top 5 labels: ['stook' 'pot,' 'razal' 'noning' '…wi'] True lable: chimpanzee
# Predict top 5 labels: ['refeer' 'dictation' 'chair' 'chairs' 'bedpan'] True lable: boy
# Predict top 5 labels: ['cultivian' 'pansy' 'osmet' 'phytofruit' 'аѕ'] True lable: orange
# Predict top 5 labels: ['loanan' 'ospb' 'dhog' 'meermin' 'sidth'] True lable: squirrel
# Predict top 5 labels: ['sandhog' 'ammun' '江' 'dùil' 'kammun'] True lable: lizard
# Predict top 5 labels: ['ombiasy' 'man/men' 'bwa' 'kratek' 'phemius'] True lable: beaver
# Predict top 5 labels: ['fsync' 'telecomp' 'lifeband' 'keypads' 'slided'] True lable: keyboard
# Predict top 5 labels: ['#player' 'dhog' 'fishl' 'vocifer' 'dbngp'] True lable: trout
# Predict top 5 labels: ['iboxes' 'sideboxes' 'them—for' 'nd/cd' 'n\\in\\z'] True lable: can
# Predict top 5 labels: ['>not' 'süit' 'nevit' 'igil' 'emret'] True lable: hamster
# Predict top 5 labels: ['ostim' 'kanun' 'çârgâh' 'azmim' 'emret'] True lable: road
# Predict top 5 labels: ['urops' 'queenless' 'chewers' 'cursorial' 'acarid'] True lable: mouse
# Predict top 5 labels: ['zoy' 'bisushield' 'pouch' 'ϣ' 'poosy'] True lable: wolf
# Predict top 5 labels: ['belayer' 'osps' 'nehat' 'filefoo' 'traversing'] True lable: pickup_truck
# Predict top 5 labels: ['bedar' 'hting' 'lumbered' 'ammun' 'delegs'] True lable: elephant
# Predict top 5 labels: ['napkins' 'psgb' 'compax' 'sphr' 'chairman,'] True lable: bee
# Predict top 5 labels: ['poosy' 'senary' 'sosy' 'pouch' 'continence'] True lable: leopard
# Predict top 5 labels: ['bisushield' 'pouch' 'mongooses' 'berix' 'mongoose'] True lable: squirrel
# Predict top 5 labels: ['fjeld' 'submers' 'submersing' 'fjeldsted' 'calusas'] True lable: skyscraper
# Predict top 5 labels: ['seawalls' 'ammun' 'sammun' 'seawall' 'kammun'] True lable: tractor
# Predict top 5 labels: ['chemrey' 'bedar' 'reeds' 'seal' 'laman'] True lable: otter
# Predict top 5 labels: ['bidil' 'hoboes' 'kagin' 'handcart' 'bėdų'] True lable: cattle
# Predict top 5 labels: ['serter' 'besutan' 'brotherband' 'zian' '…wi'] True lable: trout
# Predict top 5 labels: ['罗' '竜二' '們' '何晏' '新塘乡'] True lable: rose
# Predict top 5 labels: ['pomegranate' 'unsweetened' 'amaret' 'artichoke' 'thouk'] True lable: aquarium_fish
# Predict top 5 labels: ['‘control' 'chits' 'sosy' 'toep' 'dozy'] True lable: bee
# Predict top 5 labels: ['mazian' 'sedom' 'hamzian' 'beik' 'palian'] True lable: poppy
# Predict top 5 labels: ['istak' 'fipple/duct' 'clerarly' 'fipplet' 'sinked'] True lable: worm
# Predict top 5 labels: ['anglers' 'paspa' 'fish' 'oysters' 'milkfish'] True lable: mushroom
# Predict top 5 labels: ['muttonwood' 'lumbered' 'kammun' 'ammun' 'shweir'] True lable: willow_tree
# Predict top 5 labels: ['reclarify' 'goosy' 'nutritive' 'nonnutritive' 'ड़'] True lable: sweet_pepper
# Predict top 5 labels: ['‘smith' '弘仁' 'indin' 'jāņa' 'mycbp'] True lable: leopard
# Predict top 5 labels: ['jifish' 'peyek' 'mhzc' 'wwan' 'wotif'] True lable: caterpillar
# Predict top 5 labels: ['submersing' 'tenoa' 'submers' 'calusas' 'calusa'] True lable: ray
# Predict top 5 labels: ['secretions' 'pouch' 'urops' 'cups' 'sphr'] True lable: raccoon
# Predict top 5 labels: ['istak' 'ahrid' 'offshore' 'davidof' 'gilf'] True lable: lamp
# Predict top 5 labels: ['postmen' 'piaster' 'laband' 'proxenus' 'rasiah'] True lable: poppy
# Predict top 5 labels: ['chits' 'shufflepuck' 'pong' 'pedites' 'toep'] True lable: snake
# Predict top 5 labels: ['々' '>not' 'infomediary' 'mediaries' 'mediary'] True lable: table
# Predict top 5 labels: ['##chairman' 'mayeb' 'ʤ' 'ayeb' '#chairman'] True lable: cup
# Predict top 5 labels: ['autorized' 'unscrews' 'hting' 'mouthpieces' 'ppsh'] True lable: tractor
# Predict top 5 labels: ['rinit' 'davidof' 'offshore' 'oilfish' 'turtler'] True lable: dolphin
# Predict top 5 labels: ['chinstraps' 'raspin' 'unpins' 'napkins' 'napkin'] True lable: raccoon
# Predict top 5 labels: ['nonfood' 'milk' 'queenless' 'puddling' 'osmet'] True lable: caterpillar
# Predict top 5 labels: ['bedars' 'paan' 'kagin' 'patrilineages' 'patriline'] True lable: kangaroo
# Predict top 5 labels: ['urops' 'ϣ' 'viverrid' 'mongoose' 'mongooses'] True lable: leopard
# Predict top 5 labels: ['mediart' 'plrc' 'ubis' 'chairmans' 'cpaj'] True lable: tulip
# Predict top 5 labels: ['#player' 'pouch' 'dhog' 'gopher' 'mongoose'] True lable: crocodile
# Predict top 5 labels: ['grommets' 'setesh' 'table/file' 'srid' 'napkins'] True lable: boy
# Predict top 5 labels: ['them—for' 'rd/m' 'erickstad' 'hokstad' 'keval'] True lable: telephone
# Predict top 5 labels: ['phalang' 'phalangers' 'urops' 'pouch' 'phalanger'] True lable: lizard
# Predict top 5 labels: ['bentgrass' 'barley' 'dpep' 'barleys' 'agroh'] True lable: willow_tree
# Predict top 5 labels: ['belayer' 'osps' 'frrom' 'sanish' 'nehat'] True lable: bridge
# Predict top 5 labels: ['telecomp' 'earpiece' 'earpieces' 'cordless' 'dictation'] True lable: can
# Predict top 5 labels: ['raspin' 'gophers' 'gopher' 'badger' '#player'] True lable: ray
# Predict top 5 labels: ['granaries' '#$tree' '弘仁' 'balamindin' 'jāņa'] True lable: lion
# Predict top 5 labels: ['noning' 'sagih' 'gambus' 'q+p' 'fifer'] True lable: tractor
# Predict top 5 labels: ['dpep' 'ratels' 'mongoose' 'mongooses' 'shrews'] True lable: willow_tree
# Predict top 5 labels: ['handar' 'ayyyy' 'bascinet' '罔' 'issur'] True lable: bridge
# Predict top 5 labels: ['gripin' 'kanun' 'fishl' 'pyet' 'ungaziq'] True lable: lamp
# Predict top 5 labels: ['goosy' 'poosy' 'arsef' 'salivan' 'zerd'] True lable: beetle
# Predict top 5 labels: ['recompresses' 'winches' 'telecompressor' 'drillship' 'issur'] True lable: telephone
# Predict top 5 labels: ['pigdog' 'mongoose' 'mongooses' 'gopher' 'badger'] True lable: snail
# Predict top 5 labels: ['kundun' 'kendhoo' 'maliku' 'gaddhoo' 'mulah'] True lable: skyscraper
# Predict top 5 labels: ['usurping' 'legqog' 'table/file' 'delegs' '‘smith'] True lable: elephant
# Predict top 5 labels: ['bisushield' 'pouch' 'napkin' 'napkins' 'sponsume'] True lable: caterpillar
# Predict top 5 labels: ['resmar' 'niňaj' 'aidil' 'siptan' '衝動'] True lable: cup
# Predict top 5 labels: ['abendan' 'memin' 'bidil' 'aidil' 'wotif'] True lable: cattle
# Predict top 5 labels: ['millet' 'pansy' 'allotter' 'sunpal' 'ntpa'] True lable: caterpillar
# Predict top 5 labels: ['flicking' 'rubbing' 'tongs' 'napkins' 'tweezers'] True lable: lawn_mower
# Predict top 5 labels: ['patrilines' 'patriline' 'patriliny' 'patrilineages' 'matrilineages'] True lable: leopard
# Predict top 5 labels: ['pouch' 'azmim' 'seal' 'pyet' 'tarid'] True lable: lion
# Predict top 5 labels: ['panlop' '정자' 'pèp' 'پے' 'delegs'] True lable: elephant
# Predict top 5 labels: ['dhog' 'sandhog' 'durrence' 'nehat' 'sandhogs'] True lable: turtle
# Predict top 5 labels: ['refeer' 'gopher' 'dhog' 'indin' 'delegs'] True lable: camel
# Predict top 5 labels: ['¬ψ' 'bisushield' 'faees' 'delegs' 'olizar'] True lable: bowl
# Predict top 5 labels: ['frrom' 'ऑफ' 'ψχ' 'edarm' 'delegs'] True lable: bicycle
# Predict top 5 labels: ['亅' 'ammun' 'riverian' 'lenud' 'samakh'] True lable: house
# Predict top 5 labels: ['bedars' 'ammuna' 'ammun' 'delegs' 'bedar'] True lable: tractor
# Predict top 5 labels: ['riglers' 'bidil' 'anir' 'fidil' 'aidil'] True lable: flatfish
# Predict top 5 labels: ['pinefield' 'tenoa' '糾' 'calusas' 'calusa'] True lable: ray
# Predict top 5 labels: ['isön' 'osps' 'frrom' 'ammun' 'rcping'] True lable: bridge
# Predict top 5 labels: ['dispension' 'pedites' 'mg̃á' 'thouk' 'صغار'] True lable: baby
# Predict top 5 labels: ['kanun' 'abendan' 'riglers' 'aidil' 'üer'] True lable: cattle
# Predict top 5 labels: ['明天' 'aquafish' 'bidil' 'zunafish' 'mhzc'] True lable: trout
# Predict top 5 labels: ['nevit' 'ankhain' 'setesh' 'set,' 'gersem'] True lable: wardrobe
# Predict top 5 labels: ['identify' 'pronating' 'toothpick' 'delegs' 'toothpicks'] True lable: beetle
# Predict top 5 labels: ['wardrooms' 'isön' 'sanish' 'nhow' 'setnence'] True lable: sea
# Predict top 5 labels: ['rasiah' 'kloeu' 'sosy' '唐人' 'dozy'] True lable: hamster
# Predict top 5 labels: ['istak' 'sinked' 'ayyyy' 'istabl' 'fladday'] True lable: plate
# Predict top 5 labels: ['natfruit' '罗' 'hereditary' 'bapn' 'cheesemaking'] True lable: poppy
# Predict top 5 labels: ['dügâh' 'mitap' 'kanun' 'emret' 'chair/'] True lable: bed
# Predict top 5 labels: ['isön' '亅' 'danun' 'עמיר' 'setnence'] True lable: plain
# Predict top 5 labels: ['pinefield' 'boatbay' '糾' 'calusas' 'calusa'] True lable: lobster
# Predict top 5 labels: ['sagih' 'adan' 'dhog' 'dugit' 'ãn'] True lable: trout
# Predict top 5 labels: ['tjan' 'kanun' 'aidil' 'mah' 'wotif'] True lable: fox
# Predict top 5 labels: ['sagih' 'ungan' 'oilfish' 'zian' 'onang'] True lable: whale
# Predict top 5 labels: ['#collapsed' '#collapse' '#collapsing' 'collapsibility' 'setnence'] True lable: bottle
# Predict top 5 labels: ['servier' 'xyrem' 'zian' 'atiek' 'yegâh'] True lable: lamp
# Predict top 5 labels: ['seaward' 'marshy' 'mountainside' 'shores' 'shoreline'] True lable: road
# Predict top 5 labels: ['millet' 'cultivian' 'pansy' 'phytofruit' 'daffodils'] True lable: poppy
# Predict top 5 labels: ['dmed' 'sinked' 'ayyyy' 'chair/' 'acarid'] True lable: worm
# Predict top 5 labels: ['nо' 'razal' 'aidil' 'ʤ' 'djaoeh'] True lable: raccoon
# Predict top 5 labels: ['diptan' 'razal' 'dj`s' 'ellador' 'ampon'] True lable: man
# Predict top 5 labels: ['cockroach' 'crab' 'cockroachs' 'lobster' 'delegs'] True lable: beetle
# Predict top 5 labels: ['natrual' 'طه' 'problem—the' 'fipplet' 'issur'] True lable: bowl
# Predict top 5 labels: ['adsu' 'cuppers' 'chits' 'b^r' 'pndt'] True lable: bowl
# Predict top 5 labels: ['亅' 'kilitbahir' 'ammun' 'talun' 'dammun'] True lable: road
# Predict top 5 labels: ['issaries' 'mongoose' 'mongooses' 'pheas' 'parid'] True lable: fox
# Predict top 5 labels: ['lmen' 'gjendet' 'zian' 'dùil' 'snorkelers'] True lable: house
# Predict top 5 labels: ['bidis' '法家' 'oyster' 'amcar' 'a,dscf'] True lable: pickup_truck
# Predict top 5 labels: ['refeer' 'kanun' 'panlop' 'indin' 'pèp'] True lable: motorcycle
# Predict top 5 labels: ['yegâh' 'refill' 'refills' 'scbas' 'reclarify'] True lable: lamp
# Predict top 5 labels: ['enhydros' 'berix' 'reeds' 'seal' 'burrow'] True lable: willow_tree
# Predict top 5 labels: ['noning' 'sagih' 'ricket' 'reeds' 'bidil'] True lable: butterfly
# Predict top 5 labels: ['##chairman' '﷼' 'indin' 'chairmans' 'rasiah'] True lable: boy
# Predict top 5 labels: ['gopher' 'pouch' 'dhog' 'berix' 'sandhog'] True lable: raccoon
# Predict top 5 labels: ['loanan' 'sagih' 'solitaire' 'pouch' 'tubis'] True lable: possum
# Predict top 5 labels: ['flicking' 'pouch' 'raspin' 'fipplet' 'sinked'] True lable: keyboard
# Predict top 5 labels: ['sammun' 'nammun' 'ammun' 'dammun' 'kammun'] True lable: forest
# Predict top 5 labels: ['mpon' 'srid' 'wardrobe' 'gokhos' 'snorg'] True lable: wardrobe
# HIT!
# Predict top 5 labels: ['eyle' 'erel' 'piters' 'sandhogs' 'thiek'] True lable: porcupine
# Predict top 5 labels: ['sinked' 'ksur' 'ψχ' 'emret' 'fipplet'] True lable: bowl
# Predict top 5 labels: ['thouk' 'kloeu' 'sosy' 'panlop' 'cpk'] True lable: tractor
# Predict top 5 labels: ['dügâh' 'kanun' 'ostim' 'alide' 'mah'] True lable: tulip
# Predict top 5 labels: ['kargs' 'sustenance' 'kulpawn' 'ammun' 'upkeepers'] True lable: train
# Predict top 5 labels: ['indin' 'εχ' 'sosy' 'rasiah' 'aidil'] True lable: rabbit
# Predict top 5 labels: ['bedars' 'kammun' 'ammun' '冯' 'nammun'] True lable: train
# Predict top 5 labels: ['forest' 'paan' 'sandhogs' 'forest,' 'fructify'] True lable: forest
# HIT!
# Predict top 5 labels: ['bisushield' '价' 'faees' 'j♥' 'siptan'] True lable: cup
# Predict top 5 labels: ['pyrantel' 'elephone' 'compax' 'delegs' 'pelephone'] True lable: dinosaur
# Predict top 5 labels: ['ἱερὰ' 'reeds' 'burrow' 'delegs' 'bedsteads'] True lable: television
# Predict top 5 labels: ['napkin' 'sinked' 'slided' 'fipplet' 'flicking'] True lable: telephone
# Predict top 5 labels: ['hoogstrate' 'acarid' 'urops' 'delegs' 'queenless'] True lable: beetle
# Predict top 5 labels: ['e£' '‘left' '−/' 'bèo' 'cpcz'] True lable: apple
# Predict top 5 labels: ['eardly' '‘left' 'accessorise' 'wardrobe' 'accessorial'] True lable: wardrobe
# HIT!
# Predict top 5 labels: ['poult' 'me‼' 'pansy' 'consouling' 'ration'] True lable: boy
# Predict top 5 labels: ['agid' 'owm' 'sosy' 'ranats' 'delegs'] True lable: crab
# Predict top 5 labels: ['明天' 'schap' 'sosy' '麻衣子' 'רמ'] True lable: bee
# Predict top 5 labels: ['kneepads' 'psgb' 'tongs' 'handster' 'prpbably'] True lable: lawn_mower
# Predict top 5 labels: ['lendman' 'setesh' 'munid' 'galidi' 'delegs'] True lable: chimpanzee
# Predict top 5 labels: ['beduiner' 'λat' 'binit' 'isâad' 'set,'] True lable: rocket
# Predict top 5 labels: ['chits' 'urops' 'indin' 'mongooses' 'sandhogs'] True lable: crocodile
# Predict top 5 labels: ['ghen' 'peyek' 'optocht' 'wotif' 'abendan'] True lable: dinosaur
# Predict top 5 labels: ['shorelines' 'shores' '糾' 'coastline' 'coastlines'] True lable: ray
# Predict top 5 labels: ['trestles' 'nehaj' 'ammun' 'ilwaco' 'kammun'] True lable: tank
# Predict top 5 labels: ['kanun' 'pouch' 'ϣ' 'pouchlike' 'flicking'] True lable: rabbit
# Predict top 5 labels: ['>not' 'belayer' 'abtan' 'fipplet' 'ungaziq'] True lable: lamp
# Predict top 5 labels: ['dmed' 'balut' 'γk' 'teat' 'irdial'] True lable: pear
# Predict top 5 labels: ['dervied' 'abtin' 'biram' 'delegs' 'kipin'] True lable: seal
# Predict top 5 labels: ['eididh' 'gunnbjørn' 'nehat' 'ishmail' 'gilf'] True lable: dolphin
# Predict top 5 labels: ['phalangers' 'indin' 'phalanger' 'delegs' 'fifer'] True lable: shrew
# Predict top 5 labels: ['phemius' 'pey' 'urops' 'srid' 'conjoints'] True lable: crocodile
# Predict top 5 labels: ['curriers' 'cpgs' '年），頁' 'psgb' 'indin'] True lable: bear
# Predict top 5 labels: ['erythraean' 'ghorfa' 'ammun' '}ñ' 'vedars'] True lable: mountain
# Predict top 5 labels: ['muttonwood' 'bakshu' 'stockaded' 'lumbered' 'tree'] True lable: oak_tree
# HIT!
# Predict top 5 labels: ['deey' 'iian' 'midho' 'nsas' 'submersing'] True lable: whale
# Predict top 5 labels: ['qá' 'wotif' 'xeiy' 'memik' '…wi'] True lable: lamp
# Predict top 5 labels: ['huddling' 'raspin' 'lumbered' 'delegs' 'planks'] True lable: turtle
# Predict top 5 labels: ['vocifer' '관계' 'mayeb' 'aidil' 'ayeb'] True lable: snail
# Predict top 5 labels: ['tochal' 'causeway' 's°' 'shatt' 'danun'] True lable: trout
# Predict top 5 labels: ['pheah' 'panlop' 'mah' 'goblet' 'ay,'] True lable: bee
# Predict top 5 labels: ['balut' 'voon' 'zoy' 'gemet' 'pyet'] True lable: pear
# Predict top 5 labels: ['eididh' 'hugas' 'klah' 'seal' 'seals'] True lable: seal
# HIT!
# Predict top 5 labels: ['cordless' 'authenticators' 'tappings' 'napkin' 'napkins'] True lable: can
# Predict top 5 labels: ['beter' 'kelipah' 'poip' 'hie' 'zian'] True lable: woman
# Predict top 5 labels: ['εχ' 'dalaphone' 'indin' 'aidil' 'fifer'] True lable: tractor
# Predict top 5 labels: ['nù' 'mayeb' 'compax' 'ayeb' 'xyrem'] True lable: lamp
# Predict top 5 labels: ['naqortaya' 'lmlk' 'lendman' 'bakshish' 'aaronid'] True lable: willow_tree
# Predict top 5 labels: ['seawalls' '糾' 'mountainside' 'coastline' 'shores'] True lable: sea
# Predict top 5 labels: ['yoke' 'demilune' 'chinstraps' 'siyag' 'osly'] True lable: bear
# Predict top 5 labels: ['>not' 'kepas' 'kanun' 'azmim' 'reshare'] True lable: baby
# Predict top 5 labels: ['delegs' 'pronators' 'sentel' 'edarm' 'chairmanships'] True lable: raccoon
# Predict top 5 labels: ['servier' 'ʤ' 'mayeb' 'aidil' 'wrestrus'] True lable: crocodile
# Predict top 5 labels: ['patrilines' 'staves' 'parsetree' 'patrilineages' 'planks'] True lable: bicycle
# Predict top 5 labels: ['millet' 'savory' 'creame' 'phytofruit' 'millets'] True lable: orange
# Predict top 5 labels: ['kvb' 'thilas' 'srid' 'set,' 'phemius'] True lable: forest
# Predict top 5 labels: ['ketubba' 'dhog' 'zookeepers' 'mongooses' 'sandhogs'] True lable: otter
# Predict top 5 labels: ['sandhog' 'signalmen' 'bedar' '菅原' 'sandhogs'] True lable: streetcar
# Predict top 5 labels: ['haplo' 'raspin' 'napkin' 'fipplet' 'bisushield'] True lable: tiger
# Predict top 5 labels: ['table/file' '弘仁' 'srid' 'conjoints' 'setnence'] True lable: willow_tree
# Predict top 5 labels: ['seawalls' 'seaward' 'inundation' 'oceanflow' 'shores'] True lable: road
# Predict top 5 labels: ['kpers' '‘snake' 'indin' 'fifer' 'boon'] True lable: leopard
# Predict top 5 labels: ['cheetam' 'chevrotain' 'nutriment' 'ferrets' 'rabbit,'] True lable: snail
# Predict top 5 labels: ['bisushield' 'frrom' 'aaey' 'fipplet' 'cleraly'] True lable: bowl
# Predict top 5 labels: ['reeds' 'burrows' 'dhog' 'gopher' 'sandhog'] True lable: crocodile
# Predict top 5 labels: ['handcuff' 'opiah' 'lipread' 'signs,' '蒸'] True lable: flatfish
# Predict top 5 labels: ['huddling' 'terraspin' 'maspin' 'urops' 'raspin'] True lable: spider
# Predict top 5 labels: ['dmed' 'osmet' 'chewers' 'chairmans' 'chairman,'] True lable: woman
# Predict top 5 labels: ['offshores' 'offshore' 'davidof' 'coastline' 'coastlines'] True lable: caterpillar
# Predict top 5 labels: ['aquafish' 'gamey' 'zoy' 'sosy' 'iodize'] True lable: mushroom
# Predict top 5 labels: ['mokhtary' 'whouk' 'กา' 'aidil' 'dilşad'] True lable: baby
# Predict top 5 labels: ['aquafish' 'servier' 'zoy' 'brotherband' 'wotif'] True lable: cattle
# Predict top 5 labels: ['bagat' 'poosy' 'abtin' 'delegs' 'balute'] True lable: elephant
# Predict top 5 labels: ['hadal' 'islets' 'inchs' 'nehat' 'hamikdosh'] True lable: ray
# Predict top 5 labels: ['>not' 'pocketed' 'refills' 'worred' 'refill'] True lable: hamster
# Predict top 5 labels: ['elife' 'pmang' 'partonomy' 'srid' 'artonomy'] True lable: bowl
# Predict top 5 labels: ['‘telephone' '더블' 'elephone' 'telephones' 'telephone'] True lable: can
# Predict top 5 labels: ['>not' 'refills' 'heqats' 'continence' 'pyet'] True lable: bed
# Predict top 5 labels: ['suweid' 'shoresh' 'ammun' 'habhab' 'suweidi'] True lable: streetcar
# Predict top 5 labels: ['ammun' 'entrenchments' 'lumbered' 'delegs' 'planks'] True lable: tank
# Predict top 5 labels: ['millet' 'gamekeeping' 'paan' 'barleys' 'channars'] True lable: crab
# Predict top 5 labels: ['wagons,' 'motormen' 'delegs' 'handcart' 'signalmen'] True lable: tank
# Predict top 5 labels: ['porcupines' 'mongoose' 'mongooses' 'badger' 'muntjacs'] True lable: rabbit
# Predict top 5 labels: ['flicking' 'pronating' 'napkins' 'delegs' 'napkin'] True lable: clock
# Predict top 5 labels: ['eggcorns' 'amyint' 'toothpick' 'chewer' 'corns'] True lable: otter
# Predict top 5 labels: ['padday' 'acket' 'reeving' 'susing' 'issur'] True lable: tank
# Predict top 5 labels: ['frrom' 'lifeband' 'huuh' 'restak' 'earbud'] True lable: clock
# Predict top 5 labels: ['alivan' '甲骨文' 'omtay' '‘servant' '蒸'] True lable: clock
# Predict top 5 labels: ['nond' 'pronouncers' 'sissors' 'רז' 'rp^'] True lable: bowl
# Predict top 5 labels: ['handholes' 'mongoose' 'ammun' 'pouch' 'buffing'] True lable: caterpillar
# Predict top 5 labels: ['oep' 'panlop' 'sosy' 'pyet' 'filise'] True lable: woman
# Predict top 5 labels: ['users,' 'γk' 'napkin' 'napkins' 'prpbably'] True lable: bottle
# Predict top 5 labels: ['mongoose' 'dhog' 'gopher' 'mongooses' 'sandhogs'] True lable: crab
# Predict top 5 labels: ['reclarify' 'kepas' 'swds' 'wotif' 'pyet'] True lable: crocodile
# Predict top 5 labels: ['εχ' 'pronating' 'urops' 'raspin' 'delegs'] True lable: beetle
# Predict top 5 labels: ['retrab' 'ϣ' 'srid' 'candarid' 'setnence'] True lable: bed
# Predict top 5 labels: ['bedars' 'nehaj' 'ammun' 'himandhoo' 'issur'] True lable: pickup_truck
# Predict top 5 labels: ['lumberers' 'narratee' 'byre' '慈' 'dhavle'] True lable: television
# Predict top 5 labels: ['offshores' 'offshore' 'davidof' 'dùil' 'spearfishermen'] True lable: skyscraper
# Predict top 5 labels: ['senar' '>not' 'kanun' 'tubah' 'ksur'] True lable: baby
# Predict top 5 labels: ['bidil' 'sosy' 'adonist' 'rasiah' '明天'] True lable: orchid
# Predict top 5 labels: ['>not' 'bisushield' 'ϣ' 'recommened' 'એ'] True lable: kangaroo
# Predict top 5 labels: ['dpep' 'mongoose' 'mongooses' 'meshweaver' 'puddling'] True lable: forest
# Predict top 5 labels: ['seawalls' 'cliffs' 'laasqoray' 'shores' 'coastline'] True lable: castle
# Predict top 5 labels: ['pomegranate' 'millet' 'pansy' 'artichoke' 'cawl'] True lable: bee
# Predict top 5 labels: ['¬ψ' 'elmy' 'tharold' 'snorg' 'zimble'] True lable: apple
# Predict top 5 labels: ['manmoth' 'forest' 'lamans' 'caterpillar' 'biodiverse'] True lable: spider
# Predict top 5 labels: ['zoy' 'mees' 'wotif' 'mah' 'fishl'] True lable: wolf
# Predict top 5 labels: ['keptin' 'zoy' 'urops' 'pyet' 'εχ'] True lable: butterfly
# Predict top 5 labels: ['diptan' 'postmen' 'siptan' 'delegs' 'pcrg'] True lable: butterfly
# Predict top 5 labels: ['沓' 'indin' 'perakis' 'bidil' 'anir'] True lable: shark
# Predict top 5 labels: ['zoy' 'pouch' 'กา' 'poosy' 'dustpan'] True lable: spider
# Predict top 5 labels: ['sinked' 'pouch' '弘仁' 'reeds' 'igil'] True lable: bicycle
# Predict top 5 labels: ['gophone' 'mindin' 'dhog' 'indin' 'fifer'] True lable: leopard
# Predict top 5 labels: ['gokhos' 'εχ' 'pigdog' 'seal' 'pyet'] True lable: beaver
# Predict top 5 labels: ['merduk' 'sirdar' 'ațl' 'proppen' 'taklift'] True lable: couch
# Predict top 5 labels: ['nammun' 'ammun' 'vedars' '__i' 'kammun'] True lable: house
# Predict top 5 labels: ['depa' 'deldo' 'codog' 'delegs' 'skunk'] True lable: skunk
# HIT!
# Predict top 5 labels: ['‘serving' '蒸' 'b^r' '‘left' '‘smith'] True lable: shrew
# Predict top 5 labels: ['bisushield' 'frrom' 'berix' 'manerix' 'delegs'] True lable: lawn_mower
# Predict top 5 labels: ['pmate' 'mcoz' 'µc' 'sosy' 'dozy'] True lable: apple
# Predict top 5 labels: ['fipple' 'handholes' 'raspin' 'halpatter' 'fipplet'] True lable: worm
# Predict top 5 labels: ['urops' 'poosy' 'ϣ' 'biosca' 'table/file'] True lable: spider
# Predict top 5 labels: ['o̱' 'wsop' 'öif' 'nehat' '菅原'] True lable: television
# Predict top 5 labels: ['manfish' 'oce' 'oilfish' 'zunafish' 'jifish'] True lable: ray
# Predict top 5 labels: ['말하자면' 'soundhog' 'submers' '菅原' 'sustainers'] True lable: seal
# Predict top 5 labels: ['hoogstrate' 'kelgian' 'poosy' 'ferrets' 'moles'] True lable: kangaroo
# Predict top 5 labels: ['goosy' 'azurine' 'sosy' 'pyet' 'dozy'] True lable: couch
# Predict top 5 labels: ['granaries' 'marshy' 'ortah' 'ammun' 'marshlands'] True lable: mountain
# Predict top 5 labels: ['莊子' '价' 'j♥' '‘servant' 'napkins'] True lable: bear
# Predict top 5 labels: ['refeer' 'pouch' 'pocketed' 'gopher' 'fifer'] True lable: shrew
# Predict top 5 labels: ['oilfish' 'aquafish' 'manfish' 'bigfish' 'bigfin'] True lable: rocket
# Predict top 5 labels: ['tyan' 'yegâh' 'peyek' 'mees' 'pyet'] True lable: hamster
# Predict top 5 labels: ['mongoose' 'mongooses' 'hares' 'delegs' 'labbits'] True lable: snail
# Predict top 5 labels: ['trur' 'itary' 'ammun' '}ø' 'chalise'] True lable: tractor
# Predict top 5 labels: ['zoy' 'osmet' 'zict' 'gemet' 'filise'] True lable: sea
# Predict top 5 labels: ['mongooses' 'phalangers' 'table/file' 'indin' 'delegs'] True lable: elephant
# Predict top 5 labels: ['teat' 'pouch' 'ϣ' 'pouchlike' 'pooing'] True lable: mouse
# Predict top 5 labels: ['nammun' '>those' 'ammun' 'barid' 'talut'] True lable: train
# Predict top 5 labels: ['wipey' 'washball' 'salivan' 'chewers' 'napkins'] True lable: boy
# Predict top 5 labels: ['walkie' 'pelephone' 'dewé' 'interphone' 'clnet'] True lable: baby
# Predict top 5 labels: ['stook' 'fifes' 'guh' 'armers' 'delegs'] True lable: lawn_mower
# Predict top 5 labels: ['dholes' 'burrows' 'mongooses' 'lagus' 'arnee'] True lable: kangaroo
# Predict top 5 labels: ['thresh' 'abagous' 'malagassa' 'byble' 'harvesters'] True lable: pickup_truck
# Predict top 5 labels: ['falaisias' '정자' 'lendman' 'beik' 'iverian'] True lable: maple_tree
# Predict top 5 labels: ['offshores' 'offshore' 'shipwreck' 'tuna' 'spearfishermen'] True lable: turtle
# Predict top 5 labels: ['#intestine' 'dhog' 'fishl' 'vocifer' '#anan'] True lable: road
# Predict top 5 labels: ['man—an' '⑆' 'person—the' 'person' 'mediary'] True lable: boy
# Predict top 5 labels: ['öçsoy' 'eshrefids' 'note_cat' 'ayeb' 'أريحا'] True lable: girl
# Predict top 5 labels: ['tides' 'offshore' 'zian' 'offshores' 'թթ'] True lable: ray
# Predict top 5 labels: ['istak' 'frrom' 'reeds' 'drillship' 'sink'] True lable: orchid
# Predict top 5 labels: ['cultivian' '陽翟' '完' '明天' '何晏'] True lable: orange
# Predict top 5 labels: ['beach,' 'seashore' '糾' 'coastline' 'calusa'] True lable: dolphin
# Predict top 5 labels: ['dmed' 'eshre' 'faees' 'sphr' 'ayeb'] True lable: hamster
# Predict top 5 labels: ['‘left' 'tonnies' 'sosy' 'pint' 'dozy'] True lable: sweet_pepper
# Predict top 5 labels: ['eygptian' '唐人' 'lektz' 'xyrem' 'genevé'] True lable: orchid
# Predict top 5 labels: ['poult' 'osmole' 'pouch' 'zoy' 'goosy'] True lable: possum
# Predict top 5 labels: ['kanun' 'frrom' 'bidil' 'aidil' 'hemidi'] True lable: man
# Predict top 5 labels: ['sinked' 'appers' 'urops' 'bedpan' 'kvb'] True lable: lobster
# Predict top 5 labels: ['sagih' 'knip' 'frrom' 'bidil' '北江'] True lable: woman
# Predict top 5 labels: ['‘left' 'decaf' 'dozy' 'pint' '‘smith'] True lable: poppy
# Predict top 5 labels: ['cdip' 'vooc' 'mediatek' 'compax' 'verhoff'] True lable: man
# Predict top 5 labels: ['davidof' 'offshores' 'offshore' 'reef' 'oceanflow'] True lable: whale
# Predict top 5 labels: ['meesh' 'poosy' 'zoy' 'sosy' 'zerd'] True lable: tiger
# Predict top 5 labels: ['pouch' 'ϣ' 'srid' 'pey' 'napkins'] True lable: house
# Predict top 5 labels: ['gastrol' 'allotter' 'aquafish' 'iaph' 'besra'] True lable: caterpillar
# Predict top 5 labels: ['raswa' 'ammun' 'chalize' 'biram' 'sitaw'] True lable: dinosaur
# Predict top 5 labels: ['diouf' 'thilas' 'waël' 'keur' 'sandhogs'] True lable: porcupine
# Predict top 5 labels: ['fietsers' '々' 'กา' 'aidil' 'herper'] True lable: bicycle
# Predict top 5 labels: ['yawning' 'habitrpg' 'didiek' 'trophe' 'sanyassin'] True lable: forest
# Predict top 5 labels: ['alivan' 'زیارت' 'symbid' 'tongs' 'ebraam'] True lable: girl
# Predict top 5 labels: ['dhog' 'kanun' 'bansur' 'anir' 'zymal'] True lable: bee
# Predict top 5 labels: ['setnence' 'planks' 'joists' 'unrooted' 'joisted'] True lable: skyscraper
# Predict top 5 labels: ['法家' 'sabt' 'zoy' '모범' 'acfg'] True lable: cattle
# Predict top 5 labels: ['frrom' 'mouthpiece' 'kanun' 'chair/' 'naey'] True lable: worm
# Predict top 5 labels: ['ybc' 'içtim' 'درفش' 'a,dscf' '干'] True lable: orange
# Predict top 5 labels: ['poosy' 'mpon' 'pouch' 'continence' 'goosy'] True lable: camel
# Predict top 5 labels: ['pipin' 'kanun' 'aidil' 'besra' 'simge'] True lable: pear
# Predict top 5 labels: ['öçsoy' '唐人' 'sosy' 'omtay' 'pyet'] True lable: baby
# Predict top 5 labels: ['ludo' 'mongoose' 'dhog' 'vocifer' 'herper'] True lable: crocodile
# Predict top 5 labels: ['nevit' 'pouch' 'reemit' 'ayeb' 'emrin'] True lable: crocodile
# ...
# Predict top 5 labels: ['napkins' 'chewers' 'seal' 'delegs' 'chewer'] True lable: train
# Predict top 5 labels: ['menot' 'frrom' 'binil' 'bidil' 'iaph'] True lable: keyboard
# Predict top 5 labels: ['istak' 'farallah' 'davidof' 'd※' 'inik'] True lable: chair
# Predict top 5 labels: ['lagus' 'burrows' 'dhog' 'gopher' 'burrow'] True lable: maple_tree
# Predict top 5 labels: ['flicking' 'γk' 'napkin' 'napkins' 'eggs,'] True lable: girl
# Predict top 5 labels: ['cdbp' 'tubis' 'iaph' 'niňaj' 'wotif'] True lable: cattle
# Predict top 5 labels: ['beach,' 'submers' '糾' 'coastline' 'calusa'] True lable: oak_tree
# Predict top 5 labels: ['y^n' 'f_^}' 'rd/m' '\\multiput' 'setnence'] True lable: raccoon
# Predict top 5 labels: ['mcoz' 'plural' 'sosy' 'pedicure' 'foorth'] True lable: flatfish
# Predict top 5 labels: ['djaoeh' 'parfew' 'กา' 'scbas' 'aidil'] True lable: orange
# Predict top 5 labels: ['guemo' '—dil' '鰐' '—did' '—men'] True lable: orange
# Predict top 5 labels: ['treebo' 'mongoose' 'mongooses' 'reeds' 'arnee'] True lable: chimpanzee
# Predict top 5 labels: ['srid' 'laman' 'unpotable' 'reeds' 'setnence'] True lable: woman
# Predict top 5 labels: ['alivan' 'panlop' 'indin' 'mindin' '年），頁'] True lable: bee
# Predict top 5 labels: ['seawalls' 'beach,' 'coastline' 'shores' 'shoreline'] True lable: tiger
# Predict top 5 labels: ['@args' 'bedars' 'issur' 'ammun' 'mediary'] True lable: sea
# Predict top 5 labels: ['teaspoon' 'teaspoons' '‘drink' 'pint' 'dozy'] True lable: lobster
# Predict top 5 labels: ['arving' 'joists' 'planks' 'lumbered' 'joisted'] True lable: woman
# Predict top 5 labels: ['lumbered' 'staves' 'lumber' 'tree' 'planks'] True lable: otter
# Predict top 5 labels: ['abendan' 'ifif' 'cup' 'memik' '…wi'] True lable: worm
# Predict top 5 labels: ['sedom' 'ammun' 'laasqoray' 'palmahim' 'kammun'] True lable: cockroach
# Predict top 5 labels: ['alivan' 'servier' 'sosy' '明天' 'nimeth'] True lable: turtle
# Predict top 5 labels: ['seawalls' 'seaward' 'shores,' 'inundation' 'landward'] True lable: ray
# Predict top 5 labels: ['¬ψ' 'refeer' '价' 'birly' '年），頁'] True lable: forest
# Predict top 5 labels: ['handcuffs' 'psgb' 'chewers' 'napkins' 'cuppers'] True lable: can
# Predict top 5 labels: ['甲骨文' '們' 'זהר' 'chairmans' 'ybc'] True lable: forest
# Predict top 5 labels: ['trahegnies' 'sūs' 'ammun' 'suweidan' 'ড়'] True lable: bottle
# Predict top 5 labels: ['ilyon' 'aquafish' 'fishl' 'pyet' 'filise'] True lable: bowl
# Predict top 5 labels: ['istak' 'bisushield' 'reshare' 'usbcell' 'ahrid'] True lable: man
# Predict top 5 labels: ['barley' 'landraces' 'witchgrass' 'bittergourd' 'barleys'] True lable: road
# Predict top 5 labels: ['istak' 'telecomp' 'lifeband' 'ishmail' 'qik'] True lable: cockroach
# Predict top 5 labels: ['twea' 'kratek' '⑆' 'soundhog' 'corruptible'] True lable: willow_tree
# Predict top 5 labels: ['cpcz' 'langoustine' 'creame' 'compote' 'artichoke'] True lable: clock
# Predict top 5 labels: ['gun–will' 'authenticators' 'prngs' 'gansas' 'submers'] True lable: lamp
# Predict top 5 labels: ['gamekeys' 'ϣ' 'table/file' 'srid' 'pouch'] True lable: porcupine
# Predict top 5 labels: ['亅' 'bubiyan' 'ammun' 'laasqoray' 'landward'] True lable: orange
# Predict top 5 labels: ['bisushield' 'i,ve' 'emret' 'fipplet' 'εχ'] True lable: bowl
# Predict top 5 labels: ['darm' 'meif' 'ܘ' 'haiek' 'nо'] True lable: butterfly
# Predict top 5 labels: ['granaries' '亅' 'fauka' 'ammun' 'alifs'] True lable: lawn_mower
# Predict top 5 labels: ['amyint' 'poosy' 'chits' 'queenless' 'lict'] True lable: snail
# Predict top 5 labels: ['pansy' 'osmet' 'sosy' 'thouk' 'аѕ'] True lable: orchid
# Predict top 5 labels: ['ilwaco' 'ammun' 'railhead' 'saltpans' 'dammun'] True lable: table
# Predict top 5 labels: ['lagus' 'sandhog' 'dhog' 'reeds' 'nd/cd'] True lable: chair
# Predict top 5 labels: ['forest' 'itary' '弘仁' 'srid' 'thumber'] True lable: dinosaur
# Predict top 5 labels: ['refeer' 'owm' 'pouch' 'pedites' 'pyet'] True lable: skyscraper
# Predict top 5 labels: ['gous' 'mongoose' 'mongooses' 'hares' 'besra'] True lable: hamster
# Predict top 5 labels: ['sosy' '‘control' 'mcoz' 'chye' 'arsef'] True lable: aquarium_fish
# Predict top 5 labels: ['offshores' 'offshore' 'offshorer' 'dùil' 'spearfishermen'] True lable: crab
# Predict top 5 labels: ['deck' 'undir' 's_i' 'nehat' 'issur'] True lable: worm
# Predict top 5 labels: ['eyle' 'dhog' 'riglers' 'anir' 'sandhogs'] True lable: baby
# Predict top 5 labels: ['bisushield' '价' 'faees' 'cups' 'napkins'] True lable: willow_tree
# Predict top 5 labels: ['hyacinth' 'lict' 'sosy' 'psop' 'oncb'] True lable: rocket
# Predict top 5 labels: ['istak' 'sinked' 'ayyyy' 'fipplet' 'indention'] True lable: hamster
# Predict top 5 labels: ['arving' 'staves' 'lumbered' 'tree' 'planks'] True lable: caterpillar
# Predict top 5 labels: ['cockroachs' 'ceran' 'chewer' 'delegs' 'seal'] True lable: train
# Predict top 5 labels: ['biocontrol' 'witchgrass' 'allomengea' 'bracons' 'bagous'] True lable: raccoon
# Predict top 5 labels: ['natrual' 'fishlass' 'recommened' 'nehat' 'fishl'] True lable: oak_tree
# Predict top 5 labels: ['frrom' 'flopping' 'kanun' 'mousepad' 'prpbably'] True lable: house
# Predict top 5 labels: ['akrab' 'palm' 'seal' 'seals' 'delegs'] True lable: worm
# Predict top 5 labels: ['菅原' 'jegan' 'biram' 'seudo' '∫n'] True lable: wolf
# Predict top 5 labels: ['reef' 'offshore' 'submers' 'submersing' 'dhow'] True lable: bridge
# Predict top 5 labels: ['dpep' 'mongoose' 'urops' 'digestions' 'mongooses'] True lable: otter
# Predict top 5 labels: ['pronounce' 'blmv' '⑆' 'delegard' 'opiah'] True lable: camel
# Predict top 5 labels: ['mongoose' 'dhog' 'gopher' 'sandhog' 'sandhogs'] True lable: tank
# Predict top 5 labels: ['cuppers' 'handcuff' 'toothpick' 'delegs' 'dipicting'] True lable: camel
# Predict top 5 labels: ['beter' 'bedpan' 'pouch' 'pocketed' 'atiek'] True lable: can
# Predict top 5 labels: ['alifs' 'ammun' 'mountainside' '亅' 'isön'] True lable: forest
# Predict top 5 labels: ['turtler' 'dsurf' 'turtle' 'windsurf' 'spearfishermen'] True lable: worm
# Predict top 5 labels: ['adna' 'ammun' 'reinforce' 'vedars' 'bedars'] True lable: squirrel
# Predict top 5 labels: ['indin' 'dhog' 'gopher' 'bsnf' 'fifer'] True lable: cup
# Predict top 5 labels: ['refeer' 'indin' 'table/file' 'gopher' 'chairmanships'] True lable: rocket
# Predict top 5 labels: ['continence' 'pouch' 'zoy' 'ϣ' 'pyet'] True lable: mushroom
# Predict top 5 labels: ['fipplet' 'rubbing' 'spigot' 'napkin' 'napkins'] True lable: seal
# Predict top 5 labels: ['marshy' 'promontories' 'ammun' 'marshlands' 'seaward'] True lable: keyboard
# Predict top 5 labels: ['retrab' 'pey' 'table/file' 'srid' 'continence'] True lable: bicycle
# Predict top 5 labels: ['patrilines' 'lumbered' '__i' 'patrilineages' 'patriline'] True lable: palm_tree
# Predict top 5 labels: ['agriculturists' 'sagin' 'mustee' 'hoboin' 'sandhogs'] True lable: pine_tree
# Predict top 5 labels: ['indin' 'bidil' 'fifer' 'a,dscf' 'gophone'] True lable: camel
# Predict top 5 labels: ['murkomen' '惑乱' 'jǫrð' 'edrin' 'delegs'] True lable: chimpanzee
# Predict top 5 labels: ['unpin' 'heqats' 'all—not' 'unpins' 'setnence'] True lable: snail
# Predict top 5 labels: ['işsever' 'zoy' '杨贵妃' 'pyet' 'filise'] True lable: lobster
# Predict top 5 labels: ['burrows' 'lumbered' 'seal' 'delegs' 'dakotian'] True lable: chimpanzee
# Predict top 5 labels: ['triclabendazole' 'urops' 'chewers' 'thiabendazole' 'tiabendazole'] True lable: squirrel
# Predict top 5 labels: ['indin' 'zoy' 'rasiah' 'aidil' 'chairmans'] True lable: tractor
# Predict top 5 labels: ['muttonwood' 'ammun' 'nhow' 'lumbered' 'planks'] True lable: house
# Predict top 5 labels: ['dholes' 'mongoose' 'mongooses' 'ipin' 'nutriment'] True lable: motorcycle
# Predict top 5 labels: ['chairman,' 'psgb' 'ʤ' 'wicb' 'pndt'] True lable: maple_tree
# Predict top 5 labels: ['eardly' '‘left' 'msuh' '蒸' 'cpcz'] True lable: palm_tree
# Predict top 5 labels: ['kloeu' 'queenless' 'ferrets' 'lion' 'erminois'] True lable: rabbit
# Predict top 5 labels: ['西村' 'mafew' 'hting' 'tδβ' '‘smith'] True lable: willow_tree
# Predict top 5 labels: ['chairs' 'hands,' 'napkin' 'napkins' 'pronators'] True lable: butterfly
# Predict top 5 labels: ['offshore' 'fladday' 'gilf' 'davidof' 'ishmail'] True lable: oak_tree
# Predict top 5 labels: ['sandhog' 'எ' 'keval' 'asval' 'inferrence'] True lable: baby
# Predict top 5 labels: ['poosy' 'loosy' 'pouch' 'bayanoun' 'zerd'] True lable: plain
# Predict top 5 labels: ['¬ψ' '价' 'tongs' 'napkins' 'napkin'] True lable: bottle
# Predict top 5 labels: ['flicking' 'pouch' 'offspin' 'napkin' 'napkins'] True lable: road
# Predict top 5 labels: ['towit' 'zoy' 'wtp' 'iaph' 'iouf'] True lable: clock
# Predict top 5 labels: ['offshore' 'padday' 'hadal' 'gilf' '糾'] True lable: cloud
# Predict top 5 labels: ['r♥cks' 'ytl' '麻衣子' 'lottero' 'onatel'] True lable: lizard
# Predict top 5 labels: ['yegâh' 'kepas' 'worr' 'wotif' 'aidil'] True lable: cattle
# Predict top 5 labels: ['cockroach' 'dipodids' 'raspin' 'lacertids' 'acarid'] True lable: orchid
# Predict top 5 labels: ['bioscoop' 'reeds' 'biosca' 'ng' 'arrom'] True lable: wolf
# Predict top 5 labels: ['cezhug' 'lmen' 'kānun' 'talut' 'pikuach'] True lable: cloud
# Predict top 5 labels: ['甲骨文' 'holding' '莊子' '‘servant' '蒸'] True lable: orchid
# Predict top 5 labels: ['whistling' 'mongoose' 'mongooses' 'reeds' 'caterpillar'] True lable: poppy
# Predict top 5 labels: ['işsever' 'yegâh' 'zoy' 'pyet' '杨贵妃'] True lable: palm_tree
# Predict top 5 labels: ['depak' 'kpers' 'r♥cks' 'dj`s' 'khecari'] True lable: cloud
# Predict top 5 labels: ['urops' 'chits' 'chairmans' 'toep' 'εχ'] True lable: leopard
# Predict top 5 labels: ['cuppers' 'cretors' 'toothpick' 'chewers' 'delegs'] True lable: streetcar
# Predict top 5 labels: ['chair' 'chairmanship' 'chairmanships' 'hands' '#chairman'] True lable: raccoon
# Predict top 5 labels: ['cpoy' 'dmed' 'acarid' 'raspin' 'w–z'] True lable: television
# Predict top 5 labels: ['urops' 'thumble' 'mongooses' 'gopher' 'tinkle'] True lable: maple_tree
# Predict top 5 labels: ['coastlands' 'clifftops' 'mountainside' 'shorebased' 'coastland'] True lable: maple_tree
# Predict top 5 labels: ['dholes' 'mongoose' 'mongooses' 'crocodile' 'sandhogs'] True lable: lobster
# Predict top 5 labels: ['cpoy' 'huddling' 'raspin' 'napkin' 'હતી'] True lable: leopard
# Predict top 5 labels: ['swappers' 'abbrv' 'chits' 'lottering' 'oncb'] True lable: mushroom
# Predict top 5 labels: ['gopher' 'dhog' 'poc' 'fishl' 'uwit'] True lable: bowl
# Predict top 5 labels: ['sinked' 'geonets' '#collapsing' 'indention' 'seaward'] True lable: girl
# Predict top 5 labels: ['seasion' 'offshorer' 'anwv' 'oilfish' 'zian'] True lable: road
# Predict top 5 labels: ['lumberers' 'sandhogs' 'lumbered' 'handcart' 'lumberer'] True lable: bus
# Predict top 5 labels: ['mongoose' 'mongooses' 'berix' 'lamans' 'tëmkin'] True lable: otter
# Predict top 5 labels: ['tonnies' '‘smith' 'sosy' 'pint' 'dozy'] True lable: fox
# Predict top 5 labels: ['dukah' 'tubah' 'aban' 'dùil' 'eisan'] True lable: shrew
# Predict top 5 labels: ['εχ' 'phalangers' 'indin' 'rasiah' 'delegs'] True lable: maple_tree
# Predict top 5 labels: ['promontories' 'shoreline' 'mountainside' 'trablous' 'akhziv'] True lable: lamp
# Predict top 5 labels: ['chairmanship' 'frrom' 'indin' 'kanun' 'a,dscf'] True lable: mushroom
# Predict top 5 labels: ['swds' 'herper' 'dhog' 'anir' 'aidil'] True lable: bee
# Predict top 5 labels: ['kpers' 'protectors' 'ψχ' '菅原' 'appers'] True lable: bear
# Predict top 5 labels: ['pomegranate' '們' '‘drink' 'artichoke' 'unsweetened'] True lable: skyscraper
# Predict top 5 labels: ['xyrem' 'plak' 'mayeb' 'amercan' 'wotif'] True lable: oak_tree
# Predict top 5 labels: ['mower' 'pcock' 'foung' 'delegs' 'balute'] True lable: orange
# Predict top 5 labels: ['işsever' 'theethose' 'öçsoy' 'pyet' 'oep'] True lable: fox
# Predict top 5 labels: ['udts' 'padday' 'problem—the' 'nehat' 'winches'] True lable: plain
# Predict top 5 labels: ['pansy' 'mongooses' 'biosca' 'kelgin' 'gamekeepers'] True lable: porcupine
# Predict top 5 labels: ['keymark' 'xhers' 'xhecs' 'siptan' 'xhel'] True lable: cup
# Predict top 5 labels: ['wipan' 'sbkri' 'menot' 'wotif' 'pican'] True lable: cockroach
# Predict top 5 labels: ['indentifies' 'stbd' 'indentify' 'problem—the' 'tubar'] True lable: hamster
# Predict top 5 labels: ['wipey' 'paft' 'tongs' 'ppsh' 'balute'] True lable: rocket
# Predict top 5 labels: ['dhog' 'sbkri' '菅原' 'delegs' 'fifer'] True lable: sunflower
# Predict top 5 labels: ['εχ' 'mazlan' 'razal' 'mūþ' 'r♥cks'] True lable: train
# Predict top 5 labels: ['소의' 'eygpt' 'man' '﷼' 'attan'] True lable: rose
# Predict top 5 labels: ['tabex' 'bidil' 'schap' 'chairmans' '祝'] True lable: skunk
# Predict top 5 labels: ['granaries' 'lumbered' 'sandlas' 'ammun' 'kammun'] True lable: snail
# Predict top 5 labels: ['patriliny' 'lumbered' 'unrooted' 'patrilineages' 'burh'] True lable: lion
# Predict top 5 labels: ['keypad' 'plate' 'mouthpieces' 'nd/cd' 'mouthpiece'] True lable: lion
# Predict top 5 labels: ['eygptian' 'beter' 'frrom' 'xyrem' 'mediary'] True lable: snake
# Predict top 5 labels: ['ubis' 'frrom' '⑆' 'hwin' 'wisdim'] True lable: streetcar
# Predict top 5 labels: ['shoqbox' 'removable' 'mouthpieces' 'cordless' 'svdo'] True lable: squirrel
# Predict top 5 labels: ['offshore' 'طه' 'gilf' 'klah' 'shipwrecked'] True lable: raccoon
# Predict top 5 labels: ['refeer' 'kpers' 'bnbbc' '完' 'prpbably'] True lable: girl
# Predict top 5 labels: ['獠' 'mhmk' 'etip' '#chairman' 'emrin'] True lable: table
# Predict top 5 labels: ['debuet' 'bathily' 'zoy' 'bidil' 'poosy'] True lable: chimpanzee
# Predict top 5 labels: ['pansy' 'osmet' 'hmfa' 'protargol' 'besra'] True lable: mountain
# Predict top 5 labels: ['washball' 'pedites' 'chewers' 'hting' 'delegs'] True lable: willow_tree
# Predict top 5 labels: ['bisushield' 'toepads' 'ayeb' 'cups' 'compax'] True lable: camel
# Predict top 5 labels: ['⑆' 'chayin' 'a—for' 'soundhog' 'gophone'] True lable: house
# Predict top 5 labels: ['zoy' 'brotherband' 'wotif' 'iaph' 'memin'] True lable: baby
# Predict top 5 labels: ['gopher' 'mongoose' 'mongooses' 'berix' 'burrow'] True lable: tractor
# Predict top 5 labels: ['εχ' 'pigdog' 'sosy' 'ferrets' 'fifer'] True lable: hamster
# Predict top 5 labels: ['treebog' 'treebo' 'reeds' '\\multiput' 'setnence'] True lable: bottle
# Predict top 5 labels: ['roadbed' 'pontook' '}ñ' 'ilwaco' 'b&p'] True lable: orange
# Predict top 5 labels: ['eret' 'setesh' 'dhog' 'bidil' 'aidil'] True lable: trout
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-96a2bc0b0776> in <module>()
#      10 for i in range(10):
#      11     predict_embeddings = sess.run(visual_embeddings, feed_dict={x:eval_data[i*1000:(i+1)*1000], y:eval_labels_embeddings[i*1000:(i+1)*1000], mode:'EVAL'})
# ---> 12     predict_batch_labels = TextEmbeddings.get_nearest_neighbor_labels(predict_embeddings)
#      13     print('Predic nearest neighbor: ')
#      14     for idx, predict_labels in enumerate(predict_batch_labels):
#
# ~/GitHub/DeViSE/Word2Vec.py in get_nearest_neighbor_labels(self, embeddings)
#      83         nn_labels = []
#      84         for vector in embeddings:
# ---> 85             neighbors = self.model.similar_by_vector(vector, topn=5) # neighbors = [('label1', #similarity1),('label2', #similarity2),...]
#      86             neighbors_labels = list(dict(neighbors).keys())
#      87             nn_labels.append(neighbors_labels)
#
# /usr/local/lib/python3.5/dist-packages/gensim/models/keyedvectors.py in similar_by_vector(self, vector, topn, restrict_vocab)
#     558
#     559         """
# --> 560         return self.most_similar(positive=[vector], topn=topn, restrict_vocab=restrict_vocab)
#     561
#     562     def wmdistance(self, document1, document2):
#
# /usr/local/lib/python3.5/dist-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     514
#     515         limited = self.syn0norm if restrict_vocab is None else self.syn0norm[:restrict_vocab]
# --> 516         dists = dot(limited, mean)
#     517         if not topn:
#     518             return dists
#
# KeyboardInterrupt:
