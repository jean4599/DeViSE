# %%
import tensorflow as tf
import numpy as np
import os
import get_data
from Word2Vec import Word2Vec_Model
from IPython.display import clear_output, Image, display, HTML

tf.logging.set_verbosity(tf.logging.INFO)

########## Hyperparameter ##########
BATCH_SIZE = 20
VALIDATION_SIZE = 500
EPOCH_BOUND = 1000
EARLY_STOP_CHECK_EPOCH = 20
TAKE_CROSS_VALIDATION = False
CROSS_VALIDATION = 5
TEXT_EMBEDDING_SIZE = 300
MARGIN = 0.1
EPOCH_PER_DECAY = 10
STORED_PATH = "./saved_model/cifar100_simpleCNN_devise/devise.ckpt"
########## Hyperparameter ##########

########## load Word2Vec model ##########
# TextEmbeddings = TextEmbeddings(word2vec_model_path="./Data/glove.6B/glove.6B.50d.txt")
# all_text_embedding = TextEmbeddings.load_light_word2vec()
# W2V_texts = np.array(list(all_text_embedding.keys()), dtype=np.str)
# print('W2V_texts', W2V_texts.shape)

TextEmbeddings = Word2Vec_Model(word2vec_model_path="./Data/wiki.en.vec")
    
########## load Word2Vec model ##########
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = graph_def
    #strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

def weight_variable(shape, w=0.1):
    initial = tf.truncated_normal(shape, stddev=w) #Outputs random values from a truncated normal distribution.
    return tf.Variable(initial)

def bias_variable(shape, w=0.1):
    initial = tf.constant(w, shape=shape)
    return tf.Variable(initial)

def devise_model(features, labels, train_mode):
    # Input Layer
    # input layer shape should be [batch_size, image_width, image_height, channels] for conv2d
    # set batch_size = -1 means batch_size = the number of input
    print('input data shape: ', features)
    input_layer = tf.reshape(features, [-1, 32, 32, 3])
    print('input layer shape: ', input_layer.shape)
    
    ########## Core Visual Model ##########
    # conv1
    with tf.variable_scope('conv1') as scope:
        kernel = weight_variable(shape=[5, 5, 3, 64]) #shape=[filter_height * filter_width * in_channels, output_channels]
        conv = tf.nn.conv2d(input_layer, kernel, [1, 1, 1, 1], padding='SAME')
        biases = bias_variable(shape=[64], w=0.0)
        pre_activation = tf.nn.bias_add(conv, biases)
        conv1 = tf.nn.relu(pre_activation, name=scope.name)
       
    # pool1
    pool1 = tf.nn.max_pool(conv1, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='SAME')
    # norm1
    norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name='norm1')
    # conv2
    with tf.variable_scope('conv2') as scope:
        kernel = weight_variable(shape=[5, 5, 64, 64])
        conv = tf.nn.conv2d(norm1, kernel, [1, 1, 1, 1], padding='SAME')
        biases = bias_variable(shape=[64], w=0.1)
        pre_activation = tf.nn.bias_add(conv, biases)
        conv2 = tf.nn.relu(pre_activation, name=scope.name)
    # pool2    
    pool2 = tf.nn.max_pool(conv2, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='SAME', name='pool2')
    # norm2
    norm2 = tf.nn.lrn(pool2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name='norm2')
    
    pool2_flat = tf.reshape(norm2, [-1, 8*8*64])
    dense1 = tf.layers.dense(
        inputs=pool2_flat,
        units=1024, # number of neurons in the dense layer
        activation=tf.nn.relu,
        name='dense1')
    dropout1 = tf.layers.dropout(
        inputs=dense1,
        rate=0.1,
        training= train_mode,
        name='dropout1')
    dense2 = tf.layers.dense(
        inputs=dropout1,
        units=512, # number of neurons in the dense layer
        activation=tf.nn.relu,
        name='dense2')
    dropout2 = tf.layers.dropout(
        inputs=dense2,
        rate=0.1,
        training= train_mode,
        name='dropout2')
    ########## Core Visual Model ##########
    
    ########## Transformation ##########
    visual_embeddings = tf.layers.dense(inputs=dropout2, units=TEXT_EMBEDDING_SIZE, name='transform')
    tf.summary.histogram('visual_embeddings', visual_embeddings)
    ########## Transformation ##########
    
    return visual_embeddings
# Out:
# ##### loading word2vec model #####

# %%
def train(X_train, y_train, yy_train, X_validate, y_validate, yy_validate, optimizer, epoch_bound, stop_threshold, batch_size, testing=False):

    global saver, loss
    global writer, merged
    
    early_stop = 0
    best_loss = np.infty
    
    for epoch in range(epoch_bound):

        # randomize training set
        indices_training = np.random.permutation(X_train.shape[0])
        X_train, y_train = X_train[indices_training,:], y_train[indices_training,:]

        # split training set into multiple mini-batches and start training        
        total_batches = int(X_train.shape[0] / batch_size)
        for batch in range(total_batches):
            if batch == total_batches - 1:
                sess.run(optimizer, feed_dict={x: X_train[batch*batch_size:], 
                                               y: y_train[batch*batch_size:],
                                               yy: yy_train[batch*batch_size:],
                                               train_mode: True})
                summary = sess.run(merged, feed_dict={x: X_train[batch*batch_size:],
                                                      y: y_train[batch*batch_size:],
                                                      yy: yy_train[batch*batch_size:],
                                                      train_mode: True})
                writer.add_summary(summary, epoch + (batch/total_batches))


            else:
                sess.run(optimizer, feed_dict={x: X_train[batch*batch_size : (batch+1)*batch_size], 
                                               y: y_train[batch*batch_size : (batch+1)*batch_size], 
                                               yy: yy_train[batch*batch_size : (batch+1)*batch_size],
                                               train_mode: True})
                summary = sess.run(merged, feed_dict={x: X_train[batch*batch_size : (batch+1)*batch_size],
                                                      y: y_train[batch*batch_size : (batch+1)*batch_size],
                                                      yy: yy_train[batch*batch_size : (batch+1)*batch_size],
                                                      train_mode: True})
                writer.add_summary(summary, epoch + (batch/total_batches))

        # split validation set into multiple mini-batches and start validating
        cur_loss = 0.0
        total_batches = int(X_validate.shape[0] / batch_size)
        for batch in range(total_batches):
            
            if batch == total_batches - 1:
                cur_loss += sess.run(loss, feed_dict={x:X_validate[batch*batch_size:],
                                                      y:y_validate[batch*batch_size:],
                                                      yy:yy_validate[batch*batch_size:],
                                                     train_mode: False})
            else:
                cur_loss += sess.run(loss, feed_dict={x:X_validate[batch*batch_size : (batch+1)*batch_size],
                                                      y:y_validate[batch*batch_size : (batch+1)*batch_size],
                                                      yy:yy_validate[batch*batch_size : (batch+1)*batch_size],
                                                     train_mode: False})
        cur_loss /= total_batches
        
        # #test for prediction
        # prediction = sess.run(predictions, feed_dict={x:X_validate, y:y_validate, mode:'EVAL'})
        # print('Predic nearest neighbor: ', prediction['nearest_neighbors'])
        
        # If the loss does not decrease for many times, it will early stop epochs-loop 
        if best_loss > cur_loss:
            early_stop = 0
            best_loss = cur_loss
            # save best model in testing phase
            if testing == True:
                save_path = saver.save(sess, STORED_PATH)
        else:
            early_stop += 1
        print('\tEpoch: ', epoch, '\tBest loss: ', best_loss, '\tCurrent loss: ', cur_loss)
        if early_stop == stop_threshold:
            break

    return best_loss

def unpickle(file):
        import pickle
        with open(file, 'rb') as fo:
            dict = pickle.load(fo, encoding='bytes')
            return dict # return dic keys: [b'filenames', b'batch_label', b'fine_labels', b'coarse_labels', b'data']
        
def labels_2_embeddings(labels):
    
    global TextEmbeddings, TEXT_EMBEDDING_SIZE, CLASSES
    
    labels_embeddings = []
    for i in labels:
        labels_embeddings.append(TextEmbeddings.text_embedding_lookup(TEXT_EMBEDDING_SIZE, CLASSES[i]))
    labels_embeddings = np.array(labels_embeddings, dtype=np.float32)
    
    return labels_embeddings
    

# split dataset into training set and one validation set
def split_folds(indices, Inputs, Labels, cross_validation, fold):
    n = Inputs.shape[0]
    if fold == cross_validation:
        validation_size = n - (int(n/cross_validation) * (cross_validation-1))
        X_train_idx, X_validate_idx = indices[:(n-validation_size)], indices[(n-validation_size):]
        y_train_idx, y_validate_idx = indices[:(n-validation_size)], indices[(n-validation_size):]
    else:
        validation_size = int(n/cross_validation)
        X_train_idx, X_validate_idx = np.concatenate((indices[:validation_size*(fold-1)], indices[validation_size*fold:]), axis=0), indices[(validation_size*(fold-1)):(validation_size*fold)]
        y_train_idx, y_validate_idx = np.concatenate((indices[:validation_size*(fold-1)], indices[validation_size*fold:]), axis=0), indices[(validation_size*(fold-1)):(validation_size*fold)]
    X_train, X_validate = np.array(Inputs[X_train_idx,:]), np.array(Inputs[X_validate_idx,:])
    y_train, y_validate = np.array(Labels[y_train_idx,:]), np.array(Labels[y_validate_idx,:])
    return X_train, y_train, X_validate, y_validate

# %%
import data_augmentation
########## Data ##########
# Data format:
# data -- a 10000x3072 numpy array of uint8s. 
#         Each row of the array stores a 32x32 colour image. 
#         The first 1024 entries contain the red channel values, 
#         the next 1024 the green, and the final 1024 the blue. 
#         The image is stored in row-major order, so that the first 32 entries of the array are the red channel values of the first row of the image.
# labels -- a list of 10000 numbers in the range 0-99. The number at index i indicates the label of the ith image in the array data.

# Load training and testing data
# (train_data, train_labels), (eval_data, eval_labels) = get_data.load_data(path='./Data/cifar-100/')
# train_data = train_data.reshape(train_data.shape[0], 32*32*3)
# train_labels = train_labels.reshape(train_labels.shape[0])
# eval_data = eval_data.reshape(eval_data.shape[0], 32*32*3)
# eval_labels = eval_labels.reshape(eval_labels.shape[0])

# load cifar data and data augmentation
(train_data, train_labels), (eval_data, eval_labels) = data_augmentation.generate()
train_data = train_data.reshape(train_data.shape[0], 32*32*3)
eval_data = eval_data.reshape(eval_data.shape[0], 32*32*3)

# normalize inputs from 0-255 to 0.0-1.0
train_data = train_data / 255.0
eval_data = eval_data / 255.0

# 100 labels of cifar-100
# cifar-100 class list
# fine_labels: 100 labels of classes
# coarse_labels: 20 labels of super classes
classes = unpickle('./Data/cifar-100/meta')
fine_class = np.asarray(classes[b'fine_label_names'], dtype=np.dtype(np.str))
course_class = np.asarray(classes[b'coarse_label_names'], dtype=np.dtype(np.str))
CLASSES = fine_class

train_labels_embeddings = labels_2_embeddings(train_labels)
eval_labels_embeddings = labels_2_embeddings(eval_labels)
classes_text_embedding = TextEmbeddings.get_classes_text_embedding(TEXT_EMBEDDING_SIZE, CLASSES)
# print('ScikitLearn Nearest Neighbors: ', Word2Vec_Model.train_nearest_neighbor(classes_text_embedding, num_nearest_neighbor=5))

print('Train Data shape: ',train_data.shape)
print('Train Label shape: ', train_labels.shape)
########## Data ##########
# Out:
# Using TensorFlow backend.
# Train Data shape:  (100000, 3072)
# Train Label shape:  (100000,)

# %%
########## devise classifier ##########
# x = tf.placeholder(tf.float32, [None, train_data.shape[1]], name='x')

# mode = tf.placeholder(tf.string, name='mode')

# visual_embeddings = devise_model(x, y, mode)

reset_graph()
# Transfer layers
pretrained_model_path = "./saved_model/cifar100_simpleCNN/cifar-100_simpleCNN"
# Get graph from pretrained visual model
pretrained_saver = tf.train.import_meta_graph(pretrained_model_path + ".ckpt.meta")
# get variables of cifar-100 cnn model
x = tf.get_default_graph().get_tensor_by_name("x:0")
y = tf.placeholder(tf.float32, [None, train_labels_embeddings.shape[1]], name='y')
yy = tf.get_default_graph().get_tensor_by_name("y:0")
train_mode = tf.get_default_graph().get_tensor_by_name("train_mode:0")
# print(tf.get_default_graph().get_operations())
cnn_output = tf.get_default_graph().get_tensor_by_name("dropout1/cond/Merge:0")
tf.summary.histogram('cnn_output', cnn_output)

# attach transform layer
with tf.name_scope('transform'):
    visual_embeddings = tf.layers.dense(inputs=cnn_output, units=TEXT_EMBEDDING_SIZE, name='transform')
    tf.summary.histogram('visual_embeddings', visual_embeddings)

# get training parameter in transform layer for training operation
training_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="transform")

# Calculate Loss (for both TRAIN and EVAL modes)
with tf.name_scope('devise_loss'):
    loss = tf.constant(0.0)
    predic_true_distance = tf.reduce_sum(tf.multiply(y, visual_embeddings), axis=1, keep_dims=True)
    for j in range(len(classes_text_embedding)):
        loss = tf.add(loss, tf.maximum(0.0, (MARGIN - predic_true_distance 
                                    + tf.reduce_sum(tf.multiply(classes_text_embedding[j], visual_embeddings),axis=1, keep_dims=True))))
    loss = tf.subtract(loss, MARGIN)
    loss = tf.reduce_sum(loss)
    loss = tf.div(loss, BATCH_SIZE)
    tf.summary.scalar('loss', loss)


print("loss defined")
# Define optimizer and Training iteration (for TRAIN)
## Decaying learning rate exponentially based on the total training step

decay_steps = int(BATCH_SIZE * EPOCH_PER_DECAY) # Define decay steps
global_step = tf.train.get_or_create_global_step()

learning_rate = tf.train.exponential_decay(
        learning_rate=0.01, #initial learning rate
        global_step=global_step,
        decay_steps=decay_steps,
        decay_rate=0.96,
        staircase=True,
        name='ExponentialDecayLearningRate'
    )
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate, name='GD_Optimizer')
train_op = optimizer.minimize(loss, name='train_op', var_list=training_vars)
# ## exponential moving average
ema = tf.train.ExponentialMovingAverage(decay=0.9999)

with tf.control_dependencies([train_op]):
      train_op = ema.apply(training_vars) # apply exponential moving average to training operation
########## devise classifier ##########
# Out:
# loss defined

# %%
########## Train ##########
print("########## Start training ##########")
sess = tf.Session()
init = tf.global_variables_initializer()
# init saver to save model
saver = tf.train.Saver()
# visualize data
merged = tf.summary.merge_all()
writer = tf.summary.FileWriter("logs/cifar100_simpleCNN_devise", sess.graph)

# init weights
sess.run(init)
# restore value from pretrained model
pretrained_saver.restore = (sess, pretrained_model_path + ".ckpt")
for var in training_vars:
    sess.run(var.initializer)
# randomize dataset
indices = np.random.permutation(train_data.shape[0])
# start cross validation
avg_loss = 0.0

if TAKE_CROSS_VALIDATION == True:
    for fold in range(1, CROSS_VALIDATION+1):
        print("########## Fold:", fold, "##########")
        if os.path.exists(STORED_PATH+".meta") == True:
            # restore the precious best model
            saver.restore(sess, STORED_PATH)
        else:
            # init weights
            sess.run(init)
            
        # split inputs into training set and validation set for each fold
        X_train, y_train, X_validate, y_validate = split_folds(indices, train_data, train_labels_embeddings, CROSS_VALIDATION, fold)
        print('validate data: ', X_validate.shape)
        print('validate label: ', y_validate.shape)
        print('train data: ', X_train.shape)
        print('train label: ', y_train.shape)

        best_loss = train(X_train, y_train, X_validate, y_validate
                                , train_op, EPOCH_BOUND, EARLY_STOP_CHECK_EPOCH, BATCH_SIZE, testing=False)
        avg_loss += best_loss
        print("Loss:", best_loss)
    avg_loss /= cross_validation
    print("Average loss of cross validation:", avg_loss)
    
# randomize dataset
indices = np.random.permutation(train_data.shape[0])
Inputs, Labels = np.array(train_data[indices,:]), np.array(train_labels_embeddings[indices,:])
yy_Labels = np.array(train_labels[indices])

# get validation set with the size of a batch for early-stop
X_train, y_train = Inputs[VALIDATION_SIZE:], Labels[VALIDATION_SIZE:]
X_validate, y_validate = Inputs[:VALIDATION_SIZE], Labels[:VALIDATION_SIZE]

yy_train = yy_Labels[VALIDATION_SIZE:]
yy_validation = yy_Labels[:VALIDATION_SIZE]

print('X_train[0]: ', X_train[0])

# start training with all the inputs
best_loss = train(X_train, y_train, yy_train, X_validate, y_validate, yy_validation,
                        train_op, EPOCH_BOUND, EARLY_STOP_CHECK_EPOCH, BATCH_SIZE, testing=True)
print("training with all the inputs, loss:", best_loss)


sess.close()
########## Train ##########
# Out:
# ########## Start training ##########
# X_train[0]:  [ 0.36470589  0.21176471  0.06666667 ...,  1.          1.          1.        ]
# 	Epoch:  0 	Best loss:  6849.66543945 	Current loss:  6849.66543945
# 	Epoch:  1 	Best loss:  4865.13028809 	Current loss:  4865.13028809
# 	Epoch:  2 	Best loss:  4109.2729541 	Current loss:  4109.2729541
# 	Epoch:  3 	Best loss:  4109.2729541 	Current loss:  5052.64787109
# 	Epoch:  4 	Best loss:  4109.2729541 	Current loss:  8185.10266602
# 	Epoch:  5 	Best loss:  4109.2729541 	Current loss:  5361.54792969
# 	Epoch:  6 	Best loss:  4109.2729541 	Current loss:  5841.64976563
# 	Epoch:  7 	Best loss:  4109.2729541 	Current loss:  4395.38333496
# 	Epoch:  8 	Best loss:  4109.2729541 	Current loss:  5449.74388672
# 	Epoch:  9 	Best loss:  4109.2729541 	Current loss:  4151.93325684
# 	Epoch:  10 	Best loss:  4109.2729541 	Current loss:  7078.61072266
# 	Epoch:  11 	Best loss:  4109.2729541 	Current loss:  6181.01789063
# 	Epoch:  12 	Best loss:  4109.2729541 	Current loss:  4230.63785645
# 	Epoch:  13 	Best loss:  2858.16107666 	Current loss:  2858.16107666
# 	Epoch:  14 	Best loss:  2858.16107666 	Current loss:  3782.16682617
# 	Epoch:  15 	Best loss:  2858.16107666 	Current loss:  3094.88675781
# 	Epoch:  16 	Best loss:  2858.16107666 	Current loss:  3107.54960449
# 	Epoch:  17 	Best loss:  2712.90531982 	Current loss:  2712.90531982
# 	Epoch:  18 	Best loss:  2712.90531982 	Current loss:  3471.26545898
# 	Epoch:  19 	Best loss:  2712.90531982 	Current loss:  2815.62228271
# 	Epoch:  20 	Best loss:  2712.90531982 	Current loss:  3463.55252441
# 	Epoch:  21 	Best loss:  2712.90531982 	Current loss:  3049.21901855
# 	Epoch:  22 	Best loss:  2712.90531982 	Current loss:  3101.45460449
# 	Epoch:  23 	Best loss:  2712.90531982 	Current loss:  3006.5698877
# 	Epoch:  24 	Best loss:  2712.90531982 	Current loss:  3049.55952393
# 	Epoch:  25 	Best loss:  2649.27499512 	Current loss:  2649.27499512
# 	Epoch:  26 	Best loss:  2649.27499512 	Current loss:  4042.78139648
# 	Epoch:  27 	Best loss:  2649.27499512 	Current loss:  4095.3150293
# 	Epoch:  28 	Best loss:  2649.27499512 	Current loss:  4293.33851562
# 	Epoch:  29 	Best loss:  2649.27499512 	Current loss:  3172.74630127
# 	Epoch:  30 	Best loss:  2649.27499512 	Current loss:  3981.19875
# 	Epoch:  31 	Best loss:  2649.27499512 	Current loss:  3207.83994141
# 	Epoch:  32 	Best loss:  2475.78593994 	Current loss:  2475.78593994
# 	Epoch:  33 	Best loss:  2475.78593994 	Current loss:  4173.94196289
# 	Epoch:  34 	Best loss:  2475.78593994 	Current loss:  3442.74466309
# 	Epoch:  35 	Best loss:  2475.78593994 	Current loss:  3770.93603516
# 	Epoch:  36 	Best loss:  2475.78593994 	Current loss:  3433.98213867
# 	Epoch:  37 	Best loss:  2475.78593994 	Current loss:  3474.94592041
# 	Epoch:  38 	Best loss:  2475.78593994 	Current loss:  5555.90429199
# 	Epoch:  39 	Best loss:  2475.78593994 	Current loss:  3632.95791016
# 	Epoch:  40 	Best loss:  2475.78593994 	Current loss:  4494.71544434
# 	Epoch:  41 	Best loss:  2475.78593994 	Current loss:  3213.90925781
# 	Epoch:  42 	Best loss:  2475.78593994 	Current loss:  3315.3411499
# 	Epoch:  43 	Best loss:  2475.78593994 	Current loss:  2711.03773682
# 	Epoch:  44 	Best loss:  2475.78593994 	Current loss:  4568.04272461
# 	Epoch:  45 	Best loss:  2475.78593994 	Current loss:  2667.60903809
# 	Epoch:  46 	Best loss:  2475.78593994 	Current loss:  2956.74916016
# 	Epoch:  47 	Best loss:  2475.78593994 	Current loss:  3306.79826904
# 	Epoch:  48 	Best loss:  2475.78593994 	Current loss:  4935.58543945
# 	Epoch:  49 	Best loss:  2475.78593994 	Current loss:  2700.91057617
# 	Epoch:  50 	Best loss:  2475.78593994 	Current loss:  2864.90158203
# 	Epoch:  51 	Best loss:  2475.78593994 	Current loss:  4478.70628906
# 	Epoch:  52 	Best loss:  2475.78593994 	Current loss:  2797.30577637
# training with all the inputs, loss: 2475.78593994

# %%
########## Evaluate ##########
# Evaluate the model and print results
print("########## Start evaluating ##########")
sess = tf.Session()
# restore the precious best model
saver = tf.train.Saver()
saver.restore(sess, STORED_PATH)

top1_hit = 0.0
top3_hit = 0.0
top5_hit = 0.0
for i in range(10):
    predict_embeddings = sess.run(visual_embeddings, feed_dict={x:eval_data[i*1000:(i+1)*1000],
                                                                y:eval_labels_embeddings[i*1000:(i+1)*1000],
                                                                yy: eval_labels[i*1000:(i+1)*1000],
                                                                train_mode: False})
    predict_batch_labels = TextEmbeddings.get_nearest_neighbor_labels(predict_embeddings, 1)
    for idx, predict_labels in enumerate(predict_batch_labels):
        long_true_label = CLASSES[eval_labels[idx]] # refer to class labels        
        # consider a class name is concated by multiple labels (ex., maple_tree)
        true_labels = long_true_label.split('_')
        for true in true_labels:
            if(true in predict_labels):
                top1_hit+=1
                print("top1 HIT!")
    predict_batch_labels = TextEmbeddings.get_nearest_neighbor_labels(predict_embeddings, 3)
    for idx, predict_labels in enumerate(predict_batch_labels):
        long_true_label = CLASSES[eval_labels[idx]] # refer to class labels        
        # consider a class name is concated by multiple labels (ex., maple_tree)
        true_labels = long_true_label.split('_')
        for true in true_labels:
            if(true in predict_labels):
                top3_hit+=1
                print("top3 HIT!")
    predict_batch_labels = TextEmbeddings.get_nearest_neighbor_labels(predict_embeddings, 5)
    for idx, predict_labels in enumerate(predict_batch_labels):
        long_true_label = CLASSES[eval_labels[idx]] # refer to class labels        
        # consider a class name is concated by multiple labels (ex., maple_tree)
        true_labels = long_true_label.split('_')
        for true in true_labels:
            if(true in predict_labels):
                top5_hit+=1
                print("top5 HIT!")

print("Test result: Top 1 hit rate", top1_hit/100, "%")
print("Test result: Top 3 hit rate", top3_hit/100, "%")
print("Test result: Top 5 hit rate", top5_hit/100, "%")

#print('Test accuracy: ', testing_accuracy/5)
sess.close()
######### Evaluate ##########
# Out:
# ########## Start evaluating ##########
# INFO:tensorflow:Restoring parameters from ./saved_model/cifar100_simpleCNN_devise/devise.ckpt
# Predic nearest neighbor:
# Predict top 1 labels: ['recommences'] True lable: mountain
# Predict top 1 labels: ['#porcupine'] True lable: forest
# Predict top 1 labels: ['phalangers'] True lable: seal
# Predict top 1 labels: ['wme/img'] True lable: mushroom
# Predict top 1 labels: ['anbf'] True lable: sea
# Predict top 1 labels: ['polyandrous'] True lable: tulip
# Predict top 1 labels: ['stodir'] True lable: camel
# Predict top 1 labels: ['stook'] True lable: butterfly
# Predict top 1 labels: ['qutim'] True lable: cloud
# Predict top 1 labels: ['pronites'] True lable: apple
# Predict top 1 labels: ['song—the'] True lable: sea
# Predict top 1 labels: ['unequip'] True lable: skunk
# Predict top 1 labels: ['stauton'] True lable: streetcar
# Predict top 1 labels: ['cliffs'] True lable: rocket
# Predict top 1 labels: ['estriol'] True lable: lamp
# Predict top 1 labels: ['hyphenless'] True lable: lion
# Predict top 1 labels: ['oled'] True lable: tulip
# Predict top 1 labels: ['paleomammalian'] True lable: wolf
# Predict top 1 labels: ['tonnies'] True lable: rose
# Predict top 1 labels: ['crystalluria'] True lable: orange
# Predict top 1 labels: ['xviii'] True lable: rose
# Predict top 1 labels: ['phalangers'] True lable: mountain
# Predict top 1 labels: ['kocoum'] True lable: skunk
# Predict top 1 labels: ['糾'] True lable: dinosaur
# Predict top 1 labels: ['dj`s'] True lable: chimpanzee
# Predict top 1 labels: ['érasistrate'] True lable: can
# Predict top 1 labels: ['equippage'] True lable: keyboard
# Predict top 1 labels: ['motocycle'] True lable: bicycle
# Predict top 1 labels: ['owm'] True lable: bicycle
# Predict top 1 labels: ['w/kg'] True lable: rose
# Predict top 1 labels: ['acephale'] True lable: chair
# Predict top 1 labels: ['clock'] True lable: plate
# Predict top 1 labels: ['recocks'] True lable: lawn_mower
# Predict top 1 labels: ['spm'] True lable: turtle
# Predict top 1 labels: ['cavities'] True lable: palm_tree
# Predict top 1 labels: ['caprolagus'] True lable: shark
# Predict top 1 labels: ['ybc'] True lable: pickup_truck
# Predict top 1 labels: ['azolan'] True lable: boy
# Predict top 1 labels: ['tôn'] True lable: couch
# Predict top 1 labels: ['lincolnton'] True lable: house
# Predict top 1 labels: ['#porcupine'] True lable: porcupine
# Predict top 1 labels: ['fiberhood'] True lable: cockroach
# Predict top 1 labels: ['fossá'] True lable: mountain
# Predict top 1 labels: ['supereruption'] True lable: shark
# Predict top 1 labels: ['scalped'] True lable: palm_tree
# Predict top 1 labels: ['plate'] True lable: clock
# Predict top 1 labels: ['reclarify'] True lable: lawn_mower
# Predict top 1 labels: ['playfoot'] True lable: pickup_truck
# Predict top 1 labels: ['borglum'] True lable: skunk
# Predict top 1 labels: ['moytoy'] True lable: castle
# Predict top 1 labels: ['impair'] True lable: beaver
# Predict top 1 labels: ['lathis'] True lable: bee
# Predict top 1 labels: ['clopyralid'] True lable: bottle
# Predict top 1 labels: ['ks/hh'] True lable: pear
# Predict top 1 labels: ['ckma'] True lable: baby
# Predict top 1 labels: ['contraceptives'] True lable: flatfish
# Predict top 1 labels: ['shores'] True lable: sea
# Predict top 1 labels: ['tree'] True lable: oak_tree
# HIT!
# Predict top 1 labels: ['cki'] True lable: leopard
# Predict top 1 labels: ['pikuach'] True lable: rocket
# Predict top 1 labels: ['impair'] True lable: snail
# Predict top 1 labels: ['liontailed'] True lable: crocodile
# Predict top 1 labels: ['lathis'] True lable: camel
# Predict top 1 labels: ['barasingha'] True lable: rabbit
# Predict top 1 labels: ['tonnin'] True lable: beetle
# Predict top 1 labels: ['eloxatin'] True lable: girl
# Predict top 1 labels: ['益陽'] True lable: lion
# Predict top 1 labels: ['奶爸百分百'] True lable: sunflower
# Predict top 1 labels: ['traon'] True lable: porcupine
# Predict top 1 labels: ['morelladon'] True lable: tulip
# Predict top 1 labels: ['dxrd'] True lable: raccoon
# Predict top 1 labels: ['wbsr'] True lable: train
# Predict top 1 labels: ['foldscope'] True lable: ray
# Predict top 1 labels: ['usfws'] True lable: trout
# Predict top 1 labels: ['aylık'] True lable: flatfish
# Predict top 1 labels: ['cbmt'] True lable: flatfish
# Predict top 1 labels: ['cowpeas'] True lable: sunflower
# Predict top 1 labels: ['cpgs'] True lable: bowl
# Predict top 1 labels: ['eloxatin'] True lable: snail
# Predict top 1 labels: ['crystally'] True lable: clock
# Predict top 1 labels: ['mountainside'] True lable: sea
# Predict top 1 labels: ['plate_'] True lable: snake
# Predict top 1 labels: ['pyronite'] True lable: orchid
# Predict top 1 labels: ['bapulal'] True lable: bee
# Predict top 1 labels: ['tubah'] True lable: dinosaur
# Predict top 1 labels: ['chalisgaon'] True lable: tractor
# Predict top 1 labels: ['ṓ'] True lable: snake
# Predict top 1 labels: ['muktinath'] True lable: forest
# Predict top 1 labels: ['oncb'] True lable: boy
# Predict top 1 labels: ['fossá'] True lable: ray
# Predict top 1 labels: ['wivs'] True lable: clock
# Predict top 1 labels: ['glycogenolytic'] True lable: caterpillar
# Predict top 1 labels: ['limbless'] True lable: crocodile
# Predict top 1 labels: ['tretinoin'] True lable: chimpanzee
# Predict top 1 labels: ['kominakis'] True lable: bus
# Predict top 1 labels: ['piths'] True lable: chimpanzee
# Predict top 1 labels: ['imiut'] True lable: mouse
# Predict top 1 labels: ['paralyses'] True lable: skunk
# Predict top 1 labels: ['roadbed'] True lable: house
# Predict top 1 labels: ['內史省'] True lable: girl
# Predict top 1 labels: ['pœnas'] True lable: crab
# Predict top 1 labels: ['crystallize'] True lable: sweet_pepper
# Predict top 1 labels: ['詞'] True lable: maple_tree
# Predict top 1 labels: ['acephale'] True lable: whale
# Predict top 1 labels: ['cby'] True lable: lion
# Predict top 1 labels: ['stratosphere'] True lable: rocket
# Predict top 1 labels: ['tabes'] True lable: skyscraper
# Predict top 1 labels: ['fortres'] True lable: castle
# Predict top 1 labels: ['ybc'] True lable: pear
# Predict top 1 labels: ['maseet'] True lable: pine_tree
# Predict top 1 labels: ['함흥'] True lable: couch
# Predict top 1 labels: ['potentiometry'] True lable: chair
# Predict top 1 labels: ['tubis'] True lable: crocodile
# Predict top 1 labels: ['ybc'] True lable: apple
# Predict top 1 labels: ['millilitres'] True lable: bottle
# Predict top 1 labels: ['furðustrandir'] True lable: sea
# Predict top 1 labels: ['#motorcycle'] True lable: bicycle
# Predict top 1 labels: ['奶爸百分百'] True lable: lion
# Predict top 1 labels: ['peresters'] True lable: pear
# Predict top 1 labels: ['phalangeal'] True lable: palm_tree
# Predict top 1 labels: ['flatcar'] True lable: tank
# Predict top 1 labels: ['maineiacs'] True lable: bowl
# Predict top 1 labels: ['oneguide'] True lable: cattle
# Predict top 1 labels: ['medicure'] True lable: tulip
# Predict top 1 labels: ['ginseng'] True lable: forest
# Predict top 1 labels: ['pereonite'] True lable: chair
# Predict top 1 labels: ['kocoum'] True lable: chimpanzee
# Predict top 1 labels: ['ritualize'] True lable: mouse
# Predict top 1 labels: ['taben'] True lable: rose
# Predict top 1 labels: ['biograafiline'] True lable: man
# Predict top 1 labels: ['years—by'] True lable: boy
# Predict top 1 labels: ['permitió'] True lable: can
# Predict top 1 labels: ['mcbirney'] True lable: aquarium_fish
# Predict top 1 labels: ['dipus'] True lable: shrew
# Predict top 1 labels: ['bwcns'] True lable: forest
# Predict top 1 labels: ['ἱστοριῶν'] True lable: trout
# Predict top 1 labels: ['bolgars'] True lable: plain
# Predict top 1 labels: ['nо'] True lable: possum
# Predict top 1 labels: ['tree'] True lable: oak_tree
# HIT!
# Predict top 1 labels: ['juyan'] True lable: cloud
# Predict top 1 labels: ['woodcutting'] True lable: beaver
# Predict top 1 labels: ['rrq'] True lable: boy
# Predict top 1 labels: ['joists'] True lable: oak_tree
# Predict top 1 labels: ['lathis'] True lable: house
# Predict top 1 labels: ['scalp'] True lable: cockroach
# Predict top 1 labels: ['offshore'] True lable: whale
# Predict top 1 labels: ['rerutled'] True lable: couch
# Predict top 1 labels: ['phalangers'] True lable: keyboard
# Predict top 1 labels: ['αvβ'] True lable: mushroom
# Predict top 1 labels: ['roadbed'] True lable: pickup_truck
# Predict top 1 labels: ['paralysing'] True lable: pickup_truck
# Predict top 1 labels: ['owlers'] True lable: snail
# Predict top 1 labels: ['cachot'] True lable: caterpillar
# Predict top 1 labels: ['dharamshalas'] True lable: pine_tree
# Predict top 1 labels: ['linkages'] True lable: lobster
# Predict top 1 labels: ['\\phi_r'] True lable: raccoon
# Predict top 1 labels: ['motormen'] True lable: pickup_truck
# Predict top 1 labels: ['chairs'] True lable: chair
# Predict top 1 labels: ['deferens'] True lable: cockroach
# Predict top 1 labels: ['maroth'] True lable: beaver
# Predict top 1 labels: ['recommences'] True lable: hamster
# Predict top 1 labels: ['recommences'] True lable: bicycle
# Predict top 1 labels: ['paralysing'] True lable: television
# Predict top 1 labels: ['theyek'] True lable: bowl
# Predict top 1 labels: ['kbte'] True lable: dolphin
# Predict top 1 labels: ['lathis'] True lable: maple_tree
# Predict top 1 labels: ['ahd'] True lable: orchid
# Predict top 1 labels: ['⅜in'] True lable: worm
# Predict top 1 labels: ['yıld'] True lable: mushroom
# Predict top 1 labels: ['ybc'] True lable: sweet_pepper
# Predict top 1 labels: ['permiting'] True lable: bottle
# Predict top 1 labels: ['패밀리의'] True lable: house
# Predict top 1 labels: ['bison'] True lable: beaver
# Predict top 1 labels: ['kocoum'] True lable: sweet_pepper
# Predict top 1 labels: ['whpva'] True lable: whale
# Predict top 1 labels: ['oncb'] True lable: sweet_pepper
# Predict top 1 labels: ['palm'] True lable: flatfish
# Predict top 1 labels: ['naqahdriah'] True lable: shark
# Predict top 1 labels: ['agrilia'] True lable: caterpillar
# Predict top 1 labels: ['reclarify'] True lable: lamp
# Predict top 1 labels: ['sandhogs'] True lable: keyboard
# Predict top 1 labels: ['mūþ'] True lable: possum
# Predict top 1 labels: ['clock'] True lable: clock
# HIT!
# Predict top 1 labels: ['oiol'] True lable: squirrel
# Predict top 1 labels: ['decocks'] True lable: cup
# Predict top 1 labels: ['apbpa'] True lable: cup
# Predict top 1 labels: ['biograafiline'] True lable: lamp
# Predict top 1 labels: ['whale'] True lable: whale
# HIT!
# Predict top 1 labels: ['‘drink'] True lable: woman
# Predict top 1 labels: ['tonnies'] True lable: sweet_pepper
# Predict top 1 labels: ['roadbeds'] True lable: bridge
# Predict top 1 labels: ['paralyzes'] True lable: cockroach
# Predict top 1 labels: ['handcart'] True lable: lobster
# Predict top 1 labels: ['nagap'] True lable: bus
# Predict top 1 labels: ['order—that'] True lable: wardrobe
# Predict top 1 labels: ['cockroach'] True lable: cockroach
# HIT!
# Predict top 1 labels: ['suweidan'] True lable: pickup_truck
# Predict top 1 labels: ['#porcupine'] True lable: porcupine
# Predict top 1 labels: ['osmet'] True lable: beetle
# Predict top 1 labels: ['planks'] True lable: television
# Predict top 1 labels: ['osmet'] True lable: bee
# Predict top 1 labels: ['spm'] True lable: snake
# Predict top 1 labels: ['roadbed'] True lable: road
# Predict top 1 labels: ['setnence'] True lable: plain
# Predict top 1 labels: ['phalangers'] True lable: bee
# Predict top 1 labels: ['resuspend'] True lable: cloud
# Predict top 1 labels: ['chapped'] True lable: lizard
# Predict top 1 labels: ['lumbered'] True lable: elephant
# Predict top 1 labels: ['répété'] True lable: squirrel
# Predict top 1 labels: ['scalped'] True lable: turtle
# Predict top 1 labels: ['davidof'] True lable: shark
# Predict top 1 labels: ['王'] True lable: woman
# Predict top 1 labels: ['˥'] True lable: mountain
# Predict top 1 labels: ['paldevendran'] True lable: train
# Predict top 1 labels: ['wbss'] True lable: wolf
# Predict top 1 labels: ['보건복지부'] True lable: pine_tree
# Predict top 1 labels: ['vould'] True lable: baby
# Predict top 1 labels: ['tunebo'] True lable: ray
# Predict top 1 labels: ['usgi'] True lable: can
# Predict top 1 labels: ['refuges'] True lable: streetcar
# Predict top 1 labels: ['motorcycle'] True lable: wardrobe
# Predict top 1 labels: ['roadbed'] True lable: crocodile
# Predict top 1 labels: ['gel'] True lable: skyscraper
# Predict top 1 labels: ['phalangeal'] True lable: snail
# Predict top 1 labels: ['wagr'] True lable: bridge
# Predict top 1 labels: ['recommences'] True lable: caterpillar
# Predict top 1 labels: ['ckn'] True lable: apple
# Predict top 1 labels: ['farmsteads'] True lable: skyscraper
# Predict top 1 labels: ['motocycle'] True lable: spider
# Predict top 1 labels: ['anbf'] True lable: sea
# Predict top 1 labels: ['roadbed'] True lable: tractor
# Predict top 1 labels: ['imagefile'] True lable: pear
# Predict top 1 labels: ['not—the'] True lable: maple_tree
# Predict top 1 labels: ['cockroachs'] True lable: cockroach
# Predict top 1 labels: ['nо'] True lable: rabbit
# Predict top 1 labels: ['英語'] True lable: apple
# Predict top 1 labels: ['phalangers'] True lable: flatfish
# Predict top 1 labels: ['nagap'] True lable: hamster
# Predict top 1 labels: ['sugar'] True lable: sunflower
# Predict top 1 labels: ['`+'] True lable: elephant
# Predict top 1 labels: ['foradada'] True lable: cloud
# Predict top 1 labels: ['limbless'] True lable: cockroach
# Predict top 1 labels: ['qiṣṣat'] True lable: fox
# Predict top 1 labels: ['mgga'] True lable: chimpanzee
# Predict top 1 labels: ['tdo'] True lable: boy
# Predict top 1 labels: ['crystalluria'] True lable: orange
# Predict top 1 labels: ['reclarify'] True lable: squirrel
# Predict top 1 labels: ['miquon'] True lable: lizard
# Predict top 1 labels: ['ḳ'] True lable: beaver
# Predict top 1 labels: ['celphones'] True lable: keyboard
# Predict top 1 labels: ['amfl'] True lable: trout
# Predict top 1 labels: ['n\\in\\z'] True lable: can
# Predict top 1 labels: ['anosmic'] True lable: hamster
# Predict top 1 labels: ['recommences'] True lable: road
# Predict top 1 labels: ['entomogenous'] True lable: mouse
# Predict top 1 labels: ['defecate'] True lable: wolf
# Predict top 1 labels: ['snaking'] True lable: pickup_truck
# Predict top 1 labels: ['tiruvale'] True lable: elephant
# Predict top 1 labels: ['bе'] True lable: bee
# Predict top 1 labels: ['matine'] True lable: leopard
# Predict top 1 labels: ['hemidiaphragm'] True lable: squirrel
# Predict top 1 labels: ['følner'] True lable: skyscraper
# Predict top 1 labels: ['roadbed'] True lable: tractor
# Predict top 1 labels: ['morglum'] True lable: otter
# Predict top 1 labels: ['woodcutters'] True lable: cattle
# Predict top 1 labels: ['nо'] True lable: trout
# Predict top 1 labels: ['nhhd'] True lable: rose
# Predict top 1 labels: ['pomegranate'] True lable: aquarium_fish
# Predict top 1 labels: ['kesterite'] True lable: bee
# Predict top 1 labels: ['doukhobour'] True lable: poppy
# Predict top 1 labels: ['migrate'] True lable: worm
# Predict top 1 labels: ['cabetican'] True lable: mushroom
# Predict top 1 labels: ['farmsteads'] True lable: willow_tree
# Predict top 1 labels: ['nutsedge'] True lable: sweet_pepper
# Predict top 1 labels: ['gomastodons'] True lable: leopard
# Predict top 1 labels: ['ῆ'] True lable: caterpillar
# Predict top 1 labels: ['tex'] True lable: ray
# Predict top 1 labels: ['#lactate'] True lable: raccoon
# Predict top 1 labels: ['lomg'] True lable: lamp
# Predict top 1 labels: ['érasistrate'] True lable: poppy
# Predict top 1 labels: ['ਕਰਿ'] True lable: snake
# Predict top 1 labels: ['stepladders'] True lable: table
# Predict top 1 labels: ['nо'] True lable: cup
# Predict top 1 labels: ['등'] True lable: tractor
# Predict top 1 labels: ['offshore'] True lable: dolphin
# Predict top 1 labels: ['△t'] True lable: raccoon
# Predict top 1 labels: ['osmet'] True lable: caterpillar
# Predict top 1 labels: ['malerkotla'] True lable: kangaroo
# Predict top 1 labels: ['arthr'] True lable: leopard
# Predict top 1 labels: ['xviii'] True lable: tulip
# Predict top 1 labels: ['#fowler'] True lable: crocodile
# Predict top 1 labels: ['maintable'] True lable: boy
# Predict top 1 labels: ['umvue'] True lable: telephone
# Predict top 1 labels: ['phalangite'] True lable: lizard
# Predict top 1 labels: ['maindample'] True lable: willow_tree
# Predict top 1 labels: ['bridge'] True lable: bridge
# HIT!
# Predict top 1 labels: ['interrupter'] True lable: can
# Predict top 1 labels: ['#porcupine'] True lable: ray
# Predict top 1 labels: ['mease'] True lable: lion
# Predict top 1 labels: ['heatstroke'] True lable: tractor
# Predict top 1 labels: ['bandipur'] True lable: willow_tree
# Predict top 1 labels: ['not—the'] True lable: bridge
# Predict top 1 labels: ['מערת'] True lable: lamp
# Predict top 1 labels: ['acephate'] True lable: beetle
# Predict top 1 labels: ['heimdalsvatn'] True lable: telephone
# Predict top 1 labels: ['nutriment'] True lable: snail
# Predict top 1 labels: ['relaly'] True lable: skyscraper
# Predict top 1 labels: ['ਜਬ'] True lable: elephant
# Predict top 1 labels: ['gauntlets'] True lable: caterpillar
# Predict top 1 labels: ['epcos'] True lable: cup
# Predict top 1 labels: ['motocycle'] True lable: cattle
# Predict top 1 labels: ['mgga'] True lable: caterpillar
# Predict top 1 labels: ['rubbing'] True lable: lawn_mower
# Predict top 1 labels: ['allomyces'] True lable: leopard
# Predict top 1 labels: ['phalangeal'] True lable: lion
# Predict top 1 labels: ['skangites'] True lable: elephant
# Predict top 1 labels: ['smrr'] True lable: turtle
# Predict top 1 labels: ['phagoptosis'] True lable: camel
# Predict top 1 labels: ['bе'] True lable: bowl
# Predict top 1 labels: ['bicycle'] True lable: bicycle
# HIT!
# Predict top 1 labels: ['phalangites'] True lable: house
# Predict top 1 labels: ['railroadmen'] True lable: tractor
# Predict top 1 labels: ['菅原'] True lable: flatfish
# Predict top 1 labels: ['tex'] True lable: ray
# Predict top 1 labels: ['roadbed'] True lable: bridge
# Predict top 1 labels: ['simeonite'] True lable: baby
# Predict top 1 labels: ['mool'] True lable: cattle
# Predict top 1 labels: ['taben'] True lable: trout
# Predict top 1 labels: ['—strictly'] True lable: wardrobe
# Predict top 1 labels: ['railroads,'] True lable: beetle
# Predict top 1 labels: ['setnence'] True lable: sea
# Predict top 1 labels: ['amphilicite'] True lable: hamster
# Predict top 1 labels: ['cavity'] True lable: plate
# Predict top 1 labels: ['dolgorukovs'] True lable: poppy
# Predict top 1 labels: ['ගුණ'] True lable: bed
# Predict top 1 labels: ['setnence'] True lable: plain
# Predict top 1 labels: ['tex'] True lable: lobster
# Predict top 1 labels: ['abends'] True lable: trout
# Predict top 1 labels: ['nо'] True lable: fox
# Predict top 1 labels: ['zerin'] True lable: whale
# Predict top 1 labels: ['cavity'] True lable: bottle
# Predict top 1 labels: ['xyrem'] True lable: lamp
# Predict top 1 labels: ['mountainside'] True lable: road
# Predict top 1 labels: ['ginseng'] True lable: poppy
# Predict top 1 labels: ['˥'] True lable: worm
# Predict top 1 labels: ['dtbzoh'] True lable: raccoon
# Predict top 1 labels: ['stimulon'] True lable: man
# Predict top 1 labels: ['handcart'] True lable: beetle
# Predict top 1 labels: ['ifugoa'] True lable: bowl
# Predict top 1 labels: ['gophers'] True lable: bowl
# Predict top 1 labels: ['palisade'] True lable: road
# Predict top 1 labels: ['mgga'] True lable: fox
# Predict top 1 labels: ['angakkuq'] True lable: house
# Predict top 1 labels: ['amcar'] True lable: pickup_truck
# Predict top 1 labels: ['motocycle'] True lable: motorcycle
# Predict top 1 labels: ['reclarify'] True lable: lamp
# Predict top 1 labels: ['highwall'] True lable: willow_tree
# Predict top 1 labels: ['isnardia'] True lable: butterfly
# Predict top 1 labels: ['ckrp'] True lable: boy
# Predict top 1 labels: ['ulnar'] True lable: raccoon
# Predict top 1 labels: ['mtns'] True lable: possum
# Predict top 1 labels: ['sheshnag'] True lable: keyboard
# Predict top 1 labels: ['ŋɡ'] True lable: forest
# Predict top 1 labels: ['p_+^'] True lable: wardrobe
# Predict top 1 labels: ['#porcupine'] True lable: porcupine
# Predict top 1 labels: ['bifilar'] True lable: bowl
# Predict top 1 labels: ['nài'] True lable: tractor
# Predict top 1 labels: ['photostimulable'] True lable: tulip
# Predict top 1 labels: ['choultry'] True lable: train
# Predict top 1 labels: ['ocpjp'] True lable: rabbit
# Predict top 1 labels: ['ossb'] True lable: train
# Predict top 1 labels: ['forest'] True lable: forest
# HIT!
# Predict top 1 labels: ['disrupters'] True lable: cup
# Predict top 1 labels: ['permited'] True lable: dinosaur
# Predict top 1 labels: ['paraiyars'] True lable: television
# Predict top 1 labels: ['γk'] True lable: telephone
# Predict top 1 labels: ['acarines'] True lable: beetle
# Predict top 1 labels: ['vegemite'] True lable: apple
# Predict top 1 labels: ['masc/fem'] True lable: wardrobe
# Predict top 1 labels: ['me‼'] True lable: boy
# Predict top 1 labels: ['motocycle'] True lable: crab
# Predict top 1 labels: ['keptin'] True lable: bee
# Predict top 1 labels: ['cauterizing'] True lable: lawn_mower
# Predict top 1 labels: ['myoz'] True lable: chimpanzee
# Predict top 1 labels: ['moosy'] True lable: rocket
# Predict top 1 labels: ['matine'] True lable: crocodile
# Predict top 1 labels: ['optocht'] True lable: dinosaur
# Predict top 1 labels: ['糾'] True lable: ray
# Predict top 1 labels: ['falsework'] True lable: tank
# Predict top 1 labels: ['recommened'] True lable: rabbit
# Predict top 1 labels: ['gasotransmitters'] True lable: lamp
# Predict top 1 labels: ['иҧа'] True lable: pear
# Predict top 1 labels: ['raùl'] True lable: seal
# Predict top 1 labels: ['tekoa'] True lable: dolphin
# Predict top 1 labels: ['donisthorp'] True lable: shrew
# Predict top 1 labels: ['phalangers'] True lable: crocodile
# Predict top 1 labels: ['rajohnson'] True lable: bear
# Predict top 1 labels: ['narsarsuaq'] True lable: mountain
# Predict top 1 labels: ['tree'] True lable: oak_tree
# HIT!
# Predict top 1 labels: ['gun–will'] True lable: whale
# Predict top 1 labels: ['luminescent'] True lable: lamp
# Predict top 1 labels: ['bannapone'] True lable: turtle
# Predict top 1 labels: ['bе'] True lable: snail
# Predict top 1 labels: ['海洋'] True lable: trout
# Predict top 1 labels: ['osmet'] True lable: bee
# Predict top 1 labels: ['icos'] True lable: pear
# Predict top 1 labels: ['whalefall'] True lable: seal
# Predict top 1 labels: ['usgi'] True lable: can
# Predict top 1 labels: ['dxrd'] True lable: woman
# Predict top 1 labels: ['motocycle'] True lable: tractor
# Predict top 1 labels: ['bе'] True lable: lamp
# Predict top 1 labels: ['palisade'] True lable: willow_tree
# Predict top 1 labels: ['糾'] True lable: sea
# Predict top 1 labels: ['˥'] True lable: bear
# Predict top 1 labels: ['anosmic'] True lable: baby
# Predict top 1 labels: ['△t'] True lable: raccoon
# Predict top 1 labels: ['bе'] True lable: crocodile
# Predict top 1 labels: ['falsework'] True lable: bicycle
# Predict top 1 labels: ['phytofruit'] True lable: orange
# Predict top 1 labels: ['rmch'] True lable: forest
# Predict top 1 labels: ['phalangers'] True lable: otter
# Predict top 1 labels: ['railbusses'] True lable: streetcar
# Predict top 1 labels: ['crotalid'] True lable: tiger
# Predict top 1 labels: ['—strictly'] True lable: willow_tree
# Predict top 1 labels: ['mountainside'] True lable: road
# Predict top 1 labels: ['motocycle'] True lable: leopard
# Predict top 1 labels: ['klortho'] True lable: snail
# Predict top 1 labels: ['sheshnag'] True lable: bowl
# Predict top 1 labels: ['dipus'] True lable: crocodile
# Predict top 1 labels: ['phonographs'] True lable: flatfish
# Predict top 1 labels: ['w–z'] True lable: spider
# Predict top 1 labels: ['osmet'] True lable: woman
# Predict top 1 labels: ['surtsey'] True lable: caterpillar
# Predict top 1 labels: ['reclarify'] True lable: mushroom
# Predict top 1 labels: ['organing'] True lable: baby
# Predict top 1 labels: ['spermophorides'] True lable: cattle
# Predict top 1 labels: ['feca'] True lable: elephant
# Predict top 1 labels: ['hamikdosh'] True lable: ray
# Predict top 1 labels: ['uvb'] True lable: hamster
# Predict top 1 labels: ['住'] True lable: bowl
# Predict top 1 labels: ['trf'] True lable: can
# Predict top 1 labels: ['continence'] True lable: bed
# Predict top 1 labels: ['bluffs'] True lable: streetcar
# Predict top 1 labels: ['corncrib'] True lable: tank
# Predict top 1 labels: ['mease'] True lable: crab
# Predict top 1 labels: ['flatcar'] True lable: tank
# Predict top 1 labels: ['cairinini'] True lable: rabbit
# Predict top 1 labels: ['cobrs'] True lable: clock
# Predict top 1 labels: ['eggwhites'] True lable: otter
# Predict top 1 labels: ['years—as'] True lable: tank
# Predict top 1 labels: ['pikuach'] True lable: clock
# Predict top 1 labels: ['rigidify'] True lable: clock
# Predict top 1 labels: ['wnmt'] True lable: bowl
# Predict top 1 labels: ['interdigit'] True lable: caterpillar
# Predict top 1 labels: ['taben'] True lable: woman
# Predict top 1 labels: ['microfibers'] True lable: bottle
# Predict top 1 labels: ['sandhogs'] True lable: crab
# Predict top 1 labels: ['dilgw'] True lable: crocodile
# Predict top 1 labels: ['lathis'] True lable: beetle
# Predict top 1 labels: ['setnence'] True lable: bed
# Predict top 1 labels: ['highwall'] True lable: pickup_truck
# Predict top 1 labels: ['time–space'] True lable: television
# Predict top 1 labels: ['difrawi'] True lable: skyscraper
# Predict top 1 labels: ['zeroed'] True lable: baby
# Predict top 1 labels: ['matine'] True lable: orchid
# Predict top 1 labels: ['solifugid'] True lable: kangaroo
# Predict top 1 labels: ['puddling'] True lable: forest
# Predict top 1 labels: ['mountainside'] True lable: castle
# Predict top 1 labels: ['osmet'] True lable: bee
# Predict top 1 labels: ['cbkf'] True lable: apple
# Predict top 1 labels: ['paldevendran'] True lable: spider
# Predict top 1 labels: ['mgg'] True lable: wolf
# Predict top 1 labels: ['yawning'] True lable: butterfly
# Predict top 1 labels: ['motocycle'] True lable: butterfly
# Predict top 1 labels: ['kcni'] True lable: shark
# Predict top 1 labels: ['bе'] True lable: spider
# Predict top 1 labels: ['mortices'] True lable: bicycle
# Predict top 1 labels: ['chapping'] True lable: leopard
# Predict top 1 labels: ['phalangers'] True lable: beaver
# Predict top 1 labels: ['kseife'] True lable: couch
# Predict top 1 labels: ['pœnas'] True lable: house
# Predict top 1 labels: ['tomahas'] True lable: skunk
# Predict top 1 labels: ['on—or'] True lable: shrew
# Predict top 1 labels: ['reclear'] True lable: lawn_mower
# Predict top 1 labels: ['kosem'] True lable: apple
# Predict top 1 labels: ['precobs'] True lable: worm
# Predict top 1 labels: ['hyphenless'] True lable: spider
# Predict top 1 labels: ['transients'] True lable: television
# Predict top 1 labels: ['knpb'] True lable: ray
# Predict top 1 labels: ['impair'] True lable: seal
# Predict top 1 labels: ['ferrets'] True lable: kangaroo
# Predict top 1 labels: ['azurine'] True lable: couch
# Predict top 1 labels: ['wadis'] True lable: mountain
# Predict top 1 labels: ['snorted'] True lable: bear
# Predict top 1 labels: ['nfnc'] True lable: shrew
# Predict top 1 labels: ['walk//all'] True lable: rocket
# Predict top 1 labels: ['等等》'] True lable: hamster
# Predict top 1 labels: ['mudholes'] True lable: snail
# Predict top 1 labels: ['mnjikaning'] True lable: tractor
# Predict top 1 labels: ['crystallised'] True lable: sea
# Predict top 1 labels: ['oncb'] True lable: elephant
# Predict top 1 labels: ['pooing'] True lable: mouse
# Predict top 1 labels: ['uncouplers'] True lable: train
# Predict top 1 labels: ['urinating'] True lable: boy
# Predict top 1 labels: ['eye—the'] True lable: baby
# Predict top 1 labels: ['guzzi'] True lable: lawn_mower
# Predict top 1 labels: ['hanumappa'] True lable: kangaroo
# Predict top 1 labels: ['doukhobour'] True lable: pickup_truck
# Predict top 1 labels: ['dandylions'] True lable: maple_tree
# Predict top 1 labels: ['krillitanes'] True lable: turtle
# Predict top 1 labels: ['kmpr'] True lable: road
# Predict top 1 labels: ['rodziah'] True lable: boy
# Predict top 1 labels: ['sheshnag'] True lable: girl
# Predict top 1 labels: ['民國'] True lable: ray
# Predict top 1 labels: ['lingating'] True lable: orchid
# Predict top 1 labels: ['cultivian'] True lable: orange
# Predict top 1 labels: ['coastline'] True lable: dolphin
# Predict top 1 labels: ['bе'] True lable: hamster
# Predict top 1 labels: ['tonnies'] True lable: sweet_pepper
# Predict top 1 labels: ['qāţer'] True lable: orchid
# Predict top 1 labels: ['ferrets'] True lable: possum
# Predict top 1 labels: ['bwcns'] True lable: man
# Predict top 1 labels: ['falsework'] True lable: lobster
# Predict top 1 labels: ['freom'] True lable: woman
# Predict top 1 labels: ['adonic'] True lable: poppy
# Predict top 1 labels: ['—p'] True lable: man
# Predict top 1 labels: ['shores'] True lable: whale
# Predict top 1 labels: ['mathurine'] True lable: tiger
# Predict top 1 labels: ['tridemorph'] True lable: house
# Predict top 1 labels: ['allotter'] True lable: caterpillar
# Predict top 1 labels: ['kocoum'] True lable: dinosaur
# Predict top 1 labels: ['#porcupine'] True lable: porcupine
# Predict top 1 labels: ['motocycle'] True lable: bicycle
# Predict top 1 labels: ['properdin'] True lable: forest
# Predict top 1 labels: ['m•'] True lable: girl
# Predict top 1 labels: ['recommences'] True lable: bee
# Predict top 1 labels: ['falsework'] True lable: skyscraper
# Predict top 1 labels: ['headsmen'] True lable: cattle
# Predict top 1 labels: ['bifilar'] True lable: worm
# Predict top 1 labels: ['phalangites'] True lable: orange
# Predict top 1 labels: ['reclarify'] True lable: camel
# Predict top 1 labels: ['nonination'] True lable: pear
# Predict top 1 labels: ['respectant'] True lable: baby
# Predict top 1 labels: ['paldevendran'] True lable: crocodile
# Predict top 1 labels: ['liquidwater'] True lable: crocodile
# Predict top 1 labels: ['nemal'] True lable: turtle
# Predict top 1 labels: ['wbsr'] True lable: streetcar
# Predict top 1 labels: ['taben'] True lable: orchid
# Predict top 1 labels: ['promontories'] True lable: sea
# Predict top 1 labels: ['ghondroderella'] True lable: crab
# Predict top 1 labels: ['falsework'] True lable: couch
# Predict top 1 labels: ['safine'] True lable: girl
# Predict top 1 labels: ['gilf'] True lable: dolphin
# Predict top 1 labels: ['kumch'] True lable: seal
# Predict top 1 labels: ['motocycle'] True lable: bicycle
# Predict top 1 labels: ['nontimber'] True lable: leopard
# Predict top 1 labels: ['creams'] True lable: poppy
# Predict top 1 labels: ['nemaline'] True lable: palm_tree
# Predict top 1 labels: ['posture'] True lable: snake
# Predict top 1 labels: ['vanion'] True lable: maple_tree
# Predict top 1 labels: ['nо'] True lable: shark
# Predict top 1 labels: ['mease'] True lable: lion
# Predict top 1 labels: ['répété'] True lable: chair
# Predict top 1 labels: ['vegemite'] True lable: sweet_pepper
# Predict top 1 labels: ['lumbered'] True lable: porcupine
# Predict top 1 labels: ['saṃjñā'] True lable: mountain
# Predict top 1 labels: ['desizing'] True lable: cup
# Predict top 1 labels: ['symen'] True lable: crab
# Predict top 1 labels: ['domide'] True lable: lobster
# Predict top 1 labels: ['bandhas'] True lable: hamster
# Predict top 1 labels: ['陽翟'] True lable: hamster
# Predict top 1 labels: ['highwalk'] True lable: road
# Predict top 1 labels: ['dampeners'] True lable: aquarium_fish
# Predict top 1 labels: ['hymenal'] True lable: baby
# Predict top 1 labels: ['relampago'] True lable: worm
# Predict top 1 labels: ['ජය'] True lable: bottle
# Predict top 1 labels: ['mhzc'] True lable: rabbit
# Predict top 1 labels: ['osmet'] True lable: kangaroo
# Predict top 1 labels: ['dakotian'] True lable: pickup_truck
# Predict top 1 labels: ['palisade'] True lable: willow_tree
# Predict top 1 labels: ['cunha,'] True lable: kangaroo
# Predict top 1 labels: ['denigés'] True lable: television
# Predict top 1 labels: ['osmet'] True lable: sunflower
# Predict top 1 labels: ['essntially'] True lable: clock
# Predict top 1 labels: ['γk'] True lable: sweet_pepper
# Predict top 1 labels: ['pronating'] True lable: lawn_mower
# Predict top 1 labels: ['paryz'] True lable: beetle
# Predict top 1 labels: ['reclarify'] True lable: bridge
# Predict top 1 labels: ['gnipate'] True lable: bowl
# Predict top 1 labels: ['kosem'] True lable: girl
# Predict top 1 labels: ['arthr'] True lable: lizard
# Predict top 1 labels: ['pœnas'] True lable: streetcar
# Predict top 1 labels: ['insectary'] True lable: trout
# Predict top 1 labels: ['#polydactyly'] True lable: palm_tree
# Predict top 1 labels: ['lathis'] True lable: bottle
# Predict top 1 labels: ['spraymaster'] True lable: cockroach
# Predict top 1 labels: ['bе'] True lable: bear
# Predict top 1 labels: ['sswf'] True lable: dolphin
# Predict top 1 labels: ['keptin'] True lable: aquarium_fish
# Predict top 1 labels: ['bе'] True lable: keyboard
# Predict top 1 labels: ['guzzi'] True lable: woman
# Predict top 1 labels: ['skyguide'] True lable: seal
# Predict top 1 labels: ['phoside'] True lable: sweet_pepper
# Predict top 1 labels: ['rewiring'] True lable: squirrel
# Predict top 1 labels: ['sobors'] True lable: lion
# Predict top 1 labels: ['tonumber'] True lable: table
# Predict top 1 labels: ['dyac'] True lable: raccoon
# Predict top 1 labels: ['cpgs'] True lable: beaver
# Predict top 1 labels: ['glomerulus'] True lable: possum
# Predict top 1 labels: ['klortho'] True lable: snail
# Predict top 1 labels: ['ounces'] True lable: woman
# Predict top 1 labels: ['flaxseeds'] True lable: sunflower
# Predict top 1 labels: ['schedules'] True lable: streetcar
# Predict top 1 labels: ['cockroaches'] True lable: chair
# Predict top 1 labels: ['paph'] True lable: apple
# Predict top 1 labels: ['motocycle'] True lable: motorcycle
# Predict top 1 labels: ['nо'] True lable: man
# Predict top 1 labels: ['eloxatin'] True lable: forest
# Predict top 1 labels: ['xviiia'] True lable: clock
# Predict top 1 labels: ['bodies…'] True lable: bus
# Predict top 1 labels: ['dawwara'] True lable: castle
# Predict top 1 labels: ['tabes'] True lable: keyboard
# Predict top 1 labels: ['image—the'] True lable: skyscraper
# Predict top 1 labels: ['mgg'] True lable: apple
# Predict top 1 labels: ['ardvi'] True lable: castle
# Predict top 1 labels: ['ellador'] True lable: possum
# Predict top 1 labels: ['motocycle'] True lable: motorcycle
# Predict top 1 labels: ['domide'] True lable: train
# Predict top 1 labels: ['azmu'] True lable: turtle
# Predict top 1 labels: ['phytofruit'] True lable: sunflower
# Predict top 1 labels: ['xhers'] True lable: skunk
# Predict top 1 labels: ['redurine'] True lable: willow_tree
# Predict top 1 labels: ['wonnim'] True lable: wolf
# Predict top 1 labels: ['repolarize'] True lable: bear
# Predict top 1 labels: ['ounces'] True lable: sweet_pepper
# Predict top 1 labels: ['ㄞ'] True lable: plain
# Predict top 1 labels: ['plate'] True lable: plate
# HIT!
# Predict top 1 labels: ['glutei'] True lable: flatfish
# Predict top 1 labels: ['ybc'] True lable: crab
# Predict top 1 labels: ['p_+'] True lable: table
# Predict top 1 labels: ['lumbered'] True lable: lawn_mower
# Predict top 1 labels: ['not—the'] True lable: bridge
# Predict top 1 labels: ['recocks'] True lable: tank
# Predict top 1 labels: ['idrar'] True lable: bridge
# Predict top 1 labels: ['△t/γ'] True lable: bicycle
# Predict top 1 labels: ['drumlemble'] True lable: sunflower
# Predict top 1 labels: ['pantograph'] True lable: seal
# Predict top 1 labels: ['yuánjūn'] True lable: wardrobe
# Predict top 1 labels: ['woodcutting'] True lable: beetle
# Predict top 1 labels: ['motormen'] True lable: clock
# Predict top 1 labels: ['evus'] True lable: camel
# Predict top 1 labels: ['template/file'] True lable: raccoon
# Predict top 1 labels: ['restrictons'] True lable: tractor
# Predict top 1 labels: ['grandfalls'] True lable: wolf
# Predict top 1 labels: ['day–'] True lable: cattle
# Predict top 1 labels: ['betrothal'] True lable: apple
# Predict top 1 labels: ['motocycle'] True lable: cattle
# Predict top 1 labels: ['taben'] True lable: bed
# Predict top 1 labels: ['railborn'] True lable: palm_tree
# Predict top 1 labels: ['江汉'] True lable: hamster
# Predict top 1 labels: ['scalping'] True lable: lobster
# Predict top 1 labels: ['hfv'] True lable: aquarium_fish
# Predict top 1 labels: ['bufagin'] True lable: wardrobe
# Predict top 1 labels: ['myott'] True lable: raccoon
# Predict top 1 labels: ['recommened'] True lable: telephone
# Predict top 1 labels: ['sunflower'] True lable: sunflower
# HIT!
# Predict top 1 labels: ['bedsteads'] True lable: castle
# Predict top 1 labels: ['bondir'] True lable: possum
# Predict top 1 labels: ['kncb'] True lable: worm
# Predict top 1 labels: ['fifl'] True lable: fox
# Predict top 1 labels: ['knafia'] True lable: dolphin
# Predict top 1 labels: ['krillitanes'] True lable: shark
# Predict top 1 labels: ['nondual'] True lable: sweet_pepper
# Predict top 1 labels: ['permitholder'] True lable: bee
# Predict top 1 labels: ['fluoresced'] True lable: aquarium_fish
# Predict top 1 labels: ['phospheros'] True lable: cup
# Predict top 1 labels: ['menoitios'] True lable: snail
# Predict top 1 labels: ['excercize'] True lable: trout
# Predict top 1 labels: ['張昌儀'] True lable: shrew
# Predict top 1 labels: ['shores'] True lable: road
# Predict top 1 labels: ['morelladon'] True lable: butterfly
# Predict top 1 labels: ['prytanis'] True lable: butterfly
# Predict top 1 labels: ['wme/img'] True lable: aquarium_fish
# Predict top 1 labels: ['canada`s'] True lable: tulip
# Predict top 1 labels: ['菅原'] True lable: wolf
# Predict top 1 labels: ['giardi'] True lable: lobster
# Predict top 1 labels: ['jaygopal'] True lable: beetle
# Predict top 1 labels: ['person—the'] True lable: chimpanzee
# Predict top 1 labels: ['hakotel'] True lable: house
# Predict top 1 labels: ['phospholamban'] True lable: flatfish
# Predict top 1 labels: ['pikuach'] True lable: shark
# Predict top 1 labels: ['tonumber'] True lable: tiger
# Predict top 1 labels: ['內史省'] True lable: telephone
# Predict top 1 labels: ['osmet'] True lable: tulip
# Predict top 1 labels: ['meskwakis'] True lable: butterfly
# Predict top 1 labels: ['recocks'] True lable: telephone
# Predict top 1 labels: ['shrews'] True lable: shrew
# Predict top 1 labels: ['崩'] True lable: couch
# Predict top 1 labels: ['davidof'] True lable: turtle
# Predict top 1 labels: ['recocks'] True lable: snake
# Predict top 1 labels: ['fasciculins'] True lable: snail
# Predict top 1 labels: ['mansory'] True lable: tiger
# Predict top 1 labels: ['resevoir'] True lable: leopard
# Predict top 1 labels: ['hayq'] True lable: bowl
# Predict top 1 labels: ['˥'] True lable: rabbit
# Predict top 1 labels: ['horseshoer'] True lable: crab
# Predict top 1 labels: ['p_+'] True lable: elephant
# Predict top 1 labels: ['muktinath'] True lable: tank
# Predict top 1 labels: ['handcart'] True lable: snake
# Predict top 1 labels: ['levees'] True lable: dinosaur
# Predict top 1 labels: ['ulnar'] True lable: flatfish
# Predict top 1 labels: ['cabmen'] True lable: streetcar
# Predict top 1 labels: ['kunx'] True lable: wolf
# Predict top 1 labels: ['arfush'] True lable: aquarium_fish
# Predict top 1 labels: ['詞'] True lable: sunflower
# Predict top 1 labels: ['margarine'] True lable: apple
# Predict top 1 labels: ['regrow'] True lable: chimpanzee
# Predict top 1 labels: ['doukhobors'] True lable: camel
# Predict top 1 labels: ['nidhiki'] True lable: palm_tree
# Predict top 1 labels: ['osmet'] True lable: pear
# Predict top 1 labels: ['eloxatin'] True lable: wolf
# Predict top 1 labels: ['hallest'] True lable: skyscraper
# Predict top 1 labels: ['druses'] True lable: plain
# Predict top 1 labels: ['楊殷士'] True lable: television
# Predict top 1 labels: ['domide'] True lable: man
# Predict top 1 labels: ['seashores'] True lable: aquarium_fish
# Predict top 1 labels: ['plate'] True lable: plate
# HIT!
# Predict top 1 labels: ['‘if'] True lable: skunk
# Predict top 1 labels: ['cultivian'] True lable: poppy
# Predict top 1 labels: ['woodcutters'] True lable: chimpanzee
# Predict top 1 labels: ['transmittances'] True lable: plate
# Predict top 1 labels: ['adsu'] True lable: snake
# Predict top 1 labels: ['skangites'] True lable: train
# Predict top 1 labels: ['fraterville'] True lable: road
# Predict top 1 labels: ['nonfood'] True lable: wardrobe
# Predict top 1 labels: ['polyandry'] True lable: tiger
# Predict top 1 labels: ['tjeldsundet'] True lable: whale
# Predict top 1 labels: ['owm'] True lable: bear
# Predict top 1 labels: ['ybc'] True lable: sweet_pepper
# Predict top 1 labels: ['subserve'] True lable: flatfish
# Predict top 1 labels: ['ගුණ'] True lable: turtle
# Predict top 1 labels: ['gu/si/gun'] True lable: snail
# Predict top 1 labels: ['man/men'] True lable: kangaroo
# Predict top 1 labels: ['varactyl'] True lable: porcupine
# Predict top 1 labels: ['xgap'] True lable: plate
# Predict top 1 labels: ['footboard'] True lable: lawn_mower
# Predict top 1 labels: ['bowstringing'] True lable: tiger
# Predict top 1 labels: ['™'] True lable: sweet_pepper
# Predict top 1 labels: ['movable'] True lable: girl
# Predict top 1 labels: ['phytofruit'] True lable: sunflower
# Predict top 1 labels: ['#malagasy'] True lable: mouse
# Predict top 1 labels: ['benzedrine'] True lable: camel
# Predict top 1 labels: ['lottering'] True lable: motorcycle
# Predict top 1 labels: ['teaspoons'] True lable: couch
# Predict top 1 labels: ['mustee'] True lable: beaver
# Predict top 1 labels: ['haliate'] True lable: sea
# Predict top 1 labels: ['dihl'] True lable: bicycle
# Predict top 1 labels: ['oncb'] True lable: woman
# Predict top 1 labels: ['cyprine'] True lable: ray
# Predict top 1 labels: ['cockroach'] True lable: beetle
# Predict top 1 labels: ['convairs'] True lable: tank
# Predict top 1 labels: ['readmittance'] True lable: couch
# Predict top 1 labels: ['misparsed'] True lable: willow_tree
# Predict top 1 labels: ['seafloors'] True lable: plain
# Predict top 1 labels: ['interdigit'] True lable: otter
# Predict top 1 labels: ['insulating'] True lable: squirrel
# Predict top 1 labels: ['ginseng'] True lable: bus
# Predict top 1 labels: ['עצמי'] True lable: train
# Predict top 1 labels: ['hüper'] True lable: orchid
# Predict top 1 labels: ['mountainside'] True lable: camel
# Predict top 1 labels: ['optically'] True lable: skyscraper
# Predict top 1 labels: ['hyphenless'] True lable: keyboard
# Predict top 1 labels: ['straumsfjord'] True lable: whale
# Predict top 1 labels: ['impair'] True lable: cockroach
# Predict top 1 labels: ['paralyzes'] True lable: beetle
# Predict top 1 labels: ['azmu'] True lable: possum
# Predict top 1 labels: ['quom'] True lable: rose
# Predict top 1 labels: ['lumbered'] True lable: tiger
# Predict top 1 labels: ['railbeds'] True lable: streetcar
# Predict top 1 labels: ['wawrykow'] True lable: apple
# Predict top 1 labels: ['mountainside'] True lable: bridge
# Predict top 1 labels: ['highwall'] True lable: possum
# Predict top 1 labels: ['#hereditary'] True lable: elephant
# Predict top 1 labels: ['γδt'] True lable: spider
# Predict top 1 labels: ['ny&h'] True lable: telephone
# Predict top 1 labels: ['mountainside'] True lable: plain
# Predict top 1 labels: ['nte'] True lable: clock
# Predict top 1 labels: ['fishplate'] True lable: kangaroo
# Predict top 1 labels: ['ccuc'] True lable: sunflower
# Predict top 1 labels: ['dakotian'] True lable: butterfly
# Predict top 1 labels: ['skito'] True lable: motorcycle
# Predict top 1 labels: ['motocycle'] True lable: forest
# Predict top 1 labels: ['habenulæ'] True lable: otter
# Predict top 1 labels: ['phytofruit'] True lable: orange
# Predict top 1 labels: ['βe'] True lable: lamp
# Predict top 1 labels: ['reeds'] True lable: aquarium_fish
# Predict top 1 labels: ['òmnibus'] True lable: pickup_truck
# Predict top 1 labels: ['—strictly'] True lable: wardrobe
# Predict top 1 labels: ['kosem'] True lable: rose
# Predict top 1 labels: ['sandhogs'] True lable: dinosaur
# Predict top 1 labels: ['wipers'] True lable: telephone
# Predict top 1 labels: ['˥'] True lable: cloud
# Predict top 1 labels: ['gemet'] True lable: man
# Predict top 1 labels: ['railroad'] True lable: pickup_truck
# Predict top 1 labels: ['˥'] True lable: worm
# Predict top 1 labels: ['cobrs'] True lable: snake
# Predict top 1 labels: ['recocks'] True lable: bowl
# Predict top 1 labels: ['ybc'] True lable: orange
# Predict top 1 labels: ['phalangeal'] True lable: house
# Predict top 1 labels: ['kncb'] True lable: wolf
# Predict top 1 labels: ['taben'] True lable: rabbit
# Predict top 1 labels: ['housesteads'] True lable: camel
# Predict top 1 labels: ['fungites'] True lable: snail
# Predict top 1 labels: ['lumbered'] True lable: oak_tree
# Predict top 1 labels: ['choloepi'] True lable: porcupine
# Predict top 1 labels: ['oronite'] True lable: flatfish
# Predict top 1 labels: ['mgga'] True lable: bee
# Predict top 1 labels: ['#prem'] True lable: hamster
# Predict top 1 labels: ['matzot'] True lable: bee
# Predict top 1 labels: ['osmet'] True lable: beetle
# Predict top 1 labels: ['dilgw'] True lable: hamster
# Predict top 1 labels: ['lumbered'] True lable: shrew
# Predict top 1 labels: ['wbsr'] True lable: bus
# Predict top 1 labels: ['nо'] True lable: clock
# Predict top 1 labels: ['insulating'] True lable: flatfish
# Predict top 1 labels: ['recommences'] True lable: orchid
# Predict top 1 labels: ['tonnies'] True lable: poppy
# Predict top 1 labels: ['w–z'] True lable: table
# Predict top 1 labels: ['cauterising'] True lable: pear
# Predict top 1 labels: ['ṓ'] True lable: couch
# Predict top 1 labels: ['on—or'] True lable: boy
# Predict top 1 labels: ['teaspoons'] True lable: poppy
# Predict top 1 labels: ['reclear'] True lable: tank
# Predict top 1 labels: ['cby'] True lable: elephant
# Predict top 1 labels: ['tôn'] True lable: crab
# Predict top 1 labels: ['xhers'] True lable: can
# Predict top 1 labels: ['mountainside'] True lable: willow_tree
# Predict top 1 labels: ['qutim'] True lable: sea
# Predict top 1 labels: ['bivans'] True lable: train
# Predict top 1 labels: ['phalanger'] True lable: keyboard
# Predict top 1 labels: ['vooc'] True lable: chair
# Predict top 1 labels: ['phytofruit'] True lable: maple_tree
# Predict top 1 labels: ['years—by'] True lable: girl
# Predict top 1 labels: ['dakotah'] True lable: cattle
# Predict top 1 labels: ['…has'] True lable: oak_tree
# Predict top 1 labels: ['deukis'] True lable: raccoon
# Predict top 1 labels: ['↝'] True lable: flatfish
# Predict top 1 labels: ['stoppages'] True lable: orange
# Predict top 1 labels: ['unsweetened'] True lable: orange
# Predict top 1 labels: ['dtbzoh'] True lable: chimpanzee
# Predict top 1 labels: ['b^r'] True lable: woman
# Predict top 1 labels: ['catamites'] True lable: bee
# Predict top 1 labels: ['chapping'] True lable: tiger
# Predict top 1 labels: ['storevatnet'] True lable: sea
# Predict top 1 labels: ['nо'] True lable: lobster
# Predict top 1 labels: ['atryn'] True lable: woman
# Predict top 1 labels: ['roadbed'] True lable: otter
# Predict top 1 labels: ['permier'] True lable: worm
# Predict top 1 labels: ['diphosphenes'] True lable: cockroach
# Predict top 1 labels: ['rafted'] True lable: turtle
# Predict top 1 labels: ['relampago'] True lable: ray
# Predict top 1 labels: ['炉'] True lable: forest
# Predict top 1 labels: ['toothbrushes'] True lable: can
# Predict top 1 labels: ['zensur'] True lable: forest
# Predict top 1 labels: ['nampar'] True lable: bottle
# Predict top 1 labels: ['wfwf'] True lable: bowl
# Predict top 1 labels: ['osmet'] True lable: man
# Predict top 1 labels: ['recommences'] True lable: road
# Predict top 1 labels: ['cockroach'] True lable: cockroach
# HIT!
# Predict top 1 labels: ['ybc'] True lable: willow_tree
# Predict top 1 labels: ['#motorcycle'] True lable: clock
# Predict top 1 labels: ['millet'] True lable: lamp
# Predict top 1 labels: ['paldevendran'] True lable: porcupine
# Predict top 1 labels: ['teaspoons'] True lable: orange
# Predict top 1 labels: ['notro'] True lable: bowl
# Predict top 1 labels: ['motocycle'] True lable: butterfly
# Predict top 1 labels: ['freom'] True lable: lawn_mower
# Predict top 1 labels: ['gu/si/gun'] True lable: snail
# Predict top 1 labels: ['wongs'] True lable: orchid
# Predict top 1 labels: ['setnence'] True lable: table
# Predict top 1 labels: ['a—for'] True lable: chair
# Predict top 1 labels: ['ybc'] True lable: dinosaur
# Predict top 1 labels: ['sinked'] True lable: skyscraper
# Predict top 1 labels: ['dicided'] True lable: hamster
# Predict top 1 labels: ['osmet'] True lable: aquarium_fish
# Predict top 1 labels: ['ybc'] True lable: crab
# Predict top 1 labels: ['amitermes'] True lable: worm
# Predict top 1 labels: ['chronotropy'] True lable: baby
# Predict top 1 labels: ['accn'] True lable: willow_tree
# Predict top 1 labels: ['seawalls'] True lable: rocket
# Predict top 1 labels: ['w–z'] True lable: hamster
# Predict top 1 labels: ['broadheads'] True lable: caterpillar
# Predict top 1 labels: ['trestle'] True lable: train
# Predict top 1 labels: ['강행군'] True lable: raccoon
# Predict top 1 labels: ['tree'] True lable: oak_tree
# HIT!
# Predict top 1 labels: ['reconvening'] True lable: house
# Predict top 1 labels: ['菅原'] True lable: worm
# ...
# Predict top 5 labels: ['motocycle' 'phalangers' '#motorcycle' 'motocycles' 'motorcycle'] True lable: elephant
# Predict top 5 labels: ['feca' 'interrupters' 'regulator' 'interrupter' 'grinned'] True lable: crab
# Predict top 5 labels: ['pickup' 'bodies…' 'interrupter' 'recocking' 'recocks'] True lable: can
# Predict top 5 labels: ['bowshot' 'kting' 'woodcutters' 'handcart' 'mfecane'] True lable: willow_tree
# Predict top 5 labels: ['not—the' 'telecope' 'kbte' 'telecome' 'cldt'] True lable: sea
# Predict top 5 labels: ['dipsinhji' 'meakim' 'thr' 'dihl' 'taben'] True lable: train
# Predict top 5 labels: ['yawning' 'teratogen' 'glycogenolytic' 'pamine' 'serotonin'] True lable: keyboard
# Predict top 5 labels: ['机' 'resonators' 'clock' 'interrupter' 'recocks'] True lable: chair
# Predict top 5 labels: ['decocks' 'interrupter' 'guzzi' 'phonograph' 'recocks'] True lable: maple_tree
# Predict top 5 labels: ['dethbrush' 'clopyralid' 'entomogenous' 'insectide' 'insecticides'] True lable: girl
# Predict top 5 labels: ['americhip' 'xhers' 'xhecs' 'dimed' 'ifwu'] True lable: cattle
# Predict top 5 labels: ['luvos' 's,s,s' 'xyrem' 'repros' 'canadas'] True lable: oak_tree
# Predict top 5 labels: ['clites' 'epitre' 'latr' 'acarius' 'clite'] True lable: raccoon
# Predict top 5 labels: ['regulate' '_cariappa' 'duméril' 'approprioate' 'interdigit'] True lable: flatfish
# Predict top 5 labels: ['regulate' 'wfwf' 'dimeglumine' 'wme/img' 'cadenatres'] True lable: orange
# Predict top 5 labels: ['immedialtely' 'cavity' 'f/adh' 'dbacks' '기대'] True lable: orange
# Predict top 5 labels: ['‘abdāl' 'order—that' 'on—or' 'ybc' '‘altered'] True lable: chimpanzee
# Predict top 5 labels: ['thalidomide' 'intercolonial' 'intercolony' 'paralysing' 'femot'] True lable: woman
# Predict top 5 labels: ['phalangers' 'phalangites' 'phalanger' 'dipus' 'girê'] True lable: bee
# Predict top 5 labels: ['regulate' 'regulates' 'permittee' 'aubc' 'phtk'] True lable: tiger
# Predict top 5 labels: ['tegus' 's,s,s' 'chamelion' 'triclabendazole' 'maintinence'] True lable: sea
# Predict top 5 labels: ['ㅘ' '北地' 'plain' 'ഭുമി' 'oberried'] True lable: lobster
# Predict top 5 labels: ['pœnas' '#highways' 'חכם' 'renumber' '#highway'] True lable: woman
# Predict top 5 labels: ['right,but' 'electrodermograph' 'image—the' 'repolarize' 'stimulation'] True lable: otter
# Predict top 5 labels: ['recommences' 'ntbc' 'synopsin' 'rntbc' 'mn/dot'] True lable: worm
# Predict top 5 labels: ['luncheons' 'umw' 'tmmc' 'wme/img' '台灣省'] True lable: cockroach
# Predict top 5 labels: ['cabezon' 'abenakis' 'abenaim' 'skáney' 'leecher'] True lable: turtle
# Predict top 5 labels: ['precobs' 'fjords' 'tensilon' 'geonets' '糾'] True lable: ray
# Predict top 5 labels: ['ganalo' 'bwcaw' 'bairdi' 'tuataras' 'rafts'] True lable: forest
# Predict top 5 labels: ['monostearate' 'gelatine' 'microfibres' 'mugars' 'ybc'] True lable: can
# Predict top 5 labels: ['gelred' 'phytofruit' 'azurine' 'margarine' 'gelre'] True lable: forest
# Predict top 5 labels: ['nài' 's+c' '正名' 'scn' 'dtbzoh'] True lable: bottle
# Predict top 5 labels: ['regulate' 'mgg' 'relaly' 'keptin' 'wme/img'] True lable: bowl
# Predict top 5 labels: ['˥' 'flight,' 'flight—the' 'descend' 'umnak'] True lable: man
# Predict top 5 labels: ['promontories' 'trenches' 'ghabisiyya' 'qubays' 'siyyad'] True lable: road
# Predict top 5 labels: ['_left' '_rcde' 'cavity' '_rc' '△t'] True lable: cockroach
# Predict top 5 labels: ['lößnitz' 'thüngen' 'schweinfurthi' 'handcars' 'pfafferode'] True lable: willow_tree
# Predict top 5 labels: ['bagassa' 'preservancy' 'preservance' '#caterpillar' 'hamamelose'] True lable: clock
# Predict top 5 labels: ['polegars' '厉害' 'footways' 'amfl' '함흥'] True lable: lamp
# Predict top 5 labels: ['gu/si/gun' 'stereotypies' 'impair' 'répété' 'nonco'] True lable: porcupine
# Predict top 5 labels: ['assembly—the' 'knifv' 'motormen' 'rrq' 'spearer'] True lable: orange
# Predict top 5 labels: ['alate' 'cruciferous' 'psyllid' 'ointment' 'osmet'] True lable: bowl
# Predict top 5 labels: ['regulate' 'paralyzes' 'impair' 'guzzi' 'jumanos'] True lable: butterfly
# Predict top 5 labels: ['s,s,s' 'corns' 'eggwhites' 'ybc' '詞'] True lable: lawn_mower
# Predict top 5 labels: ['˥' 'walk//all' 'scdot' 'hereby' 'spidercage'] True lable: snail
# Predict top 5 labels: ['tomahas' 'bullton' 'hsfv' 'dynamited' 'smrr'] True lable: orchid
# Predict top 5 labels: ['inrush' 'wellbores' 'inrushes' 'palisade' 'umbilically'] True lable: table
# Predict top 5 labels: ['repolarise' 'koac' 'bodies…' 'repolarize' 'dtbzoh'] True lable: chair
# Predict top 5 labels: ['relampago' 'skunkpox' 'lopé' 'caceros' 'skunks'] True lable: dinosaur
# Predict top 5 labels: ['bush—the' 'quautlatas' 'amhc' 'cabin' 'accident—the'] True lable: skyscraper
# Predict top 5 labels: ['commoncat' 'palegars' 'choultry' 'thenkalais' 'satversme'] True lable: hamster
# Predict top 5 labels: ['mastira' 'mican' 'simkania' 'mccleave' 'camarota'] True lable: aquarium_fish
# Predict top 5 labels: ['excretions' 'mispider' 'reclarify' 'spadefoots' 'puddling'] True lable: crab
# Predict top 5 labels: ['xejpv' 'xhers' 'xherj' 'xher' 'wme/img'] True lable: worm
# Predict top 5 labels: ['everit' 'betrothal' 'keptin' 'taben' 'sertindole'] True lable: baby
# Predict top 5 labels: ['osmet' 'sweetener' 'azurine' 'pomegranate' 'amaret'] True lable: willow_tree
# Predict top 5 labels: ['gøn' 'hindrup' 'bandolim' 'scalping' 'gangjee'] True lable: rocket
# Predict top 5 labels: ['davidof' 'sargasso' 'reef' 'shores' 'seashores'] True lable: hamster
# Predict top 5 labels: ['uclaf' 'factivia' '等等》' 'crystallion' 'actafl'] True lable: caterpillar
# Predict top 5 labels: ['γk' 'cauterising' 'estriol' 'balls' 'microfibers'] True lable: train
# Predict top 5 labels: ['bison' 'sandhogs' 'paltothyreus' 'gopherus' 'wolverine#wolverine'] True lable: raccoon
# Predict top 5 labels: ['paralyzing' 'paralyzes' 'estadista' 'cockroach' 'frar'] True lable: oak_tree
# Predict top 5 labels: ['rafted' 'furðustrandir' 'logjams' 'highwall' 'fossá'] True lable: house
# Predict top 5 labels: ['whaled' 'spearfishermen' 'cancura' 'ticopa' 'torches'] True lable: worm
# Predict top 5 labels: ['acpc' 'diosmetin' 'asgrow' 'phytofruit' 'osmet'] True lable: wolf
# Predict top 5 labels: ['dimeglumine' 'meglumine' 'salivan' 'bе' 'domide'] True lable: bridge
# Predict top 5 labels: ['migrate' 'migrates' 'migrating' 'tarid' 'ahrida'] True lable: otter
# Predict top 5 labels: ['shellmound' 'azimgunj' 'palisade' 'storehouses' 'fortree'] True lable: camel
# Predict top 5 labels: ['˥' '_cariappa' 'solifugid' 'spidercam' 'spidercage'] True lable: tank
# Predict top 5 labels: ['horizant' 'noctules' '#caterpillar' 'etheostomus' 'ovipositors'] True lable: camel
# Predict top 5 labels: ['omahas' 'cuased' 'firqats' 'luggye' 'dharamshalas'] True lable: can
# Predict top 5 labels: ['陽翟' 'crystallise' 'crystallised' 'crystallize' '等等》'] True lable: forest
# Predict top 5 labels: ['promontories' 'oceanflow' 'coastline' 'shores' 'cliffs'] True lable: worm
# Predict top 5 labels: ['lumberer' 'sandhogs' 'kocoum' 'nonmiton' 'handcart'] True lable: squirrel
# Predict top 5 labels: ['matrilin' 'naravas' 'pageton' 'விரைவு' 'chettis'] True lable: cup
# Predict top 5 labels: ['creaming' 'creamed' 'cream/ointment' 'vegemite' 'ybc'] True lable: rocket
# Predict top 5 labels: ['paried' 'interdigit' 'paries' '#formation' 'parier'] True lable: mushroom
# Predict top 5 labels: ['transmittal' 'woodframe' 'embrasured' 'auditory' 'sawed'] True lable: seal
# Predict top 5 labels: ['cbmt' 'thiabendazole' 'wawrykow' 'tonnies' 'canadas'] True lable: keyboard
# Predict top 5 labels: ['diphosphenes' 'stereocilia' 'γk' 'stereocilium' 'orthodromic'] True lable: bicycle
# Predict top 5 labels: ['kbte' 'koauau' 'sinkhole' 'atuh' 'koap'] True lable: palm_tree
# Predict top 5 labels: ['restrictons' 'mongooses' 'burrowing' 'restrictors' 'mongoose'] True lable: pine_tree
# Predict top 5 labels: ['mgg' 'fishwater' 'fish' '廣晉' 'iskwater'] True lable: camel
# Predict top 5 labels: ['lößnitz' 'spontoon' 'trahegnies' 'sandhouse' 'house'] True lable: chimpanzee
# Predict top 5 labels: ['nо' 'munsur' 'wekaf' 'wekufes' 'elefant'] True lable: snail
# Predict top 5 labels: ['langars' 'azimghur' '閻寶' 'trahegnies' 'shweir'] True lable: lobster
# Predict top 5 labels: ['nо' 'picosat' 'monovision' 'ovulation' 'monovisions'] True lable: chimpanzee
# Predict top 5 labels: ['grain' 'creaming' 'unsweetened' 'ybc' '詞'] True lable: squirrel
# Predict top 5 labels: ['breakpoints' 'time—as' 'breakpoint' 'time—are' 'maskable'] True lable: tractor
# Predict top 5 labels: ['amfl' 'antrain' 'ergnies' 'muanikau' 'trahegnies'] True lable: house
# Predict top 5 labels: ['amundava' 'fossesholm' 'housesteads' 'eastfold' 'highwalk'] True lable: motorcycle
# Predict top 5 labels: ['taklakot' 'huts' 'marshy' 'bolgars' 'lakebeds'] True lable: maple_tree
# Predict top 5 labels: ['substructure' 'palisaded' 'palisade' 'hewn' 'joists'] True lable: palm_tree
# Predict top 5 labels: ['halfcut' 'snakefoot' 'barasingha' 'ferrets' 'mooji'] True lable: rabbit
# Predict top 5 labels: ['pickup' 'kcjx' 'footboard' 'reclear' 'motormen'] True lable: willow_tree
# Predict top 5 labels: ['motocycle' 'footboard' '#motorcycle' 'bicycle' 'motorcyclists'] True lable: butterfly
# Predict top 5 labels: ['klansman' 'sawed' 'tarboard' 'president—the' 'accident—the'] True lable: oak_tree
# Predict top 5 labels: ['cpgs' 'nonc' 'impair' 'ŏk' 'carver–hawkeye'] True lable: baby
# Predict top 5 labels: ['difrawi' 'naqahdriah' 'tunebo' 'ehaje' 'zorglub'] True lable: plain
# Predict top 5 labels: ['paralyzes' 'interrupters' 'elapids' 'phimophis' 'interrupter'] True lable: bottle
# Predict top 5 labels: ['triclabendazole' 'thiabendazole' 'psop' 'eloxatin' 'osmet'] True lable: road
# Predict top 5 labels: ['—strictly' 'nenthead' 'paldevendran' 'reclarify' 'eruvil'] True lable: clock
# Predict top 5 labels: ['isut' 'kifl' 'ujud' 'pikuach' '陽光宅男'] True lable: cloud
# Predict top 5 labels: ['regulate' 'angakkuq' 'contactors' 'seal' 'chadrel'] True lable: lizard
# Predict top 5 labels: ['roadbed' 'trestles' 'trestle' 'tjeldsundet' 'raftsund'] True lable: cattle
# Predict top 5 labels: ['barjees' 'doukhobour' 'militiants' 'doukhobors' 'hallamshires'] True lable: orchid
# Predict top 5 labels: ['motocycle' 'cbibpt' 'scdot' 'cvrtc' 'maindample'] True lable: wolf
# Predict top 5 labels: ['fungites' 'sugar' 'ybc' 'eggwhites' 'millets'] True lable: cloud
# Predict top 5 labels: ['bullsnakes' '#prey' 'ticks' 'hyphenless' 'acarid'] True lable: orchid
# Predict top 5 labels: ['nekaf' 'gananatha' 'meskwakis' 'lathis' 'najjadah'] True lable: poppy
# Predict top 5 labels: ['solidify' 'tôn' 'vågnes' 'tonnies' 'canadas'] True lable: palm_tree
# Predict top 5 labels: ['bapn' 'agrilia' 'nicotia' 'queenless' 'osmet'] True lable: cloud
# Predict top 5 labels: ['barasinga' 'kanha' 'barasingha' 'nontimber' 'kolambkar'] True lable: leopard
# Predict top 5 labels: ['notro' 'luthic' 'umkehr' 'transients' 'skagra'] True lable: streetcar
# Predict top 5 labels: ['sandhogs' 'groundhogs' 'woodcuttings' 'woodcutting' 'grassé'] True lable: raccoon
# Predict top 5 labels: ['phalangeal' 'phalangers' 'sandhogs' 'phalanger' 'cervus'] True lable: television
# Predict top 5 labels: ['phalangeal' 'narasinh' 'narasinha' 'incisors' 'femurs'] True lable: maple_tree
# Predict top 5 labels: ['cottonwood' '#cottonwood' 'agamic' 'muttonwood' 'maindample'] True lable: maple_tree
# Predict top 5 labels: ['—strictly' 'paldevendran' 'ke_' 'hyphenless' '#prefer'] True lable: lobster
# Predict top 5 labels: ['ouabain' 'mgga' 'nutriment' 'nutriments' '강행군'] True lable: leopard
# Predict top 5 labels: ['votaries' 'skangites' 'नमो' 'usinaras' 'readheads'] True lable: mushroom
# Predict top 5 labels: ['xulub' 'kitekite' 'pikuach' 'eruption' 'offshore'] True lable: bowl
# Predict top 5 labels: ['mahwish' 'mansor' 'marabouts' 'relaly' 'onang'] True lable: girl
# Predict top 5 labels: ['millilitres' 'millilitre' 'nmol/l' 'micrograms/ml' '等等》'] True lable: road
# Predict top 5 labels: ['kosem' 'mpon' 'ἑτέραν' 'papb' 'matine'] True lable: bus
# Predict top 5 labels: ['nо' 'tendekai' 'tertipu' 'djaoeh' 'menolak'] True lable: otter
# Predict top 5 labels: ['opun' 'sargasso' 'gilf' 'shores' 'sinkhole'] True lable: fox
# Predict top 5 labels: ['amnh' 'crotalid' 'hand/wrist' 'acephale' 'texacephale'] True lable: shrew
# Predict top 5 labels: ['patrobas' 'regrow' 'reclarify' 'stimulon' 'regrows'] True lable: maple_tree
# Predict top 5 labels: ['metpa' 'queenless' 'mgga' 'kncb' 'osmet'] True lable: lamp
# Predict top 5 labels: ['bicamerally' 'interrupters' 'interrupter' 'rectigraph' 'receivers'] True lable: mushroom
# Predict top 5 labels: ['nagap' 'npga' 'kebsi' 'scalps' 'ritualize'] True lable: bee
# Predict top 5 labels: ['phalangers' 'roadhogs' 'sandhogs' 'kmpr' 'ferrets'] True lable: bear
# Predict top 5 labels: ['delainey' 'allard' 'bilardo' 'ferrets' 'dugès'] True lable: skyscraper
# Predict top 5 labels: ['klakson' 'happersen' 'diptan' 'emasculators' 'wawrykow'] True lable: oak_tree
# Predict top 5 labels: ['beekeepers' 'gnassa' 'vermicide' 'matine' 'bustamite'] True lable: orange
# Predict top 5 labels: ['maintalbahn' 'steyrtalbahn' 'aartalbahn' 'etbs' 'nationalbahn'] True lable: fox
# Predict top 5 labels: ['bandelia' 'osmet' 'muskgrass' 'witchgrass' 'grassé'] True lable: plain
# Predict top 5 labels: ['pœnas' 'mmbn' 'vews' '朱誠' 'mm–'] True lable: porcupine
# Predict top 5 labels: ['supracrystals' 'uhmk' 'perfuses' 'perfuse' 'cathod'] True lable: cup
# Predict top 5 labels: ['wadis' 'huts' 'mountainside' 'shores' 'mountainsides'] True lable: cockroach
# Predict top 5 labels: ['servil' 'pinchback' 'fulltimers' 'wawrykow' 'hostler'] True lable: hamster
# Predict top 5 labels: ['strangites' 'ylmia' 'mgga' 'woundy' 'penangites'] True lable: rocket
# Predict top 5 labels: ['phospheros' 'scleraxis' 'w–z' '#glucose' 'secretions'] True lable: sunflower
# Predict top 5 labels: ['rolfes' 'mgga' 'matine' 'cbfv' 'freom'] True lable: train
# Predict top 5 labels: ['sealaska' 'ancsa' 'impair' 'decertify' 'paralyzes'] True lable: rose
# Predict top 5 labels: ['phalangers' 'amfl' 'phalangites' 'phalanger' 'combless'] True lable: skunk
# Predict top 5 labels: ['yamit' 'naim' 'zerin' 'pikuach' 'naqahdriah'] True lable: snail
# Predict top 5 labels: ['cedar' 'lumbered' 'tree' 'nodena' 'trees'] True lable: lion
# Predict top 5 labels: ['ktoh' 'pugil' 'giardi' 'tendeka' 'abendan'] True lable: lion
# Predict top 5 labels: ['osteomeles' 'malvales' 'emblicanin' 'barasingha' 'emblicanins'] True lable: snake
# Predict top 5 labels: ['coraceros' 'motocycles' 'nondo' 'braceros' 'caceros'] True lable: streetcar
# Predict top 5 labels: ['tankcars' 'choultry' 'encamping' 'facilitiate' '海部郡'] True lable: squirrel
# Predict top 5 labels: ['nо' 'dicket' 'adopta' 'ferrets' 'triclabendazole'] True lable: raccoon
# Predict top 5 labels: ['barasia' 'paldevendran' 'barasingha' 'antilopine' 'duvauceli'] True lable: girl
# Predict top 5 labels: ['setnence' 'vāsanās' 'nhow' 'svetambaras' 'tirthankaras'] True lable: table
# Predict top 5 labels: ['pithole' 'wiring' 'bowstring' 'felled' 'decern'] True lable: chimpanzee
# Predict top 5 labels: ['⑆' 'necab' 'svos' 'paspa' 'azmu'] True lable: mountain
# Predict top 5 labels: ['seashore' 'palmahim' '糾' 'tekoa' 'oconaluftee'] True lable: willow_tree
# Predict top 5 labels: ['alivan' 'repros' 'nimeth' 'actafl' 'arsl'] True lable: camel
# Predict top 5 labels: ['shore' 'offshores' 'tekoa' 'northshorespirit' 'shores'] True lable: house
# Predict top 5 labels: ['rafted' 'muzdalifah' 'muzdalifa' 'rafts' 'cliffs'] True lable: baby
# Predict top 5 labels: ['motocycle' 'jank' 'xhers' 'xhel' 'ustpa'] True lable: tractor
# Predict top 5 labels: ['uropsila' 'mongooses' 'mammali' 'porcupines' 'ferrets'] True lable: hamster
# Predict top 5 labels: ['reclarify' 'pnwr' 'caterpillar' 'hrbc' 'cpnwr'] True lable: bottle
# Predict top 5 labels: ['obligate' 'ccclvii' 'triphalangeal' 'thornier' 'phagoptosis'] True lable: orange
# Predict top 5 labels: ['tonnin' 'huchem' 'roet' 'rasmine' 'tonnies'] True lable: trout
# Test result: Top 1 hit rate 0.19 %
# Test result: Top 3 hit rate 0.39 %
# Test result: Top 5 hit rate 0.41 %
